# %%
from functions import *

# %%
df = load_data_tagtog(['../tagtog/output'])

# %%
df
# Out:
#                                     doc_id  \
# 0     ec583817-3c60-41ee-b856-65f0d9bd7772
# 1     f4806621-b874-4f20-97fb-f7c1fa94f6bc
# 2     259d503d-f6b1-44b6-a866-8eff03799a07
# 3                                     None
# 4     f4182e23-bcd2-4627-b5ee-6284ac4a2eac
# ...                                    ...
# 1385  3ab75588-1219-4abb-b46d-0573897425b1
# 1386  dcbad4f4-8464-4d15-b952-309fa61172d9
# 1387  fd8a27cf-2d1c-4f97-8900-4def4fba882f
# 1388  4d833d8f-18ea-4a98-87ff-50ecc04b4f97
# 1389  e214aa71-0b08-4540-a3b8-01e7f6f97c5f
#
#                                                filename  \
# 0     dailySun_data_ec583817-3c60-41ee-b856-65f0d9bd...
# 1     theDailyStar_data_f4806621-b874-4f20-97fb-f7c1...
# 2     prothomalo_data_259d503d-f6b1-44b6-a866-8eff03...
# 3     1989_34feabf9fb9bd7378a2a378bbc72e5c80ce50f43.txt
# 4     dhakaTribune_data_f4182e23-bcd2-4627-b5ee-6284...
# ...                                                 ...
# ...

# %%
df[df['event_damage'].apply(lambda x:len(x)>0)]
# Out:
#                                     doc_id  \
# 27    b83c5c87-da13-4043-ad4b-87d436d9a56c
# 54    729dcbab-e075-413a-add7-ca10168816ec
# 74                                    None
# 104   04e0b65e-5c66-42cb-bb1a-422dc4c7630a
# 126                                   None
# ...                                    ...
# 1266                                  None
# 1300  edc272d7-71f1-4abc-80e5-4ee06358d386
# 1309                                  None
# 1351                                  None
# 1362  9362053a-e588-44e6-8eb5-b0f2f2c83a05
#
#                                                filename  \
# 27    theDailyStar_data_b83c5c87-da13-4043-ad4b-87d4...
# 54    theDailyStar_data_729dcbab-e075-413a-add7-ca10...
# 74    1988_c592d7972eb0f78bc4dd832376167cdfcb5ec4b2.txt
# 104   dhakaTribune_data_04e0b65e-5c66-42cb-bb1a-422d...
# 126   1987_acde84fb87df06b145e2c18b8f046795370ee401.txt
# ...                                                 ...
# ...
