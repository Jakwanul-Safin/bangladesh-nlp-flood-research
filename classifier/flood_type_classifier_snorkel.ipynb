# %%
import warnings
warnings.filterwarnings("ignore")

import os
import dateparser
import pandas as pd
import json
import nltk
import numpy as np
import string
import re
import csv
from datetime import datetime
from collections import defaultdict
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 12})
from functions import *
import dateparser
from fuzzysearch import find_near_matches
from ccfMitchell import ccf

# %%
df_data_snorkel = pd.read_json('timeseries_data/data_snorkel.json')

# %%
flood_types = ['cyclone', 'river', 'flash', 'urban', 'monsoon']

# %%
df_data_snorkel[[f+"Any" for f in flood_types]]
# Out:
#      cycloneAny  riverAny  flashAny  urbanAny  monsoonAny
# 0         False      True     False     False        True
# 1         False      True      True     False        True
# 2         False     False      True      True        True
# 3         False      True     False      True        True
# 4         False      True     False     False        True
# 5         False     False     False     False       False
# 6         False     False      True      True        True
# 7         False     False     False      True        True
# 8         False     False     False     False       False
# 9         False     False     False     False       False
# 10        False     False     False     False        True
# 11        False     False      True      True        True
# 12        False     False      True     False       False
# 13        False     False      True     False        True
# 14        False     False     False     False       False
# 15        False     False     False     False        True
# 16        False     False     False     False        True
# 17        False     False     False     False       False
# 18        False     False     False      True        True
# 19        False     False     False     False       False
# 20        False      True      True     False        True
# 21        False     False      True     False        True
# 22        False     False      True     False       False
# 23        False     False     False     False       False
# 24        False     False      True      True        True
# 25        False     False     False     False       False
# 26        False     False     False     False        True
# 27        False     False     False     False        True
# 28        False     False      True      True       False
# 29        False      True     False     False       False
# ..          ...       ...       ...       ...         ...
# 163       False     False     False     False       False
# 164       False     False     False     False       False
# 165       False     False     False      True       False
# 166       False     False     False      True        True
# 167       False     False      True      True        True
# 168       False     False     False     False        True
# 169       False     False     False     False        True
# 170       False      True     False     False        True
# 171       False      True     False     False        True
# 172       False      True      True      True        True
# 173       False     False     False     False       False
# 174       False     False      True     False        True
# 175       False     False     False      True        True
# 176       False      True      True     False       False
# 177       False     False     False      True        True
# 178       False     False     False     False       False
# 179       False      True      True     False        True
# 180       False     False      True      True        True
# 181       False     False     False     False        True
# 182       False      True     False     False       False
# 183       False      True      True      True        True
# 184       False      True     False      True       False
# 185       False     False      True      True        True
# 186       False     False     False     False        True
# 187       False     False     False     False       False
# 188       False      True     False     False       False
# 189       False      True      True      True        True
# 190       False     False     False     False       False
# 191       False     False      True      True        True
# 192       False     False     False     False        True
#
# [193 rows x 5 columns]
