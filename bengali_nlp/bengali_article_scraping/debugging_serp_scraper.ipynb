# %% [markdown]
# # Config File

# %%
import json, yaml
from datetime import timedelta, date, datetime

PAPER_SITES_FILE = "paper_to_site.json"
with open("paper_to_site.json", 'r') as f:
    paper_site = json.load(f)

class SERPLinkScraperConfig:
    def __init__(self, config_file = None):
        self.config = {
            "searchnws": False, 
            "gl": "bd", 
            "hl": "bn", 
            "filter": "0", 
            "num": 100,
            "output_dir": "",
            "output_file": "serp_{papers}_{query}.json",
            "quote_sub": "[QUOTE]",
            "overwrite": False,
            "skip_existing": True,
            "seen_sites_file": None
        }
        
        if config_file is not None:
            self.load_config(config_file)
    
    def range_dates(self, date_start:date, date_end:date, increment:timedelta):
        """
        Helper function to get time intervals
        :param date_start: Starting date
        :param date_end: ending date
        :param increment: increments dates by value
        :return: list of dates
        """
        while date_start + increment < date_end:
            yield date_start, date_start + increment
            date_start += increment
        yield date_start, date_end

    def generate_dates_from_date_ranges(self, date_ranges):
        dates = []
        for start, end, inc in date_ranges:
            start = datetime.strptime(start, "%m/%d/%Y").date()
            end = datetime.strptime(end, "%m/%d/%Y").date()
            inc = timedelta(days=inc)
            dates.extend((s.strftime("%m/%d/%Y"), t.strftime("%m/%d/%Y")) for s, t in self.range_dates(start, end, inc))
        return dates
    
    def query_paper_date_from_spec(self, specs):
        if 'query' in specs:
            queries = [specs['query']]
        elif 'queries' in specs:
            queries = specs['queries']
        else:
            raise KeyError("Expecting 'queries' in config file")
        
        if 'paper' in specs:
            papers = [specs['paper']]
        elif 'papers' in specs:
            papers = specs['papers']
        else:
            raise KeyError("Expecting 'paper' in config file")
            
        unknown_papers = [paper for paper in papers if paper not in paper_site]
        if len(unknown_papers) > 0:
            raise KeyError("Unknown papers: {}\nPlease add to paper list".format(", ".join(unknown_papers)))
        
        if 'date_ranges' not in specs:
            raise KeyError("Expecting 'date_ranges' in config file")
        
        dates = self.generate_dates_from_date_ranges(specs['date_ranges'])
        
        for q in queries:
            for p in papers:
                for d in dates:
                    yield q, p, d  
    
    def params(self, query, paper, date_interval):
        site = paper_site[paper]
        start_date, end_date = date_interval
        params = {
            "engine": "google",
            "q": "{} site:{}".format(query, site),
            "google_domain": "google.com",
            "gl": self.config['gl'],
            "hl": self.config['hl'],
            'filter':self.config['filter'],
            "num": self.config['num'],
            "api_key": self.config['SERPAPI_KEY'],
            "tbs": "cdr:1,cd_min:{},cd_max:{}".format(start_date, end_date)
        }

        if self.config['searchnws']:
            params["tbm"] = "nws"

        return params 
    
    def update_config(self, config_file):
        with open(config_file, "r", encoding='utf-8') as f:
            self.config.update(yaml.load(f, Loader=yaml.FullLoader))
    
    def check_config(self):
        missing = [param for param in ('SERPAPI_KEY',) if param not in self.config]
        if len(missing) > 0:
            raise KeyError("Config missing: {}".format(", ".join(missing)))

    def load_config(self, config_file):
        self.update_config(config_file)
        self.check_config()
        
    def searches(self, spec = None):
        if spec is None:
            spec = self.config
            
        if "searches" in spec:
            for spec in self.config['searches'].values():
                for search in self.searches(spec):
                    yield search
        else:
            for query, paper, date in self.query_paper_date_from_spec(spec):
                yield query, paper, date, self.params(query, paper, date)
                
    def outfile(self):
        filename = self.config["output_file"]
        outdir = self.config["output_dir"] if 'output_dir' in self.config else ""
        return os.path.join(outdir, filename)
        
    def __repr__(self):
        return self.config.__repr__()

# %%
s = SERPLinkScraperConfig("RandomDenseSERPSearch.yaml")

# %%
for q, i in zip(s.searches(), range(10)):
    print(q)
# Out:
# ('"হয়েছে"', 'the_daily_janakantha', ('01/01/1996', '12/30/2000'), {'engine': 'google', 'q': '"হয়েছে" site:https://www.dailyjanakantha.com', 'google_domain': 'google.com', 'gl': 'bd', 'hl': 'bn', 'filter': '0', 'num': 100, 'api_key': 'c8f7c4a413d768d9b454c42f233867c4bf3f4dba7be4b31bae4ed7b9b05dd268', 'tbs': 'cdr:1,cd_min:01/01/1996,cd_max:12/30/2000'})
# ('"হয়েছে"', 'the_daily_janakantha', ('12/30/2000', '12/29/2005'), {'engine': 'google', 'q': '"হয়েছে" site:https://www.dailyjanakantha.com', 'google_domain': 'google.com', 'gl': 'bd', 'hl': 'bn', 'filter': '0', 'num': 100, 'api_key': 'c8f7c4a413d768d9b454c42f233867c4bf3f4dba7be4b31bae4ed7b9b05dd268', 'tbs': 'cdr:1,cd_min:12/30/2000,cd_max:12/29/2005'})
# ('"হয়েছে"', 'the_daily_janakantha', ('12/29/2005', '12/28/2010'), {'engine': 'google', 'q': '"হয়েছে" site:https://www.dailyjanakantha.com', 'google_domain': 'google.com', 'gl': 'bd', 'hl': 'bn', 'filter': '0', 'num': 100, 'api_key': 'c8f7c4a413d768d9b454c42f233867c4bf3f4dba7be4b31bae4ed7b9b05dd268', 'tbs': 'cdr:1,cd_min:12/29/2005,cd_max:12/28/2010'})
# ('"হয়েছে"', 'the_daily_janakantha', ('12/28/2010', '12/27/2015'), {'engine': 'google', 'q': '"হয়েছে" site:https://www.dailyjanakantha.com', 'google_domain': 'google.com', 'gl': 'bd', 'hl': 'bn', 'filter': '0', 'num': 100, 'api_key': 'c8f7c4a413d768d9b454c42f233867c4bf3f4dba7be4b31bae4ed7b9b05dd268', 'tbs': 'cdr:1,cd_min:12/28/2010,cd_max:12/27/2015'})
# ('"হয়েছে"', 'the_daily_janakantha', ('12/27/2015', '12/31/2015'), {'engine': 'google', 'q': '"হয়েছে" site:https://www.dailyjanakantha.com', 'google_domain': 'google.com', 'gl': 'bd', 'hl': 'bn', 'filter': '0', 'num': 100, 'api_key': 'c8f7c4a413d768d9b454c42f233867c4bf3f4dba7be4b31bae4ed7b9b05dd268', 'tbs': 'cdr:1,cd_min:12/27/2015,cd_max:12/31/2015'})
# ('"হয়েছে"', 'the_daily_janakantha', ('01/01/2016', '02/20/2016'), {'engine': 'google', 'q': '"হয়েছে" site:https://www.dailyjanakantha.com', 'google_domain': 'google.com', 'gl': 'bd', 'hl': 'bn', 'filter': '0', 'num': 100, 'api_key': 'c8f7c4a413d768d9b454c42f233867c4bf3f4dba7be4b31bae4ed7b9b05dd268', 'tbs': 'cdr:1,cd_min:01/01/2016,cd_max:02/20/2016'})
# ('"হয়েছে"', 'the_daily_janakantha', ('02/20/2016', '04/10/2016'), {'engine': 'google', 'q': '"হয়েছে" site:https://www.dailyjanakantha.com', 'google_domain': 'google.com', 'gl': 'bd', 'hl': 'bn', 'filter': '0', 'num': 100, 'api_key': 'c8f7c4a413d768d9b454c42f233867c4bf3f4dba7be4b31bae4ed7b9b05dd268', 'tbs': 'cdr:1,cd_min:02/20/2016,cd_max:04/10/2016'})
# ('"হয়েছে"', 'the_daily_janakantha', ('04/10/2016', '05/30/2016'), {'engine': 'google', 'q': '"হয়েছে" site:https://www.dailyjanakantha.com', 'google_domain': 'google.com', 'gl': 'bd', 'hl': 'bn', 'filter': '0', 'num': 100, 'api_key': 'c8f7c4a413d768d9b454c42f233867c4bf3f4dba7be4b31bae4ed7b9b05dd268', 'tbs': 'cdr:1,cd_min:04/10/2016,cd_max:05/30/2016'})
# ('"হয়েছে"', 'the_daily_janakantha', ('05/30/2016', '07/19/2016'), {'engine': 'google', 'q': '"হয়েছে" site:https://www.dailyjanakantha.com', 'google_domain': 'google.com', 'gl': 'bd', 'hl': 'bn', 'filter': '0', 'num': 100, 'api_key': 'c8f7c4a413d768d9b454c42f233867c4bf3f4dba7be4b31bae4ed7b9b05dd268', 'tbs': 'cdr:1,cd_min:05/30/2016,cd_max:07/19/2016'})
# ('"হয়েছে"', 'the_daily_janakantha', ('07/19/2016', '09/07/2016'), {'engine': 'google', 'q': '"হয়েছে" site:https://www.dailyjanakantha.com', 'google_domain': 'google.com', 'gl': 'bd', 'hl': 'bn', 'filter': '0', 'num': 100, 'api_key': 'c8f7c4a413d768d9b454c42f233867c4bf3f4dba7be4b31bae4ed7b9b05dd268', 'tbs': 'cdr:1,cd_min:07/19/2016,cd_max:09/07/2016'})

# %%
s.outfile()
# Out:
# 'testing/dense_serp.csv'

# %% [markdown]
# # Scraper

# %%
import os, sys, time
from datetime import timedelta, date, datetime

import csv
import pandas as pd

import logging
from logging.handlers import RotatingFileHandler

#from serpapi import GoogleSearch

# Logger for full SERP Queries
queryLogger = logging.getLogger('SERP Queries')
#queryLogger.setLevel(logging.INFO)
#ch = RotatingFileHandler("log/serpQuery.log", maxBytes=400000, backupCount=1000, encoding="utf-8")
#formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s \n%(message)s')
#ch.setFormatter(formatter)
#queryLogger.addHandler(ch)
if not queryLogger.handlers:
    sth = logging.StreamHandler()
    queryLogger.addHandler(sth)

# Logger for basic output
logger = logging.getLogger("SERP Logger")
logger.setLevel(logging.DEBUG)

#ch = logging.handlers.RotatingFileHandler("log/serpScrape.log", maxBytes=400000, encoding="utf-8")
#formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s \n%(message)s')
#ch.setFormatter(formatter)
#logger.addHandler(ch)

if not logger.handlers:
    sth = logging.StreamHandler()
    logger.addHandler(sth)
    
class SERPError(Exception):
    def __init__(self, msg):
        super().__init__(msg)

import random
class SERPLinkScraper:
    def __init__(self, config):
        self.config = config
        self.search_delay = 3.601 # Delay to avoid hiting the 1000 queries per hour limit
        self.last_search = - self.search_delay

    def search_results_for(self, params):
        results = {}
        
        for _ in range(10):
            rdm_link = str(random.randint(1000, 9999))[::-1]
            title = "title"
            results[rdm_link] = {'title': title, 'link': rdm_link}
            
        return results

        # Loop through till end of search results or error encountered
        MAX_HITS = int(1e10)
        for start in range(0, MAX_HITS, self.config['num']):
            params['start'] = start

            time.sleep(max(0, self.search_delay + self.last_search - time.time()))

            queryLogger.info(params)
            client = GoogleSearch(params)
            search_results = client.get_dict()
            search_results = {'error': "Google hasn't returned any results for this query"}


            self.last_search = time.time()

            if 'error' in search_results:
                if "Google hasn't returned any results for this query" in search_results['error']:
                    return results
                elif "Your searches for the month are exhausted" in search_results['error']:
                    raise SERPError(f"SERP searches exhausted\n{search_results['error']}")
                else:
                    raise SERPError(f"Found SERP error:\n{search_results['error']}")

            news_results = search_results['news_results'] if self.config['searchnws'] else search_results['organic_results']
            
            if news_results is None or news_results:
                return results

            for news in news_results:
                link = news['link']
                if link in results:
                    continue

                if link in self.seen_sites:
                    continue
                
                info = {k:v for k, v in news.items() if k in ('title', 'link', 'date')}
                results[link] = info
        raise OverflowError(f"Excepted at most {MAX_HITS} results for each query")

    def query_SERP(self, query:str, site:str, dates:list=[(None, None)]) -> list:
        """
        Make dict for serp query using make_params()
        query serpAPI
        :param query: query string for google news
        :param site: site root url (eg. www.google.com)
        :param dates: list of dates

        :return: List of results in format [{'title':[TITLE], 'link':[LINK], 'date':[DATE]}]: (date according to SERP)
        """
        self.seen_sites = set()
        if self.config["seen_sites_file"] is not None:
            with open(self.config["seen_sites_file"], 'r') as f:
                self.seen_sites = set(json.load(f))
        
        overlap = 0
        results = {}
        for start_date, end_date in dates:
            params = {
                "engine": "google",
                "q": "{} site:{}".format(query, site),
                "google_domain": "google.com",
                "gl": self.config['gl'],
                "hl": self.config['hl'],
                'filter':self.config['filter'],
                "num": self.config['num'],
                "api_key": self.config['SERPAPI_KEY'],
                "tbs": "cdr:1,cd_min:{},cd_max:{}".format(start_date, end_date)
            }
                        
            if self.config['searchnws']:
                params["tbm"] = "nws"

            try:
                new_results = self.search_results_for(params)
            except SERPError as e:
                logger.warning(f"Issue with SERP {e}")
                raise e
            results.update(new_results)
            logger.debug(f'Date Range: {start_date}-{end_date}\tSites Found: {len(new_results)}\tTotal Found: {len(results)}')

        logger.debug('Total Sites: {}, Overlap: {}'.format(len(results), overlap))
        return list(results.values())
    
    def execute_search(self, params):
        try:
            news_results = self.search_results_for(params)
        except SERPError as e:
            logger.warning(f"Issue with SERP {e}")
            raise e
        
        for result in news_results.values():
            yield result
        
    def run(self):
        columnnames = ('title', 'paper', 'date', 'link', 'query', 'search_date_start', 'search_date_end')
        outfile = self.config.outfile()
        if os.path.exists(outfile):
            logger.warning(f"An output File {outfile} Already Exists!")
            mode = 'a+'
            self.seen_links = set(pd.read_csv(outfile, delimiter = "\t")['link'])
        else:
            mode = 'w'
            self.seen_links = set()
            
        executed_searches, found_links = set(), set()
        total_searches = sum(1 for _ in self.config.searches())
        
        start = time.time()
        with open(outfile, mode, newline = '', encoding="utf-8") as f:
            writer = csv.DictWriter(f, delimiter = "\t", fieldnames = columnnames)
            
            if mode == 'w':
                writer.writeheader()
            
            q_links = 0
            for i, search in enumerate(self.config.searches()):
                query, paper, date, params = search
                if (query, paper, date) in executed_searches:
                    continue

                q_new_links = 0
                for result in self.execute_search(params):
                    if result['link'] in found_links:
                        continue
                    else:
                        q_new_links += 1
                        q_links += 1
                        found_links.add(result['link'])
                    
                    result['query'] = query
                    result['paper'] = paper
                    result['search_date_start'], result['search_date_end'] = date
                    writer.writerow({k:(v.replace("\t", "    ") if k != 'category' else v) for k, v in result.items()})
                
                executed_searches.add((query, paper, date))
                    
                logger.debug(f'Total New Sites from {query} on {paper} in {date[0]}-{date[1]}: {q_new_links}')
                
                if i % 50 == 0:
                    logger.info(f"Executed {i}/{total_searches} searches in {timedelta(seconds = time.time() - start)}\nTotal Sites: {q_links}")
                    
        logger.info(f"Completed in {timedelta(seconds = time.time() - start)}")

# %%
config = SERPLinkScraperConfig("RandomDenseSERPSearch.yaml")
scraper = SERPLinkScraper(config)

# %%
scraper.run()
# Out:
# An output File testing/dense_serp.csv Already Exists!
# Total New Sites from "হয়েছে" on the_daily_janakantha in 01/01/1996-12/30/2000: 10
# Executed 0/740 searches in 0:00:00.001246
# Total Sites: 10
# Total New Sites from "হয়েছে" on the_daily_janakantha in 12/30/2000-12/29/2005: 10
# Total New Sites from "হয়েছে" on the_daily_janakantha in 12/29/2005-12/28/2010: 10
# Total New Sites from "হয়েছে" on the_daily_janakantha in 12/28/2010-12/27/2015: 10
# Total New Sites from "হয়েছে" on the_daily_janakantha in 12/27/2015-12/31/2015: 10
# Total New Sites from "হয়েছে" on the_daily_janakantha in 01/01/2016-02/20/2016: 10
# Total New Sites from "হয়েছে" on the_daily_janakantha in 02/20/2016-04/10/2016: 10
# Total New Sites from "হয়েছে" on the_daily_janakantha in 04/10/2016-05/30/2016: 10
# Total New Sites from "হয়েছে" on the_daily_janakantha in 05/30/2016-07/19/2016: 10
# Total New Sites from "হয়েছে" on the_daily_janakantha in 07/19/2016-09/07/2016: 10
# Total New Sites from "হয়েছে" on the_daily_janakantha in 09/07/2016-10/27/2016: 10
# Total New Sites from "হয়েছে" on the_daily_janakantha in 10/27/2016-12/16/2016: 10
# Total New Sites from "হয়েছে" on the_daily_janakantha in 12/16/2016-02/04/2017: 10
# Total New Sites from "হয়েছে" on the_daily_janakantha in 02/04/2017-03/26/2017: 9
# Total New Sites from "হয়েছে" on the_daily_janakantha in 03/26/2017-05/15/2017: 10
# Total New Sites from "হয়েছে" on the_daily_janakantha in 05/15/2017-07/04/2017: 9
# Total New Sites from "হয়েছে" on the_daily_janakantha in 07/04/2017-08/23/2017: 9
# Total New Sites from "হয়েছে" on the_daily_janakantha in 08/23/2017-10/12/2017: 10
# Total New Sites from "হয়েছে" on the_daily_janakantha in 10/12/2017-12/01/2017: 10
# Total New Sites from "হয়েছে" on the_daily_janakantha in 12/01/2017-01/20/2018: 10
# Total New Sites from "হয়েছে" on the_daily_janakantha in 01/20/2018-03/11/2018: 8
# Total New Sites from "হয়েছে" on the_daily_janakantha in 03/11/2018-04/30/2018: 9
# Total New Sites from "হয়েছে" on the_daily_janakantha in 04/30/2018-06/19/2018: 10
# Total New Sites from "হয়েছে" on the_daily_janakantha in 06/19/2018-08/08/2018: 10
# Total New Sites from "হয়েছে" on the_daily_janakantha in 08/08/2018-09/27/2018: 9
# Total New Sites from "হয়েছে" on the_daily_janakantha in 09/27/2018-11/16/2018: 10
# Total New Sites from "হয়েছে" on the_daily_janakantha in 11/16/2018-01/05/2019: 10
# Total New Sites from "হয়েছে" on the_daily_janakantha in 01/05/2019-02/24/2019: 10
# Total New Sites from "হয়েছে" on the_daily_janakantha in 02/24/2019-04/15/2019: 9
# Total New Sites from "হয়েছে" on the_daily_janakantha in 04/15/2019-06/04/2019: 10
# Total New Sites from "হয়েছে" on the_daily_janakantha in 06/04/2019-07/24/2019: 10
# Total New Sites from "হয়েছে" on the_daily_janakantha in 07/24/2019-09/12/2019: 9
# Total New Sites from "হয়েছে" on the_daily_janakantha in 09/12/2019-11/01/2019: 10
# Total New Sites from "হয়েছে" on the_daily_janakantha in 11/01/2019-12/21/2019: 10
# Total New Sites from "হয়েছে" on the_daily_janakantha in 12/21/2019-02/09/2020: 10
# Total New Sites from "হয়েছে" on the_daily_janakantha in 02/09/2020-03/30/2020: 9
# Total New Sites from "হয়েছে" on the_daily_janakantha in 03/30/2020-05/19/2020: 9
# Total New Sites from "হয়েছে" on the_daily_janakantha in 05/19/2020-07/08/2020: 10
# Total New Sites from "হয়েছে" on the_daily_janakantha in 07/08/2020-08/27/2020: 10
# Total New Sites from "হয়েছে" on the_daily_janakantha in 08/27/2020-10/16/2020: 10
# Total New Sites from "হয়েছে" on the_daily_janakantha in 10/16/2020-12/05/2020: 10
# Total New Sites from "হয়েছে" on the_daily_janakantha in 12/05/2020-01/24/2021: 10
# Total New Sites from "হয়েছে" on the_daily_janakantha in 01/24/2021-03/15/2021: 10
# Total New Sites from "হয়েছে" on the_daily_janakantha in 03/15/2021-05/04/2021: 10
# Total New Sites from "হয়েছে" on the_daily_janakantha in 05/04/2021-06/23/2021: 10
# Total New Sites from "হয়েছে" on the_daily_janakantha in 06/23/2021-08/12/2021: 10
# Total New Sites from "হয়েছে" on the_daily_janakantha in 08/12/2021-10/01/2021: 10
# Total New Sites from "হয়েছে" on the_daily_janakantha in 10/01/2021-11/20/2021: 9
# Total New Sites from "হয়েছে" on the_daily_janakantha in 11/20/2021-12/31/2021: 10
# Total New Sites from "হয়েছে" on the_daily_jugantor in 01/01/1996-12/30/2000: 10
# Total New Sites from "হয়েছে" on the_daily_jugantor in 12/30/2000-12/29/2005: 9
# Executed 50/740 searches in 0:00:00.032583
# Total Sites: 497
# Total New Sites from "হয়েছে" on the_daily_jugantor in 12/29/2005-12/28/2010: 10
# Total New Sites from "হয়েছে" on the_daily_jugantor in 12/28/2010-12/27/2015: 10
# Total New Sites from "হয়েছে" on the_daily_jugantor in 12/27/2015-12/31/2015: 10
# Total New Sites from "হয়েছে" on the_daily_jugantor in 01/01/2016-02/20/2016: 9
# Total New Sites from "হয়েছে" on the_daily_jugantor in 02/20/2016-04/10/2016: 9
# Total New Sites from "হয়েছে" on the_daily_jugantor in 04/10/2016-05/30/2016: 10
# Total New Sites from "হয়েছে" on the_daily_jugantor in 05/30/2016-07/19/2016: 8
# Total New Sites from "হয়েছে" on the_daily_jugantor in 07/19/2016-09/07/2016: 10
# Total New Sites from "হয়েছে" on the_daily_jugantor in 09/07/2016-10/27/2016: 9
# Total New Sites from "হয়েছে" on the_daily_jugantor in 10/27/2016-12/16/2016: 10
# Total New Sites from "হয়েছে" on the_daily_jugantor in 12/16/2016-02/04/2017: 9
# Total New Sites from "হয়েছে" on the_daily_jugantor in 02/04/2017-03/26/2017: 8
# Total New Sites from "হয়েছে" on the_daily_jugantor in 03/26/2017-05/15/2017: 9
# Total New Sites from "হয়েছে" on the_daily_jugantor in 05/15/2017-07/04/2017: 10
# Total New Sites from "হয়েছে" on the_daily_jugantor in 07/04/2017-08/23/2017: 10
# Total New Sites from "হয়েছে" on the_daily_jugantor in 08/23/2017-10/12/2017: 9
# Total New Sites from "হয়েছে" on the_daily_jugantor in 10/12/2017-12/01/2017: 10
# Total New Sites from "হয়েছে" on the_daily_jugantor in 12/01/2017-01/20/2018: 8
# Total New Sites from "হয়েছে" on the_daily_jugantor in 01/20/2018-03/11/2018: 7
# Total New Sites from "হয়েছে" on the_daily_jugantor in 03/11/2018-04/30/2018: 10
# Total New Sites from "হয়েছে" on the_daily_jugantor in 04/30/2018-06/19/2018: 9
# Total New Sites from "হয়েছে" on the_daily_jugantor in 06/19/2018-08/08/2018: 10
# Total New Sites from "হয়েছে" on the_daily_jugantor in 08/08/2018-09/27/2018: 9
# Total New Sites from "হয়েছে" on the_daily_jugantor in 09/27/2018-11/16/2018: 8
# Total New Sites from "হয়েছে" on the_daily_jugantor in 11/16/2018-01/05/2019: 9
# Total New Sites from "হয়েছে" on the_daily_jugantor in 01/05/2019-02/24/2019: 9
# Total New Sites from "হয়েছে" on the_daily_jugantor in 02/24/2019-04/15/2019: 9
# Total New Sites from "হয়েছে" on the_daily_jugantor in 04/15/2019-06/04/2019: 8
# Total New Sites from "হয়েছে" on the_daily_jugantor in 06/04/2019-07/24/2019: 9
# Total New Sites from "হয়েছে" on the_daily_jugantor in 07/24/2019-09/12/2019: 10
# Total New Sites from "হয়েছে" on the_daily_jugantor in 09/12/2019-11/01/2019: 10
# Total New Sites from "হয়েছে" on the_daily_jugantor in 11/01/2019-12/21/2019: 8
# Total New Sites from "হয়েছে" on the_daily_jugantor in 12/21/2019-02/09/2020: 9
# Total New Sites from "হয়েছে" on the_daily_jugantor in 02/09/2020-03/30/2020: 8
# Total New Sites from "হয়েছে" on the_daily_jugantor in 03/30/2020-05/19/2020: 10
# Total New Sites from "হয়েছে" on the_daily_jugantor in 05/19/2020-07/08/2020: 9
# Total New Sites from "হয়েছে" on the_daily_jugantor in 07/08/2020-08/27/2020: 9
# Total New Sites from "হয়েছে" on the_daily_jugantor in 08/27/2020-10/16/2020: 10
# Total New Sites from "হয়েছে" on the_daily_jugantor in 10/16/2020-12/05/2020: 10
# Total New Sites from "হয়েছে" on the_daily_jugantor in 12/05/2020-01/24/2021: 8
# Total New Sites from "হয়েছে" on the_daily_jugantor in 01/24/2021-03/15/2021: 9
# Total New Sites from "হয়েছে" on the_daily_jugantor in 03/15/2021-05/04/2021: 7
# Total New Sites from "হয়েছে" on the_daily_jugantor in 05/04/2021-06/23/2021: 8
# Total New Sites from "হয়েছে" on the_daily_jugantor in 06/23/2021-08/12/2021: 8
# Total New Sites from "হয়েছে" on the_daily_jugantor in 08/12/2021-10/01/2021: 10
# Total New Sites from "হয়েছে" on the_daily_jugantor in 10/01/2021-11/20/2021: 8
# Total New Sites from "হয়েছে" on the_daily_jugantor in 11/20/2021-12/31/2021: 10
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 01/01/1996-12/30/2000: 7
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 12/30/2000-12/29/2005: 9
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 12/29/2005-12/28/2010: 8
# Executed 100/740 searches in 0:00:00.062598
# Total Sites: 947
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 12/28/2010-12/27/2015: 8
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 12/27/2015-12/31/2015: 7
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 01/01/2016-02/20/2016: 9
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 02/20/2016-04/10/2016: 10
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 04/10/2016-05/30/2016: 9
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 05/30/2016-07/19/2016: 10
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 07/19/2016-09/07/2016: 10
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 09/07/2016-10/27/2016: 8
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 10/27/2016-12/16/2016: 10
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 12/16/2016-02/04/2017: 9
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 02/04/2017-03/26/2017: 9
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 03/26/2017-05/15/2017: 7
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 05/15/2017-07/04/2017: 7
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 07/04/2017-08/23/2017: 9
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 08/23/2017-10/12/2017: 10
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 10/12/2017-12/01/2017: 8
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 12/01/2017-01/20/2018: 10
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 01/20/2018-03/11/2018: 8
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 03/11/2018-04/30/2018: 10
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 04/30/2018-06/19/2018: 8
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 06/19/2018-08/08/2018: 9
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 08/08/2018-09/27/2018: 8
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 09/27/2018-11/16/2018: 10
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 11/16/2018-01/05/2019: 8
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 01/05/2019-02/24/2019: 10
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 02/24/2019-04/15/2019: 10
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 04/15/2019-06/04/2019: 9
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 06/04/2019-07/24/2019: 6
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 07/24/2019-09/12/2019: 9
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 09/12/2019-11/01/2019: 10
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 11/01/2019-12/21/2019: 8
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 12/21/2019-02/09/2020: 9
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 02/09/2020-03/30/2020: 9
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 03/30/2020-05/19/2020: 7
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 05/19/2020-07/08/2020: 10
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 07/08/2020-08/27/2020: 7
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 08/27/2020-10/16/2020: 9
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 10/16/2020-12/05/2020: 7
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 12/05/2020-01/24/2021: 9
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 01/24/2021-03/15/2021: 9
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 03/15/2021-05/04/2021: 9
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 05/04/2021-06/23/2021: 10
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 06/23/2021-08/12/2021: 9
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 08/12/2021-10/01/2021: 9
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 10/01/2021-11/20/2021: 9
# Total New Sites from "হয়েছে" on the_daily_ittefaq in 11/20/2021-12/31/2021: 7
# Total New Sites from "হয়েছে" on amader_shomoy in 01/01/1996-12/30/2000: 9
# Total New Sites from "হয়েছে" on amader_shomoy in 12/30/2000-12/29/2005: 10
# Total New Sites from "হয়েছে" on amader_shomoy in 12/29/2005-12/28/2010: 8
# Total New Sites from "হয়েছে" on amader_shomoy in 12/28/2010-12/27/2015: 7
# Executed 150/740 searches in 0:00:00.093544
# Total Sites: 1383
# Total New Sites from "হয়েছে" on amader_shomoy in 12/27/2015-12/31/2015: 7
# Total New Sites from "হয়েছে" on amader_shomoy in 01/01/2016-02/20/2016: 6
# Total New Sites from "হয়েছে" on amader_shomoy in 02/20/2016-04/10/2016: 5
# Total New Sites from "হয়েছে" on amader_shomoy in 04/10/2016-05/30/2016: 9
# Total New Sites from "হয়েছে" on amader_shomoy in 05/30/2016-07/19/2016: 9
# Total New Sites from "হয়েছে" on amader_shomoy in 07/19/2016-09/07/2016: 8
# Total New Sites from "হয়েছে" on amader_shomoy in 09/07/2016-10/27/2016: 6
# Total New Sites from "হয়েছে" on amader_shomoy in 10/27/2016-12/16/2016: 9
# Total New Sites from "হয়েছে" on amader_shomoy in 12/16/2016-02/04/2017: 9
# Total New Sites from "হয়েছে" on amader_shomoy in 02/04/2017-03/26/2017: 9
# Total New Sites from "হয়েছে" on amader_shomoy in 03/26/2017-05/15/2017: 9
# Total New Sites from "হয়েছে" on amader_shomoy in 05/15/2017-07/04/2017: 9
# Total New Sites from "হয়েছে" on amader_shomoy in 07/04/2017-08/23/2017: 9
# Total New Sites from "হয়েছে" on amader_shomoy in 08/23/2017-10/12/2017: 8
# Total New Sites from "হয়েছে" on amader_shomoy in 10/12/2017-12/01/2017: 8
# Total New Sites from "হয়েছে" on amader_shomoy in 12/01/2017-01/20/2018: 8
# Total New Sites from "হয়েছে" on amader_shomoy in 01/20/2018-03/11/2018: 10
# Total New Sites from "হয়েছে" on amader_shomoy in 03/11/2018-04/30/2018: 10
# Total New Sites from "হয়েছে" on amader_shomoy in 04/30/2018-06/19/2018: 10
# Total New Sites from "হয়েছে" on amader_shomoy in 06/19/2018-08/08/2018: 6
# Total New Sites from "হয়েছে" on amader_shomoy in 08/08/2018-09/27/2018: 10
# Total New Sites from "হয়েছে" on amader_shomoy in 09/27/2018-11/16/2018: 8
# Total New Sites from "হয়েছে" on amader_shomoy in 11/16/2018-01/05/2019: 9
# Total New Sites from "হয়েছে" on amader_shomoy in 01/05/2019-02/24/2019: 9
# Total New Sites from "হয়েছে" on amader_shomoy in 02/24/2019-04/15/2019: 8
# Total New Sites from "হয়েছে" on amader_shomoy in 04/15/2019-06/04/2019: 7
# Total New Sites from "হয়েছে" on amader_shomoy in 06/04/2019-07/24/2019: 8
# Total New Sites from "হয়েছে" on amader_shomoy in 07/24/2019-09/12/2019: 7
# Total New Sites from "হয়েছে" on amader_shomoy in 09/12/2019-11/01/2019: 9
# Total New Sites from "হয়েছে" on amader_shomoy in 11/01/2019-12/21/2019: 9
# Total New Sites from "হয়েছে" on amader_shomoy in 12/21/2019-02/09/2020: 8
# Total New Sites from "হয়েছে" on amader_shomoy in 02/09/2020-03/30/2020: 9
# Total New Sites from "হয়েছে" on amader_shomoy in 03/30/2020-05/19/2020: 8
# Total New Sites from "হয়েছে" on amader_shomoy in 05/19/2020-07/08/2020: 8
# Total New Sites from "হয়েছে" on amader_shomoy in 07/08/2020-08/27/2020: 7
# Total New Sites from "হয়েছে" on amader_shomoy in 08/27/2020-10/16/2020: 6
# Total New Sites from "হয়েছে" on amader_shomoy in 10/16/2020-12/05/2020: 6
# Total New Sites from "হয়েছে" on amader_shomoy in 12/05/2020-01/24/2021: 6
# Total New Sites from "হয়েছে" on amader_shomoy in 01/24/2021-03/15/2021: 7
# Total New Sites from "হয়েছে" on amader_shomoy in 03/15/2021-05/04/2021: 8
# Total New Sites from "হয়েছে" on amader_shomoy in 05/04/2021-06/23/2021: 8
# Total New Sites from "হয়েছে" on amader_shomoy in 06/23/2021-08/12/2021: 10
# Total New Sites from "হয়েছে" on amader_shomoy in 08/12/2021-10/01/2021: 9
# Total New Sites from "হয়েছে" on amader_shomoy in 10/01/2021-11/20/2021: 8
# Total New Sites from "হয়েছে" on amader_shomoy in 11/20/2021-12/31/2021: 9
# Total New Sites from "হয়েছে" on bhorer_kagoj in 01/01/1996-12/30/2000: 8
# Total New Sites from "হয়েছে" on bhorer_kagoj in 12/30/2000-12/29/2005: 8
# Total New Sites from "হয়েছে" on bhorer_kagoj in 12/29/2005-12/28/2010: 7
# Total New Sites from "হয়েছে" on bhorer_kagoj in 12/28/2010-12/27/2015: 6
# Total New Sites from "হয়েছে" on bhorer_kagoj in 12/27/2015-12/31/2015: 8
# Executed 200/740 searches in 0:00:00.123618
# Total Sites: 1785
# Total New Sites from "হয়েছে" on bhorer_kagoj in 01/01/2016-02/20/2016: 7
# Total New Sites from "হয়েছে" on bhorer_kagoj in 02/20/2016-04/10/2016: 7
# Total New Sites from "হয়েছে" on bhorer_kagoj in 04/10/2016-05/30/2016: 8
# Total New Sites from "হয়েছে" on bhorer_kagoj in 05/30/2016-07/19/2016: 6
# Total New Sites from "হয়েছে" on bhorer_kagoj in 07/19/2016-09/07/2016: 8
# Total New Sites from "হয়েছে" on bhorer_kagoj in 09/07/2016-10/27/2016: 7
# Total New Sites from "হয়েছে" on bhorer_kagoj in 10/27/2016-12/16/2016: 10
# Total New Sites from "হয়েছে" on bhorer_kagoj in 12/16/2016-02/04/2017: 6
# Total New Sites from "হয়েছে" on bhorer_kagoj in 02/04/2017-03/26/2017: 5
# Total New Sites from "হয়েছে" on bhorer_kagoj in 03/26/2017-05/15/2017: 7
# Total New Sites from "হয়েছে" on bhorer_kagoj in 05/15/2017-07/04/2017: 7
# Total New Sites from "হয়েছে" on bhorer_kagoj in 07/04/2017-08/23/2017: 9
# Total New Sites from "হয়েছে" on bhorer_kagoj in 08/23/2017-10/12/2017: 10
# Total New Sites from "হয়েছে" on bhorer_kagoj in 10/12/2017-12/01/2017: 9
# Total New Sites from "হয়েছে" on bhorer_kagoj in 12/01/2017-01/20/2018: 9
# Total New Sites from "হয়েছে" on bhorer_kagoj in 01/20/2018-03/11/2018: 8
# Total New Sites from "হয়েছে" on bhorer_kagoj in 03/11/2018-04/30/2018: 5
# Total New Sites from "হয়েছে" on bhorer_kagoj in 04/30/2018-06/19/2018: 6
# Total New Sites from "হয়েছে" on bhorer_kagoj in 06/19/2018-08/08/2018: 8
# Total New Sites from "হয়েছে" on bhorer_kagoj in 08/08/2018-09/27/2018: 9
# Total New Sites from "হয়েছে" on bhorer_kagoj in 09/27/2018-11/16/2018: 6
# Total New Sites from "হয়েছে" on bhorer_kagoj in 11/16/2018-01/05/2019: 6
# Total New Sites from "হয়েছে" on bhorer_kagoj in 01/05/2019-02/24/2019: 10
# Total New Sites from "হয়েছে" on bhorer_kagoj in 02/24/2019-04/15/2019: 5
# Total New Sites from "হয়েছে" on bhorer_kagoj in 04/15/2019-06/04/2019: 9
# Total New Sites from "হয়েছে" on bhorer_kagoj in 06/04/2019-07/24/2019: 7
# Total New Sites from "হয়েছে" on bhorer_kagoj in 07/24/2019-09/12/2019: 10
# Total New Sites from "হয়েছে" on bhorer_kagoj in 09/12/2019-11/01/2019: 6
# Total New Sites from "হয়েছে" on bhorer_kagoj in 11/01/2019-12/21/2019: 6
# Total New Sites from "হয়েছে" on bhorer_kagoj in 12/21/2019-02/09/2020: 9
# Total New Sites from "হয়েছে" on bhorer_kagoj in 02/09/2020-03/30/2020: 6
# Total New Sites from "হয়েছে" on bhorer_kagoj in 03/30/2020-05/19/2020: 7
# Total New Sites from "হয়েছে" on bhorer_kagoj in 05/19/2020-07/08/2020: 8
# Total New Sites from "হয়েছে" on bhorer_kagoj in 07/08/2020-08/27/2020: 8
# Total New Sites from "হয়েছে" on bhorer_kagoj in 08/27/2020-10/16/2020: 8
# Total New Sites from "হয়েছে" on bhorer_kagoj in 10/16/2020-12/05/2020: 6
# Total New Sites from "হয়েছে" on bhorer_kagoj in 12/05/2020-01/24/2021: 6
# Total New Sites from "হয়েছে" on bhorer_kagoj in 01/24/2021-03/15/2021: 8
# Total New Sites from "হয়েছে" on bhorer_kagoj in 03/15/2021-05/04/2021: 5
# Total New Sites from "হয়েছে" on bhorer_kagoj in 05/04/2021-06/23/2021: 6
# Total New Sites from "হয়েছে" on bhorer_kagoj in 06/23/2021-08/12/2021: 8
# Total New Sites from "হয়েছে" on bhorer_kagoj in 08/12/2021-10/01/2021: 7
# Total New Sites from "হয়েছে" on bhorer_kagoj in 10/01/2021-11/20/2021: 6
# Total New Sites from "হয়েছে" on bhorer_kagoj in 11/20/2021-12/31/2021: 6
# Total New Sites from "হয়েছে" on daily_manab_zamin in 01/01/1996-12/30/2000: 8
# Total New Sites from "হয়েছে" on daily_manab_zamin in 12/30/2000-12/29/2005: 8
# Total New Sites from "হয়েছে" on daily_manab_zamin in 12/29/2005-12/28/2010: 8
# Total New Sites from "হয়েছে" on daily_manab_zamin in 12/28/2010-12/27/2015: 7
# Total New Sites from "হয়েছে" on daily_manab_zamin in 12/27/2015-12/31/2015: 7
# Total New Sites from "হয়েছে" on daily_manab_zamin in 01/01/2016-02/20/2016: 9
# Executed 250/740 searches in 0:00:00.153425
# Total Sites: 2152
# Total New Sites from "হয়েছে" on daily_manab_zamin in 02/20/2016-04/10/2016: 6
# Total New Sites from "হয়েছে" on daily_manab_zamin in 04/10/2016-05/30/2016: 7
# Total New Sites from "হয়েছে" on daily_manab_zamin in 05/30/2016-07/19/2016: 9
# Total New Sites from "হয়েছে" on daily_manab_zamin in 07/19/2016-09/07/2016: 9
# Total New Sites from "হয়েছে" on daily_manab_zamin in 09/07/2016-10/27/2016: 8
# Total New Sites from "হয়েছে" on daily_manab_zamin in 10/27/2016-12/16/2016: 5
# Total New Sites from "হয়েছে" on daily_manab_zamin in 12/16/2016-02/04/2017: 5
# Total New Sites from "হয়েছে" on daily_manab_zamin in 02/04/2017-03/26/2017: 7
# Total New Sites from "হয়েছে" on daily_manab_zamin in 03/26/2017-05/15/2017: 8
# Total New Sites from "হয়েছে" on daily_manab_zamin in 05/15/2017-07/04/2017: 9
# Total New Sites from "হয়েছে" on daily_manab_zamin in 07/04/2017-08/23/2017: 8
# Total New Sites from "হয়েছে" on daily_manab_zamin in 08/23/2017-10/12/2017: 8
# Total New Sites from "হয়েছে" on daily_manab_zamin in 10/12/2017-12/01/2017: 6
# Total New Sites from "হয়েছে" on daily_manab_zamin in 12/01/2017-01/20/2018: 6
# Total New Sites from "হয়েছে" on daily_manab_zamin in 01/20/2018-03/11/2018: 6
# Total New Sites from "হয়েছে" on daily_manab_zamin in 03/11/2018-04/30/2018: 7
# Total New Sites from "হয়েছে" on daily_manab_zamin in 04/30/2018-06/19/2018: 8
# Total New Sites from "হয়েছে" on daily_manab_zamin in 06/19/2018-08/08/2018: 9
# Total New Sites from "হয়েছে" on daily_manab_zamin in 08/08/2018-09/27/2018: 7
# Total New Sites from "হয়েছে" on daily_manab_zamin in 09/27/2018-11/16/2018: 7
# Total New Sites from "হয়েছে" on daily_manab_zamin in 11/16/2018-01/05/2019: 6
# Total New Sites from "হয়েছে" on daily_manab_zamin in 01/05/2019-02/24/2019: 10
# Total New Sites from "হয়েছে" on daily_manab_zamin in 02/24/2019-04/15/2019: 7
# Total New Sites from "হয়েছে" on daily_manab_zamin in 04/15/2019-06/04/2019: 7
# Total New Sites from "হয়েছে" on daily_manab_zamin in 06/04/2019-07/24/2019: 6
# Total New Sites from "হয়েছে" on daily_manab_zamin in 07/24/2019-09/12/2019: 8
# Total New Sites from "হয়েছে" on daily_manab_zamin in 09/12/2019-11/01/2019: 7
# Total New Sites from "হয়েছে" on daily_manab_zamin in 11/01/2019-12/21/2019: 6
# Total New Sites from "হয়েছে" on daily_manab_zamin in 12/21/2019-02/09/2020: 6
# Total New Sites from "হয়েছে" on daily_manab_zamin in 02/09/2020-03/30/2020: 6
# Total New Sites from "হয়েছে" on daily_manab_zamin in 03/30/2020-05/19/2020: 8
# Total New Sites from "হয়েছে" on daily_manab_zamin in 05/19/2020-07/08/2020: 8
# Total New Sites from "হয়েছে" on daily_manab_zamin in 07/08/2020-08/27/2020: 8
# Total New Sites from "হয়েছে" on daily_manab_zamin in 08/27/2020-10/16/2020: 6
# Total New Sites from "হয়েছে" on daily_manab_zamin in 10/16/2020-12/05/2020: 7
# Total New Sites from "হয়েছে" on daily_manab_zamin in 12/05/2020-01/24/2021: 6
# Total New Sites from "হয়েছে" on daily_manab_zamin in 01/24/2021-03/15/2021: 9
# Total New Sites from "হয়েছে" on daily_manab_zamin in 03/15/2021-05/04/2021: 5
# Total New Sites from "হয়েছে" on daily_manab_zamin in 05/04/2021-06/23/2021: 8
# Total New Sites from "হয়েছে" on daily_manab_zamin in 06/23/2021-08/12/2021: 8
# Total New Sites from "হয়েছে" on daily_manab_zamin in 08/12/2021-10/01/2021: 5
# Total New Sites from "হয়েছে" on daily_manab_zamin in 10/01/2021-11/20/2021: 8
# Total New Sites from "হয়েছে" on daily_manab_zamin in 11/20/2021-12/31/2021: 9
# Total New Sites from "হয়েছে" on alokito_bangladesh in 01/01/1996-12/30/2000: 5
# Total New Sites from "হয়েছে" on alokito_bangladesh in 12/30/2000-12/29/2005: 10
# Total New Sites from "হয়েছে" on alokito_bangladesh in 12/29/2005-12/28/2010: 9
# Total New Sites from "হয়েছে" on alokito_bangladesh in 12/28/2010-12/27/2015: 7
# Total New Sites from "হয়েছে" on alokito_bangladesh in 12/27/2015-12/31/2015: 8
# Total New Sites from "হয়েছে" on alokito_bangladesh in 01/01/2016-02/20/2016: 5
# Total New Sites from "হয়েছে" on alokito_bangladesh in 02/20/2016-04/10/2016: 7
# Executed 300/740 searches in 0:00:00.183747
# Total Sites: 2512
# Total New Sites from "হয়েছে" on alokito_bangladesh in 04/10/2016-05/30/2016: 7
# Total New Sites from "হয়েছে" on alokito_bangladesh in 05/30/2016-07/19/2016: 7
# Total New Sites from "হয়েছে" on alokito_bangladesh in 07/19/2016-09/07/2016: 6
# Total New Sites from "হয়েছে" on alokito_bangladesh in 09/07/2016-10/27/2016: 5
# Total New Sites from "হয়েছে" on alokito_bangladesh in 10/27/2016-12/16/2016: 10
# Total New Sites from "হয়েছে" on alokito_bangladesh in 12/16/2016-02/04/2017: 7
# Total New Sites from "হয়েছে" on alokito_bangladesh in 02/04/2017-03/26/2017: 8
# Total New Sites from "হয়েছে" on alokito_bangladesh in 03/26/2017-05/15/2017: 9
# Total New Sites from "হয়েছে" on alokito_bangladesh in 05/15/2017-07/04/2017: 10
# Total New Sites from "হয়েছে" on alokito_bangladesh in 07/04/2017-08/23/2017: 7
# Total New Sites from "হয়েছে" on alokito_bangladesh in 08/23/2017-10/12/2017: 6
# Total New Sites from "হয়েছে" on alokito_bangladesh in 10/12/2017-12/01/2017: 9
# Total New Sites from "হয়েছে" on alokito_bangladesh in 12/01/2017-01/20/2018: 7
# Total New Sites from "হয়েছে" on alokito_bangladesh in 01/20/2018-03/11/2018: 6
# Total New Sites from "হয়েছে" on alokito_bangladesh in 03/11/2018-04/30/2018: 5
# Total New Sites from "হয়েছে" on alokito_bangladesh in 04/30/2018-06/19/2018: 7
# Total New Sites from "হয়েছে" on alokito_bangladesh in 06/19/2018-08/08/2018: 7
# Total New Sites from "হয়েছে" on alokito_bangladesh in 08/08/2018-09/27/2018: 7
# Total New Sites from "হয়েছে" on alokito_bangladesh in 09/27/2018-11/16/2018: 5
# Total New Sites from "হয়েছে" on alokito_bangladesh in 11/16/2018-01/05/2019: 8
# Total New Sites from "হয়েছে" on alokito_bangladesh in 01/05/2019-02/24/2019: 9
# Total New Sites from "হয়েছে" on alokito_bangladesh in 02/24/2019-04/15/2019: 9
# Total New Sites from "হয়েছে" on alokito_bangladesh in 04/15/2019-06/04/2019: 5
# Total New Sites from "হয়েছে" on alokito_bangladesh in 06/04/2019-07/24/2019: 7
# Total New Sites from "হয়েছে" on alokito_bangladesh in 07/24/2019-09/12/2019: 5
# Total New Sites from "হয়েছে" on alokito_bangladesh in 09/12/2019-11/01/2019: 8
# Total New Sites from "হয়েছে" on alokito_bangladesh in 11/01/2019-12/21/2019: 6
# Total New Sites from "হয়েছে" on alokito_bangladesh in 12/21/2019-02/09/2020: 7
# Total New Sites from "হয়েছে" on alokito_bangladesh in 02/09/2020-03/30/2020: 7
# Total New Sites from "হয়েছে" on alokito_bangladesh in 03/30/2020-05/19/2020: 8
# Total New Sites from "হয়েছে" on alokito_bangladesh in 05/19/2020-07/08/2020: 7
# Total New Sites from "হয়েছে" on alokito_bangladesh in 07/08/2020-08/27/2020: 7
# Total New Sites from "হয়েছে" on alokito_bangladesh in 08/27/2020-10/16/2020: 7
# Total New Sites from "হয়েছে" on alokito_bangladesh in 10/16/2020-12/05/2020: 8
# Total New Sites from "হয়েছে" on alokito_bangladesh in 12/05/2020-01/24/2021: 9
# Total New Sites from "হয়েছে" on alokito_bangladesh in 01/24/2021-03/15/2021: 7
# Total New Sites from "হয়েছে" on alokito_bangladesh in 03/15/2021-05/04/2021: 6
# Total New Sites from "হয়েছে" on alokito_bangladesh in 05/04/2021-06/23/2021: 8
# Total New Sites from "হয়েছে" on alokito_bangladesh in 06/23/2021-08/12/2021: 4
# Total New Sites from "হয়েছে" on alokito_bangladesh in 08/12/2021-10/01/2021: 6
# Total New Sites from "হয়েছে" on alokito_bangladesh in 10/01/2021-11/20/2021: 4
# Total New Sites from "হয়েছে" on alokito_bangladesh in 11/20/2021-12/31/2021: 4
# Total New Sites from "হয়েছে" on the_sangbad in 01/01/1996-12/30/2000: 7
# Total New Sites from "হয়েছে" on the_sangbad in 12/30/2000-12/29/2005: 6
# Total New Sites from "হয়েছে" on the_sangbad in 12/29/2005-12/28/2010: 6
# Total New Sites from "হয়েছে" on the_sangbad in 12/28/2010-12/27/2015: 5
# Total New Sites from "হয়েছে" on the_sangbad in 12/27/2015-12/31/2015: 6
# Total New Sites from "হয়েছে" on the_sangbad in 01/01/2016-02/20/2016: 6
# Total New Sites from "হয়েছে" on the_sangbad in 02/20/2016-04/10/2016: 7
# Total New Sites from "হয়েছে" on the_sangbad in 04/10/2016-05/30/2016: 6
# Executed 350/740 searches in 0:00:00.213942
# Total Sites: 2852
# Total New Sites from "হয়েছে" on the_sangbad in 05/30/2016-07/19/2016: 5
# Total New Sites from "হয়েছে" on the_sangbad in 07/19/2016-09/07/2016: 6
# Total New Sites from "হয়েছে" on the_sangbad in 09/07/2016-10/27/2016: 6
# Total New Sites from "হয়েছে" on the_sangbad in 10/27/2016-12/16/2016: 8
# Total New Sites from "হয়েছে" on the_sangbad in 12/16/2016-02/04/2017: 5
# Total New Sites from "হয়েছে" on the_sangbad in 02/04/2017-03/26/2017: 6
# Total New Sites from "হয়েছে" on the_sangbad in 03/26/2017-05/15/2017: 9
# Total New Sites from "হয়েছে" on the_sangbad in 05/15/2017-07/04/2017: 6
# Total New Sites from "হয়েছে" on the_sangbad in 07/04/2017-08/23/2017: 5
# Total New Sites from "হয়েছে" on the_sangbad in 08/23/2017-10/12/2017: 7
# Total New Sites from "হয়েছে" on the_sangbad in 10/12/2017-12/01/2017: 7
# Total New Sites from "হয়েছে" on the_sangbad in 12/01/2017-01/20/2018: 5
# Total New Sites from "হয়েছে" on the_sangbad in 01/20/2018-03/11/2018: 5
# Total New Sites from "হয়েছে" on the_sangbad in 03/11/2018-04/30/2018: 8
# Total New Sites from "হয়েছে" on the_sangbad in 04/30/2018-06/19/2018: 9
# Total New Sites from "হয়েছে" on the_sangbad in 06/19/2018-08/08/2018: 4
# Total New Sites from "হয়েছে" on the_sangbad in 08/08/2018-09/27/2018: 6
# Total New Sites from "হয়েছে" on the_sangbad in 09/27/2018-11/16/2018: 5
# Total New Sites from "হয়েছে" on the_sangbad in 11/16/2018-01/05/2019: 6
# Total New Sites from "হয়েছে" on the_sangbad in 01/05/2019-02/24/2019: 8
# Total New Sites from "হয়েছে" on the_sangbad in 02/24/2019-04/15/2019: 4
# Total New Sites from "হয়েছে" on the_sangbad in 04/15/2019-06/04/2019: 9
# Total New Sites from "হয়েছে" on the_sangbad in 06/04/2019-07/24/2019: 7
# Total New Sites from "হয়েছে" on the_sangbad in 07/24/2019-09/12/2019: 5
# Total New Sites from "হয়েছে" on the_sangbad in 09/12/2019-11/01/2019: 6
# Total New Sites from "হয়েছে" on the_sangbad in 11/01/2019-12/21/2019: 7
# Total New Sites from "হয়েছে" on the_sangbad in 12/21/2019-02/09/2020: 7
# Total New Sites from "হয়েছে" on the_sangbad in 02/09/2020-03/30/2020: 7
# Total New Sites from "হয়েছে" on the_sangbad in 03/30/2020-05/19/2020: 6
# Total New Sites from "হয়েছে" on the_sangbad in 05/19/2020-07/08/2020: 7
# Total New Sites from "হয়েছে" on the_sangbad in 07/08/2020-08/27/2020: 7
# Total New Sites from "হয়েছে" on the_sangbad in 08/27/2020-10/16/2020: 7
# Total New Sites from "হয়েছে" on the_sangbad in 10/16/2020-12/05/2020: 5
# Total New Sites from "হয়েছে" on the_sangbad in 12/05/2020-01/24/2021: 8
# Total New Sites from "হয়েছে" on the_sangbad in 01/24/2021-03/15/2021: 9
# Total New Sites from "হয়েছে" on the_sangbad in 03/15/2021-05/04/2021: 5
# Total New Sites from "হয়েছে" on the_sangbad in 05/04/2021-06/23/2021: 7
# Total New Sites from "হয়েছে" on the_sangbad in 06/23/2021-08/12/2021: 5
# Total New Sites from "হয়েছে" on the_sangbad in 08/12/2021-10/01/2021: 6
# Total New Sites from "হয়েছে" on the_sangbad in 10/01/2021-11/20/2021: 7
# Total New Sites from "হয়েছে" on the_sangbad in 11/20/2021-12/31/2021: 7
# Total New Sites from "হয়েছে" on the_daily_inqilab in 01/01/1996-12/30/2000: 9
# Total New Sites from "হয়েছে" on the_daily_inqilab in 12/30/2000-12/29/2005: 5
# Total New Sites from "হয়েছে" on the_daily_inqilab in 12/29/2005-12/28/2010: 8
# Total New Sites from "হয়েছে" on the_daily_inqilab in 12/28/2010-12/27/2015: 5
# Total New Sites from "হয়েছে" on the_daily_inqilab in 12/27/2015-12/31/2015: 7
# Total New Sites from "হয়েছে" on the_daily_inqilab in 01/01/2016-02/20/2016: 7
# Total New Sites from "হয়েছে" on the_daily_inqilab in 02/20/2016-04/10/2016: 5
# Total New Sites from "হয়েছে" on the_daily_inqilab in 04/10/2016-05/30/2016: 6
# Total New Sites from "হয়েছে" on the_daily_inqilab in 05/30/2016-07/19/2016: 8
# Executed 400/740 searches in 0:00:00.242123
# Total Sites: 3176
# Total New Sites from "হয়েছে" on the_daily_inqilab in 07/19/2016-09/07/2016: 7
# Total New Sites from "হয়েছে" on the_daily_inqilab in 09/07/2016-10/27/2016: 7
# Total New Sites from "হয়েছে" on the_daily_inqilab in 10/27/2016-12/16/2016: 6
# Total New Sites from "হয়েছে" on the_daily_inqilab in 12/16/2016-02/04/2017: 5
# Total New Sites from "হয়েছে" on the_daily_inqilab in 02/04/2017-03/26/2017: 6
# Total New Sites from "হয়েছে" on the_daily_inqilab in 03/26/2017-05/15/2017: 4
# Total New Sites from "হয়েছে" on the_daily_inqilab in 05/15/2017-07/04/2017: 5
# Total New Sites from "হয়েছে" on the_daily_inqilab in 07/04/2017-08/23/2017: 5
# Total New Sites from "হয়েছে" on the_daily_inqilab in 08/23/2017-10/12/2017: 8
# Total New Sites from "হয়েছে" on the_daily_inqilab in 10/12/2017-12/01/2017: 7
# Total New Sites from "হয়েছে" on the_daily_inqilab in 12/01/2017-01/20/2018: 7
# Total New Sites from "হয়েছে" on the_daily_inqilab in 01/20/2018-03/11/2018: 4
# Total New Sites from "হয়েছে" on the_daily_inqilab in 03/11/2018-04/30/2018: 8
# Total New Sites from "হয়েছে" on the_daily_inqilab in 04/30/2018-06/19/2018: 4
# Total New Sites from "হয়েছে" on the_daily_inqilab in 06/19/2018-08/08/2018: 6
# Total New Sites from "হয়েছে" on the_daily_inqilab in 08/08/2018-09/27/2018: 8
# Total New Sites from "হয়েছে" on the_daily_inqilab in 09/27/2018-11/16/2018: 8
# Total New Sites from "হয়েছে" on the_daily_inqilab in 11/16/2018-01/05/2019: 9
# Total New Sites from "হয়েছে" on the_daily_inqilab in 01/05/2019-02/24/2019: 7
# Total New Sites from "হয়েছে" on the_daily_inqilab in 02/24/2019-04/15/2019: 5
# Total New Sites from "হয়েছে" on the_daily_inqilab in 04/15/2019-06/04/2019: 5
# Total New Sites from "হয়েছে" on the_daily_inqilab in 06/04/2019-07/24/2019: 7
# Total New Sites from "হয়েছে" on the_daily_inqilab in 07/24/2019-09/12/2019: 6
# Total New Sites from "হয়েছে" on the_daily_inqilab in 09/12/2019-11/01/2019: 6
# Total New Sites from "হয়েছে" on the_daily_inqilab in 11/01/2019-12/21/2019: 6
# Total New Sites from "হয়েছে" on the_daily_inqilab in 12/21/2019-02/09/2020: 10
# Total New Sites from "হয়েছে" on the_daily_inqilab in 02/09/2020-03/30/2020: 4
# Total New Sites from "হয়েছে" on the_daily_inqilab in 03/30/2020-05/19/2020: 5
# Total New Sites from "হয়েছে" on the_daily_inqilab in 05/19/2020-07/08/2020: 8
# Total New Sites from "হয়েছে" on the_daily_inqilab in 07/08/2020-08/27/2020: 8
# Total New Sites from "হয়েছে" on the_daily_inqilab in 08/27/2020-10/16/2020: 5
# Total New Sites from "হয়েছে" on the_daily_inqilab in 10/16/2020-12/05/2020: 8
# Total New Sites from "হয়েছে" on the_daily_inqilab in 12/05/2020-01/24/2021: 6
# Total New Sites from "হয়েছে" on the_daily_inqilab in 01/24/2021-03/15/2021: 6
# Total New Sites from "হয়েছে" on the_daily_inqilab in 03/15/2021-05/04/2021: 7
# Total New Sites from "হয়েছে" on the_daily_inqilab in 05/04/2021-06/23/2021: 6
# Total New Sites from "হয়েছে" on the_daily_inqilab in 06/23/2021-08/12/2021: 7
# Total New Sites from "হয়েছে" on the_daily_inqilab in 08/12/2021-10/01/2021: 5
# Total New Sites from "হয়েছে" on the_daily_inqilab in 10/01/2021-11/20/2021: 6
# Total New Sites from "হয়েছে" on the_daily_inqilab in 11/20/2021-12/31/2021: 8
# Total New Sites from "হয়েছে" on jaijaidin in 01/01/1996-12/30/2000: 8
# Total New Sites from "হয়েছে" on jaijaidin in 12/30/2000-12/29/2005: 5
# Total New Sites from "হয়েছে" on jaijaidin in 12/29/2005-12/28/2010: 8
# Total New Sites from "হয়েছে" on jaijaidin in 12/28/2010-12/27/2015: 8
# Total New Sites from "হয়েছে" on jaijaidin in 12/27/2015-12/31/2015: 6
# Total New Sites from "হয়েছে" on jaijaidin in 01/01/2016-02/20/2016: 9
# Total New Sites from "হয়েছে" on jaijaidin in 02/20/2016-04/10/2016: 7
# Total New Sites from "হয়েছে" on jaijaidin in 04/10/2016-05/30/2016: 8
# Total New Sites from "হয়েছে" on jaijaidin in 05/30/2016-07/19/2016: 10
# Total New Sites from "হয়েছে" on jaijaidin in 07/19/2016-09/07/2016: 5
# Executed 450/740 searches in 0:00:00.271935
# Total Sites: 3505
# Total New Sites from "হয়েছে" on jaijaidin in 09/07/2016-10/27/2016: 6
# Total New Sites from "হয়েছে" on jaijaidin in 10/27/2016-12/16/2016: 10
# Total New Sites from "হয়েছে" on jaijaidin in 12/16/2016-02/04/2017: 6
# Total New Sites from "হয়েছে" on jaijaidin in 02/04/2017-03/26/2017: 7
# Total New Sites from "হয়েছে" on jaijaidin in 03/26/2017-05/15/2017: 7
# Total New Sites from "হয়েছে" on jaijaidin in 05/15/2017-07/04/2017: 2
# Total New Sites from "হয়েছে" on jaijaidin in 07/04/2017-08/23/2017: 6
# Total New Sites from "হয়েছে" on jaijaidin in 08/23/2017-10/12/2017: 4
# Total New Sites from "হয়েছে" on jaijaidin in 10/12/2017-12/01/2017: 5
# Total New Sites from "হয়েছে" on jaijaidin in 12/01/2017-01/20/2018: 8
# Total New Sites from "হয়েছে" on jaijaidin in 01/20/2018-03/11/2018: 7
# Total New Sites from "হয়েছে" on jaijaidin in 03/11/2018-04/30/2018: 4
# Total New Sites from "হয়েছে" on jaijaidin in 04/30/2018-06/19/2018: 6
# Total New Sites from "হয়েছে" on jaijaidin in 06/19/2018-08/08/2018: 6
# Total New Sites from "হয়েছে" on jaijaidin in 08/08/2018-09/27/2018: 9
# Total New Sites from "হয়েছে" on jaijaidin in 09/27/2018-11/16/2018: 7
# Total New Sites from "হয়েছে" on jaijaidin in 11/16/2018-01/05/2019: 6
# Total New Sites from "হয়েছে" on jaijaidin in 01/05/2019-02/24/2019: 4
# Total New Sites from "হয়েছে" on jaijaidin in 02/24/2019-04/15/2019: 4
# Total New Sites from "হয়েছে" on jaijaidin in 04/15/2019-06/04/2019: 7
# Total New Sites from "হয়েছে" on jaijaidin in 06/04/2019-07/24/2019: 3
# Total New Sites from "হয়েছে" on jaijaidin in 07/24/2019-09/12/2019: 6
# Total New Sites from "হয়েছে" on jaijaidin in 09/12/2019-11/01/2019: 7
# Total New Sites from "হয়েছে" on jaijaidin in 11/01/2019-12/21/2019: 1
# Total New Sites from "হয়েছে" on jaijaidin in 12/21/2019-02/09/2020: 8
# Total New Sites from "হয়েছে" on jaijaidin in 02/09/2020-03/30/2020: 4
# Total New Sites from "হয়েছে" on jaijaidin in 03/30/2020-05/19/2020: 9
# Total New Sites from "হয়েছে" on jaijaidin in 05/19/2020-07/08/2020: 5
# Total New Sites from "হয়েছে" on jaijaidin in 07/08/2020-08/27/2020: 6
# Total New Sites from "হয়েছে" on jaijaidin in 08/27/2020-10/16/2020: 7
# Total New Sites from "হয়েছে" on jaijaidin in 10/16/2020-12/05/2020: 4
# Total New Sites from "হয়েছে" on jaijaidin in 12/05/2020-01/24/2021: 4
# Total New Sites from "হয়েছে" on jaijaidin in 01/24/2021-03/15/2021: 8
# Total New Sites from "হয়েছে" on jaijaidin in 03/15/2021-05/04/2021: 3
# Total New Sites from "হয়েছে" on jaijaidin in 05/04/2021-06/23/2021: 6
# Total New Sites from "হয়েছে" on jaijaidin in 06/23/2021-08/12/2021: 8
# Total New Sites from "হয়েছে" on jaijaidin in 08/12/2021-10/01/2021: 4
# Total New Sites from "হয়েছে" on jaijaidin in 10/01/2021-11/20/2021: 8
# Total New Sites from "হয়েছে" on jaijaidin in 11/20/2021-12/31/2021: 5
# Total New Sites from "হয়েছে" on daily_naya_diganta in 01/01/1996-12/30/2000: 7
# Total New Sites from "হয়েছে" on daily_naya_diganta in 12/30/2000-12/29/2005: 6
# Total New Sites from "হয়েছে" on daily_naya_diganta in 12/29/2005-12/28/2010: 7
# Total New Sites from "হয়েছে" on daily_naya_diganta in 12/28/2010-12/27/2015: 7
# Total New Sites from "হয়েছে" on daily_naya_diganta in 12/27/2015-12/31/2015: 7
# Total New Sites from "হয়েছে" on daily_naya_diganta in 01/01/2016-02/20/2016: 4
# Total New Sites from "হয়েছে" on daily_naya_diganta in 02/20/2016-04/10/2016: 4
# Total New Sites from "হয়েছে" on daily_naya_diganta in 04/10/2016-05/30/2016: 7
# Total New Sites from "হয়েছে" on daily_naya_diganta in 05/30/2016-07/19/2016: 6
# Total New Sites from "হয়েছে" on daily_naya_diganta in 07/19/2016-09/07/2016: 6
# Total New Sites from "হয়েছে" on daily_naya_diganta in 09/07/2016-10/27/2016: 8
# Executed 500/740 searches in 0:00:00.300524
# Total Sites: 3801
# Total New Sites from "হয়েছে" on daily_naya_diganta in 10/27/2016-12/16/2016: 3
# Total New Sites from "হয়েছে" on daily_naya_diganta in 12/16/2016-02/04/2017: 6
# Total New Sites from "হয়েছে" on daily_naya_diganta in 02/04/2017-03/26/2017: 5
# Total New Sites from "হয়েছে" on daily_naya_diganta in 03/26/2017-05/15/2017: 6
# Total New Sites from "হয়েছে" on daily_naya_diganta in 05/15/2017-07/04/2017: 6
# Total New Sites from "হয়েছে" on daily_naya_diganta in 07/04/2017-08/23/2017: 7
# Total New Sites from "হয়েছে" on daily_naya_diganta in 08/23/2017-10/12/2017: 3
# Total New Sites from "হয়েছে" on daily_naya_diganta in 10/12/2017-12/01/2017: 6
# Total New Sites from "হয়েছে" on daily_naya_diganta in 12/01/2017-01/20/2018: 6
# Total New Sites from "হয়েছে" on daily_naya_diganta in 01/20/2018-03/11/2018: 4
# Total New Sites from "হয়েছে" on daily_naya_diganta in 03/11/2018-04/30/2018: 7
# Total New Sites from "হয়েছে" on daily_naya_diganta in 04/30/2018-06/19/2018: 7
# Total New Sites from "হয়েছে" on daily_naya_diganta in 06/19/2018-08/08/2018: 6
# Total New Sites from "হয়েছে" on daily_naya_diganta in 08/08/2018-09/27/2018: 5
# Total New Sites from "হয়েছে" on daily_naya_diganta in 09/27/2018-11/16/2018: 4
# Total New Sites from "হয়েছে" on daily_naya_diganta in 11/16/2018-01/05/2019: 5
# Total New Sites from "হয়েছে" on daily_naya_diganta in 01/05/2019-02/24/2019: 4
# Total New Sites from "হয়েছে" on daily_naya_diganta in 02/24/2019-04/15/2019: 2
# Total New Sites from "হয়েছে" on daily_naya_diganta in 04/15/2019-06/04/2019: 3
# Total New Sites from "হয়েছে" on daily_naya_diganta in 06/04/2019-07/24/2019: 7
# Total New Sites from "হয়েছে" on daily_naya_diganta in 07/24/2019-09/12/2019: 3
# Total New Sites from "হয়েছে" on daily_naya_diganta in 09/12/2019-11/01/2019: 3
# Total New Sites from "হয়েছে" on daily_naya_diganta in 11/01/2019-12/21/2019: 5
# Total New Sites from "হয়েছে" on daily_naya_diganta in 12/21/2019-02/09/2020: 4
# Total New Sites from "হয়েছে" on daily_naya_diganta in 02/09/2020-03/30/2020: 7
# Total New Sites from "হয়েছে" on daily_naya_diganta in 03/30/2020-05/19/2020: 7
# Total New Sites from "হয়েছে" on daily_naya_diganta in 05/19/2020-07/08/2020: 3
# Total New Sites from "হয়েছে" on daily_naya_diganta in 07/08/2020-08/27/2020: 6
# Total New Sites from "হয়েছে" on daily_naya_diganta in 08/27/2020-10/16/2020: 5
# Total New Sites from "হয়েছে" on daily_naya_diganta in 10/16/2020-12/05/2020: 6
# Total New Sites from "হয়েছে" on daily_naya_diganta in 12/05/2020-01/24/2021: 5
# Total New Sites from "হয়েছে" on daily_naya_diganta in 01/24/2021-03/15/2021: 5
# Total New Sites from "হয়েছে" on daily_naya_diganta in 03/15/2021-05/04/2021: 2
# Total New Sites from "হয়েছে" on daily_naya_diganta in 05/04/2021-06/23/2021: 5
# Total New Sites from "হয়েছে" on daily_naya_diganta in 06/23/2021-08/12/2021: 9
# Total New Sites from "হয়েছে" on daily_naya_diganta in 08/12/2021-10/01/2021: 7
# Total New Sites from "হয়েছে" on daily_naya_diganta in 10/01/2021-11/20/2021: 5
# Total New Sites from "হয়েছে" on daily_naya_diganta in 11/20/2021-12/31/2021: 7
# Total New Sites from "হয়েছে" on the_azadi in 01/01/1996-12/30/2000: 6
# Total New Sites from "হয়েছে" on the_azadi in 12/30/2000-12/29/2005: 6
# Total New Sites from "হয়েছে" on the_azadi in 12/29/2005-12/28/2010: 5
# Total New Sites from "হয়েছে" on the_azadi in 12/28/2010-12/27/2015: 3
# Total New Sites from "হয়েছে" on the_azadi in 12/27/2015-12/31/2015: 6
# Total New Sites from "হয়েছে" on the_azadi in 01/01/2016-02/20/2016: 4
# Total New Sites from "হয়েছে" on the_azadi in 02/20/2016-04/10/2016: 7
# Total New Sites from "হয়েছে" on the_azadi in 04/10/2016-05/30/2016: 6
# Total New Sites from "হয়েছে" on the_azadi in 05/30/2016-07/19/2016: 10
# Total New Sites from "হয়েছে" on the_azadi in 07/19/2016-09/07/2016: 7
# Total New Sites from "হয়েছে" on the_azadi in 09/07/2016-10/27/2016: 5
# Total New Sites from "হয়েছে" on the_azadi in 10/27/2016-12/16/2016: 3
# Executed 550/740 searches in 0:00:00.330702
# Total Sites: 4065
# Total New Sites from "হয়েছে" on the_azadi in 12/16/2016-02/04/2017: 6
# Total New Sites from "হয়েছে" on the_azadi in 02/04/2017-03/26/2017: 6
# Total New Sites from "হয়েছে" on the_azadi in 03/26/2017-05/15/2017: 5
# Total New Sites from "হয়েছে" on the_azadi in 05/15/2017-07/04/2017: 6
# Total New Sites from "হয়েছে" on the_azadi in 07/04/2017-08/23/2017: 4
# Total New Sites from "হয়েছে" on the_azadi in 08/23/2017-10/12/2017: 6
# Total New Sites from "হয়েছে" on the_azadi in 10/12/2017-12/01/2017: 8
# Total New Sites from "হয়েছে" on the_azadi in 12/01/2017-01/20/2018: 4
# Total New Sites from "হয়েছে" on the_azadi in 01/20/2018-03/11/2018: 5
# Total New Sites from "হয়েছে" on the_azadi in 03/11/2018-04/30/2018: 5
# Total New Sites from "হয়েছে" on the_azadi in 04/30/2018-06/19/2018: 7
# Total New Sites from "হয়েছে" on the_azadi in 06/19/2018-08/08/2018: 5
# Total New Sites from "হয়েছে" on the_azadi in 08/08/2018-09/27/2018: 9
# Total New Sites from "হয়েছে" on the_azadi in 09/27/2018-11/16/2018: 5
# Total New Sites from "হয়েছে" on the_azadi in 11/16/2018-01/05/2019: 6
# Total New Sites from "হয়েছে" on the_azadi in 01/05/2019-02/24/2019: 4
# Total New Sites from "হয়েছে" on the_azadi in 02/24/2019-04/15/2019: 7
# Total New Sites from "হয়েছে" on the_azadi in 04/15/2019-06/04/2019: 5
# Total New Sites from "হয়েছে" on the_azadi in 06/04/2019-07/24/2019: 6
# Total New Sites from "হয়েছে" on the_azadi in 07/24/2019-09/12/2019: 5
# Total New Sites from "হয়েছে" on the_azadi in 09/12/2019-11/01/2019: 7
# Total New Sites from "হয়েছে" on the_azadi in 11/01/2019-12/21/2019: 8
# Total New Sites from "হয়েছে" on the_azadi in 12/21/2019-02/09/2020: 7
# Total New Sites from "হয়েছে" on the_azadi in 02/09/2020-03/30/2020: 5
# Total New Sites from "হয়েছে" on the_azadi in 03/30/2020-05/19/2020: 6
# Total New Sites from "হয়েছে" on the_azadi in 05/19/2020-07/08/2020: 8
# Total New Sites from "হয়েছে" on the_azadi in 07/08/2020-08/27/2020: 6
# Total New Sites from "হয়েছে" on the_azadi in 08/27/2020-10/16/2020: 6
# Total New Sites from "হয়েছে" on the_azadi in 10/16/2020-12/05/2020: 7
# Total New Sites from "হয়েছে" on the_azadi in 12/05/2020-01/24/2021: 2
# Total New Sites from "হয়েছে" on the_azadi in 01/24/2021-03/15/2021: 6
# Total New Sites from "হয়েছে" on the_azadi in 03/15/2021-05/04/2021: 6
# Total New Sites from "হয়েছে" on the_azadi in 05/04/2021-06/23/2021: 4
# Total New Sites from "হয়েছে" on the_azadi in 06/23/2021-08/12/2021: 4
# Total New Sites from "হয়েছে" on the_azadi in 08/12/2021-10/01/2021: 4
# Total New Sites from "হয়েছে" on the_azadi in 10/01/2021-11/20/2021: 5
# Total New Sites from "হয়েছে" on the_azadi in 11/20/2021-12/31/2021: 5
# Total New Sites from "হয়েছে" on daily_sangram in 01/01/1996-12/30/2000: 4
# Total New Sites from "হয়েছে" on daily_sangram in 12/30/2000-12/29/2005: 6
# Total New Sites from "হয়েছে" on daily_sangram in 12/29/2005-12/28/2010: 5
# Total New Sites from "হয়েছে" on daily_sangram in 12/28/2010-12/27/2015: 5
# Total New Sites from "হয়েছে" on daily_sangram in 12/27/2015-12/31/2015: 5
# Total New Sites from "হয়েছে" on daily_sangram in 01/01/2016-02/20/2016: 7
# Total New Sites from "হয়েছে" on daily_sangram in 02/20/2016-04/10/2016: 7
# Total New Sites from "হয়েছে" on daily_sangram in 04/10/2016-05/30/2016: 3
# Total New Sites from "হয়েছে" on daily_sangram in 05/30/2016-07/19/2016: 3
# Total New Sites from "হয়েছে" on daily_sangram in 07/19/2016-09/07/2016: 6
# Total New Sites from "হয়েছে" on daily_sangram in 09/07/2016-10/27/2016: 5
# Total New Sites from "হয়েছে" on daily_sangram in 10/27/2016-12/16/2016: 7
# Total New Sites from "হয়েছে" on daily_sangram in 12/16/2016-02/04/2017: 6
# Executed 600/740 searches in 0:00:00.360135
# Total Sites: 4344
# Total New Sites from "হয়েছে" on daily_sangram in 02/04/2017-03/26/2017: 2
# Total New Sites from "হয়েছে" on daily_sangram in 03/26/2017-05/15/2017: 4
# Total New Sites from "হয়েছে" on daily_sangram in 05/15/2017-07/04/2017: 4
# Total New Sites from "হয়েছে" on daily_sangram in 07/04/2017-08/23/2017: 6
# Total New Sites from "হয়েছে" on daily_sangram in 08/23/2017-10/12/2017: 4
# Total New Sites from "হয়েছে" on daily_sangram in 10/12/2017-12/01/2017: 5
# Total New Sites from "হয়েছে" on daily_sangram in 12/01/2017-01/20/2018: 6
# Total New Sites from "হয়েছে" on daily_sangram in 01/20/2018-03/11/2018: 5
# Total New Sites from "হয়েছে" on daily_sangram in 03/11/2018-04/30/2018: 3
# Total New Sites from "হয়েছে" on daily_sangram in 04/30/2018-06/19/2018: 7
# Total New Sites from "হয়েছে" on daily_sangram in 06/19/2018-08/08/2018: 4
# Total New Sites from "হয়েছে" on daily_sangram in 08/08/2018-09/27/2018: 5
# Total New Sites from "হয়েছে" on daily_sangram in 09/27/2018-11/16/2018: 5
# Total New Sites from "হয়েছে" on daily_sangram in 11/16/2018-01/05/2019: 6
# Total New Sites from "হয়েছে" on daily_sangram in 01/05/2019-02/24/2019: 6
# Total New Sites from "হয়েছে" on daily_sangram in 02/24/2019-04/15/2019: 3
# Total New Sites from "হয়েছে" on daily_sangram in 04/15/2019-06/04/2019: 5
# Total New Sites from "হয়েছে" on daily_sangram in 06/04/2019-07/24/2019: 5
# Total New Sites from "হয়েছে" on daily_sangram in 07/24/2019-09/12/2019: 5
# Total New Sites from "হয়েছে" on daily_sangram in 09/12/2019-11/01/2019: 6
# Total New Sites from "হয়েছে" on daily_sangram in 11/01/2019-12/21/2019: 8
# Total New Sites from "হয়েছে" on daily_sangram in 12/21/2019-02/09/2020: 6
# Total New Sites from "হয়েছে" on daily_sangram in 02/09/2020-03/30/2020: 4
# Total New Sites from "হয়েছে" on daily_sangram in 03/30/2020-05/19/2020: 3
# Total New Sites from "হয়েছে" on daily_sangram in 05/19/2020-07/08/2020: 8
# Total New Sites from "হয়েছে" on daily_sangram in 07/08/2020-08/27/2020: 5
# Total New Sites from "হয়েছে" on daily_sangram in 08/27/2020-10/16/2020: 7
# Total New Sites from "হয়েছে" on daily_sangram in 10/16/2020-12/05/2020: 3
# Total New Sites from "হয়েছে" on daily_sangram in 12/05/2020-01/24/2021: 4
# Total New Sites from "হয়েছে" on daily_sangram in 01/24/2021-03/15/2021: 1
# Total New Sites from "হয়েছে" on daily_sangram in 03/15/2021-05/04/2021: 4
# Total New Sites from "হয়েছে" on daily_sangram in 05/04/2021-06/23/2021: 5
# Total New Sites from "হয়েছে" on daily_sangram in 06/23/2021-08/12/2021: 3
# Total New Sites from "হয়েছে" on daily_sangram in 08/12/2021-10/01/2021: 3
# Total New Sites from "হয়েছে" on daily_sangram in 10/01/2021-11/20/2021: 3
# Total New Sites from "হয়েছে" on daily_sangram in 11/20/2021-12/31/2021: 4
# Total New Sites from "হয়েছে" on sangbad_pratidin in 01/01/1996-12/30/2000: 8
# Total New Sites from "হয়েছে" on sangbad_pratidin in 12/30/2000-12/29/2005: 3
# Total New Sites from "হয়েছে" on sangbad_pratidin in 12/29/2005-12/28/2010: 4
# Total New Sites from "হয়েছে" on sangbad_pratidin in 12/28/2010-12/27/2015: 3
# Total New Sites from "হয়েছে" on sangbad_pratidin in 12/27/2015-12/31/2015: 4
# Total New Sites from "হয়েছে" on sangbad_pratidin in 01/01/2016-02/20/2016: 4
# Total New Sites from "হয়েছে" on sangbad_pratidin in 02/20/2016-04/10/2016: 8
# Total New Sites from "হয়েছে" on sangbad_pratidin in 04/10/2016-05/30/2016: 2
# Total New Sites from "হয়েছে" on sangbad_pratidin in 05/30/2016-07/19/2016: 6
# Total New Sites from "হয়েছে" on sangbad_pratidin in 07/19/2016-09/07/2016: 6
# Total New Sites from "হয়েছে" on sangbad_pratidin in 09/07/2016-10/27/2016: 5
# Total New Sites from "হয়েছে" on sangbad_pratidin in 10/27/2016-12/16/2016: 6
# Total New Sites from "হয়েছে" on sangbad_pratidin in 12/16/2016-02/04/2017: 3
# Total New Sites from "হয়েছে" on sangbad_pratidin in 02/04/2017-03/26/2017: 1
# Executed 650/740 searches in 0:00:00.388276
# Total Sites: 4574
# Total New Sites from "হয়েছে" on sangbad_pratidin in 03/26/2017-05/15/2017: 7
# Total New Sites from "হয়েছে" on sangbad_pratidin in 05/15/2017-07/04/2017: 2
# Total New Sites from "হয়েছে" on sangbad_pratidin in 07/04/2017-08/23/2017: 3
# Total New Sites from "হয়েছে" on sangbad_pratidin in 08/23/2017-10/12/2017: 5
# Total New Sites from "হয়েছে" on sangbad_pratidin in 10/12/2017-12/01/2017: 9
# Total New Sites from "হয়েছে" on sangbad_pratidin in 12/01/2017-01/20/2018: 3
# Total New Sites from "হয়েছে" on sangbad_pratidin in 01/20/2018-03/11/2018: 4
# Total New Sites from "হয়েছে" on sangbad_pratidin in 03/11/2018-04/30/2018: 4
# Total New Sites from "হয়েছে" on sangbad_pratidin in 04/30/2018-06/19/2018: 4
# Total New Sites from "হয়েছে" on sangbad_pratidin in 06/19/2018-08/08/2018: 5
# Total New Sites from "হয়েছে" on sangbad_pratidin in 08/08/2018-09/27/2018: 5
# Total New Sites from "হয়েছে" on sangbad_pratidin in 09/27/2018-11/16/2018: 5
# Total New Sites from "হয়েছে" on sangbad_pratidin in 11/16/2018-01/05/2019: 7
# Total New Sites from "হয়েছে" on sangbad_pratidin in 01/05/2019-02/24/2019: 4
# Total New Sites from "হয়েছে" on sangbad_pratidin in 02/24/2019-04/15/2019: 8
# Total New Sites from "হয়েছে" on sangbad_pratidin in 04/15/2019-06/04/2019: 5
# Total New Sites from "হয়েছে" on sangbad_pratidin in 06/04/2019-07/24/2019: 3
# Total New Sites from "হয়েছে" on sangbad_pratidin in 07/24/2019-09/12/2019: 7
# Total New Sites from "হয়েছে" on sangbad_pratidin in 09/12/2019-11/01/2019: 7
# Total New Sites from "হয়েছে" on sangbad_pratidin in 11/01/2019-12/21/2019: 7
# Total New Sites from "হয়েছে" on sangbad_pratidin in 12/21/2019-02/09/2020: 4
# Total New Sites from "হয়েছে" on sangbad_pratidin in 02/09/2020-03/30/2020: 5
# Total New Sites from "হয়েছে" on sangbad_pratidin in 03/30/2020-05/19/2020: 4
# Total New Sites from "হয়েছে" on sangbad_pratidin in 05/19/2020-07/08/2020: 4
# Total New Sites from "হয়েছে" on sangbad_pratidin in 07/08/2020-08/27/2020: 3
# Total New Sites from "হয়েছে" on sangbad_pratidin in 08/27/2020-10/16/2020: 5
# Total New Sites from "হয়েছে" on sangbad_pratidin in 10/16/2020-12/05/2020: 5
# Total New Sites from "হয়েছে" on sangbad_pratidin in 12/05/2020-01/24/2021: 3
# Total New Sites from "হয়েছে" on sangbad_pratidin in 01/24/2021-03/15/2021: 4
# Total New Sites from "হয়েছে" on sangbad_pratidin in 03/15/2021-05/04/2021: 5
# Total New Sites from "হয়েছে" on sangbad_pratidin in 05/04/2021-06/23/2021: 7
# Total New Sites from "হয়েছে" on sangbad_pratidin in 06/23/2021-08/12/2021: 6
# Total New Sites from "হয়েছে" on sangbad_pratidin in 08/12/2021-10/01/2021: 8
# Total New Sites from "হয়েছে" on sangbad_pratidin in 10/01/2021-11/20/2021: 4
# Total New Sites from "হয়েছে" on sangbad_pratidin in 11/20/2021-12/31/2021: 1
# Total New Sites from "হয়েছে" on the_daily_star in 01/01/1996-12/30/2000: 6
# Total New Sites from "হয়েছে" on the_daily_star in 12/30/2000-12/29/2005: 3
# Total New Sites from "হয়েছে" on the_daily_star in 12/29/2005-12/28/2010: 6
# Total New Sites from "হয়েছে" on the_daily_star in 12/28/2010-12/27/2015: 6
# Total New Sites from "হয়েছে" on the_daily_star in 12/27/2015-12/31/2015: 6
# Total New Sites from "হয়েছে" on the_daily_star in 01/01/2016-02/20/2016: 5
# Total New Sites from "হয়েছে" on the_daily_star in 02/20/2016-04/10/2016: 4
# Total New Sites from "হয়েছে" on the_daily_star in 04/10/2016-05/30/2016: 5
# Total New Sites from "হয়েছে" on the_daily_star in 05/30/2016-07/19/2016: 1
# Total New Sites from "হয়েছে" on the_daily_star in 07/19/2016-09/07/2016: 7
# Total New Sites from "হয়েছে" on the_daily_star in 09/07/2016-10/27/2016: 2
# Total New Sites from "হয়েছে" on the_daily_star in 10/27/2016-12/16/2016: 4
# Total New Sites from "হয়েছে" on the_daily_star in 12/16/2016-02/04/2017: 3
# Total New Sites from "হয়েছে" on the_daily_star in 02/04/2017-03/26/2017: 5
# Total New Sites from "হয়েছে" on the_daily_star in 03/26/2017-05/15/2017: 5
# Executed 700/740 searches in 0:00:00.415768
# Total Sites: 4814
# Total New Sites from "হয়েছে" on the_daily_star in 05/15/2017-07/04/2017: 4
# Total New Sites from "হয়েছে" on the_daily_star in 07/04/2017-08/23/2017: 5
# Total New Sites from "হয়েছে" on the_daily_star in 08/23/2017-10/12/2017: 6
# Total New Sites from "হয়েছে" on the_daily_star in 10/12/2017-12/01/2017: 5
# Total New Sites from "হয়েছে" on the_daily_star in 12/01/2017-01/20/2018: 5
# Total New Sites from "হয়েছে" on the_daily_star in 01/20/2018-03/11/2018: 5
# Total New Sites from "হয়েছে" on the_daily_star in 03/11/2018-04/30/2018: 4
# Total New Sites from "হয়েছে" on the_daily_star in 04/30/2018-06/19/2018: 2
# Total New Sites from "হয়েছে" on the_daily_star in 06/19/2018-08/08/2018: 5
# Total New Sites from "হয়েছে" on the_daily_star in 08/08/2018-09/27/2018: 3
# Total New Sites from "হয়েছে" on the_daily_star in 09/27/2018-11/16/2018: 5
# Total New Sites from "হয়েছে" on the_daily_star in 11/16/2018-01/05/2019: 3
# Total New Sites from "হয়েছে" on the_daily_star in 01/05/2019-02/24/2019: 4
# Total New Sites from "হয়েছে" on the_daily_star in 02/24/2019-04/15/2019: 3
# Total New Sites from "হয়েছে" on the_daily_star in 04/15/2019-06/04/2019: 5
# Total New Sites from "হয়েছে" on the_daily_star in 06/04/2019-07/24/2019: 5
# Total New Sites from "হয়েছে" on the_daily_star in 07/24/2019-09/12/2019: 2
# Total New Sites from "হয়েছে" on the_daily_star in 09/12/2019-11/01/2019: 2
# Total New Sites from "হয়েছে" on the_daily_star in 11/01/2019-12/21/2019: 3
# Total New Sites from "হয়েছে" on the_daily_star in 12/21/2019-02/09/2020: 4
# Total New Sites from "হয়েছে" on the_daily_star in 02/09/2020-03/30/2020: 7
# Total New Sites from "হয়েছে" on the_daily_star in 03/30/2020-05/19/2020: 5
# Total New Sites from "হয়েছে" on the_daily_star in 05/19/2020-07/08/2020: 3
# Total New Sites from "হয়েছে" on the_daily_star in 07/08/2020-08/27/2020: 2
# Total New Sites from "হয়েছে" on the_daily_star in 08/27/2020-10/16/2020: 3
# Total New Sites from "হয়েছে" on the_daily_star in 10/16/2020-12/05/2020: 5
# Total New Sites from "হয়েছে" on the_daily_star in 12/05/2020-01/24/2021: 2
# Total New Sites from "হয়েছে" on the_daily_star in 01/24/2021-03/15/2021: 5
# Total New Sites from "হয়েছে" on the_daily_star in 03/15/2021-05/04/2021: 4
# Total New Sites from "হয়েছে" on the_daily_star in 05/04/2021-06/23/2021: 2
# Total New Sites from "হয়েছে" on the_daily_star in 06/23/2021-08/12/2021: 3
# Total New Sites from "হয়েছে" on the_daily_star in 08/12/2021-10/01/2021: 5
# Total New Sites from "হয়েছে" on the_daily_star in 10/01/2021-11/20/2021: 4
# Total New Sites from "হয়েছে" on the_daily_star in 11/20/2021-12/31/2021: 7
# Total New Sites from "হয়েছে" on prothom_alo in 01/01/1996-12/30/2000: 5
# Total New Sites from "হয়েছে" on prothom_alo in 12/30/2000-12/29/2005: 5
# Total New Sites from "হয়েছে" on prothom_alo in 12/29/2005-12/28/2010: 4
# Total New Sites from "হয়েছে" on prothom_alo in 12/28/2010-12/27/2015: 6
# Total New Sites from "হয়েছে" on prothom_alo in 12/27/2015-12/31/2015: 4
# Completed in 0:00:00.443765

# %%
import json

with open("paper_to_site.json", 'w') as f:
    json.dump(names_site, f)

# %%
config_file = "RandomDenseSERPSearch.yaml"
with open(config_file, "r", encoding='utf-8') as f:
    loaded = yaml.load(f, Loader=yaml.FullLoader)

# %%
loaded
# Out:
# {'searches': {'popular': {'queries': ['"হয়েছে"'],
#    'papers': ['the_daily_janakantha',
#     'the_daily_jugantor',
#     'the_daily_ittefaq',
#     'amader_shomoy',
#     'bhorer_kagoj',
#     'daily_manab_zamin',
#     'alokito_bangladesh',
#     'the_sangbad',
#     'the_daily_inqilab',
#     'jaijaidin',
#     'daily_naya_diganta',
#     'the_azadi',
#     'daily_sangram',
#     'sangbad_pratidin',
#     'the_daily_star'],
#    'date_ranges': [['1/1/1996', '12/31/2015', 1825],
#     ['1/1/2016', '12/31/2021', 50]]},
#   'prothom_alo': {'queries': ['"হয়েছে"'],
#    'papers': ['prothom_alo'],
#    'date_ranges': [['1/1/1996', '12/31/2015', 1825]]}},
#  'output_dir': 'testing',
#  'output_file': '{paper}_serp_{query}.json',
#  'quote_sub': '[RVDQUOTE]',
#  'overwrite': False,
#  'skip_existing': True,
#  'searchnws': False,
#  'gl': 'bd',
#  'hl': 'bn',
#  'filter': '0',
#  'num': 100,
#  'SERPAPI_KEY': 'c8f7c4a413d768d9b454c42f233867c4bf3f4dba7be4b31bae4ed7b9b05dd268'}

# %% [markdown]
# # Paper Sites

# %%
paper_sites_str ="""1. prothom_alo - https://www.prothomalo.com
2. bangladesh_pratidin - https://www.bd-pratidin.com
3. the_daily_ittefaq - https://www.ittefaq.com.bd
4. kaler_kantho - https://www.kalerkantho.com
5. daily_naya_diganta - https://dailynayadiganta.com
6. daily_amar_sangbad - https://www.amarsangbad.com
7. protidiner_sangbad - https://www.protidinersangbad.com
8. the_daily_jugantor - https://www.jugantor.com
9. daily_sangram - https://dailysangram.com
10. daily_manab_zamin - https://mzamin.com
11. amader_shomoy - http://www.dainikamadershomoy.com
12. samakal - https://samakal.com
13. the_daily_janakantha - https://www.dailyjanakantha.com
14. jaijaidin - https://www.jaijaidinbd.com
15. bhorer_kagoj - https://www.bhorerkagoj.com
16. arthoniteer_kagoj - http://www.arthoniteerkagoj.com
17. the_daily_inqilab - https://www.dailyinqilab.com
18. sangbad - http://sangbad.net.bd
19. manob_kantha - https://www.manobkantha.com.bd
20. daily_suprobhat - https://suprobhat.com
21. bangladesh_journal - https://www.bd-journal.com
22. bonik_barta - https://bonikbarta.net
23. alokito_bangladesh - https://www.alokitobangladesh.com
24. ajker_bazar - https://www.ajkerbazzar.com
25. amadar_orthoneeti - https://amaderorthoneeti.com/new/
26. bangladesh_post - https://bn.bangladeshpost.net
27. sorejomin_barta - http://sorejominbarta.com
28. ajker_patrika - https://www.ajkerpatrika.com
29. khabar_patra - https://khoborpatrabd.com
30. vorer_pata - https://dailyvorerpata.com
31. shomoyer_alo - https://www.shomoyeralo.com
32. dhakar_dak - https://dhakardak-bd.com
33. natun_barta - http://www.natun-barta.com
34. share_biz - https://sharebiz.net
35. daily_bartoman - http://dailybartoman.com
36. ajkaler_khobor - https://www.ajkalerkhobor.net
37. sangbad_konika - https://www.sangbadkonika.com
38. somoyer_kantha - http://www.gonokantho.com
39. daily_star - https://www.thedailystar.net/bangla/
40. khola_kagoj - http://kholakagojbd.com
41. desh_rupantor - https://www.deshrupantor.com
42. bangladesher_khabor - https://www.bangladesherkhabor.net
43. amar_desh - http://bd-bulletin.com
44. daily_jagran - https://dailyjagaran.com
45. business_standard - https://www.tbsnews.net/bangla
46. dhaka_tribune - https://bangla.dhakatribune.com
47. khulna_news - https://khulnanews.com
48. daily_azadi - https://dainikazadi.org
49. daily_purbokone - https://dainikpurbokone.net
50. amader_comilla - https://dailyamadercomilla.com
51. daily_purbanchal - https://purbanchal.com
52. ukhiya_news - https://ukhiyanews.com
53. matha_bhanga - https://mathabhanga.com
54. rajshahi_news_24 - https://rajshahinews24.com
55. chattagram_news - https://chattagramnews.com
56. daily_khowai - https://dailykhowai.com
57. daily_karatoa - https://karatoa.com.bd
58. satkhira_news - https://satkhiranews.com
59. dainik_sylhet - https://dainiksylhet.com
60. daily_coxsbazar - https://dailycoxsbazar.com
61. uttorpurbo - https://euttorpurbo.com
62. ajker_jamalpur - https://ajkerjamalpur.com
63. amader_barisal - https://amaderbarisal.com
64. surma_times - https://surmatimes.com
65. dinajpur_news - https://dinajpurnews.com
66. kuakata_news - https://kuakatanews.com
67. chadpur_times - https://chandpurtimes.com
68. mukto_khobor_24 - https://muktokhobor24.com
69. teknaf_news - https://teknafnews.com
70. bogra_sangbad - https://bograsangbad.com
71. rajshahir_somoy - https://rajshahirsomoy.com
72. chandpurweb - https://chandpurweb.com
73. barisal_news - https://barisalnews.com
74. sylhet_express - https://sylhetexpress.com
75. laksmipur_24 - https://lakshmipur24.com
76. prothom_feni - https://prothom-feni.com
77. amar_noakhali - https://amarnoakhali.com
78. chakaria_news - https://chakarianews.com
79. gramer_kagoj - https://gramerkagoj.com
80. andoloner_bazar - https://dailyandolonerbazar.com
81. khulnanchal - https://khulnanchal.com
82. mymensingh_pratidin - https://mymensinghpratidin.com"""

# %%
import re
ext = re.compile("\d+\.\s([a-z_1-9]+)\s-\s([^$]*)")
paper_site = {ext.match(line)[1]: ext.match(line)[2] for line in paper_sites_str.split('\n')}

# %%
import json
PAPER_SITES_FILE = "paper_to_site.json"
with open("paper_to_site.json", 'r') as f:
    old_paper_site = json.load(f)

# %%
for k, v in old_paper_site.items():
    paper_site[k] = old_paper_site[k]
    assert(old_paper_site[k] == paper_site[k] or print(k, old_paper_site[k], paper_site[k]))
    
#for site in

# %%
https://www.dailynayadiganta.com
https://dailynayadiganta.com
# Out:
#   File "<ipython-input-39-2057a7048f9b>", line 1
#     https://www.dailynayadiganta.com
#           ^
# SyntaxError: invalid syntax

# %%
import requests
resp = requests.get("https://www.samakal.com")

# %%
for url in paper_site.values():
    try:
        resp = requests.get(url)
    except:
        print(url, " error")
    if not resp.ok:
        print(url)
# Out:
# https://www.bd-pratidin.com
# https://www.dailysangram.com  error
# https://www.samakal.com
# http://www.natun-barta.com
# https://www.sangbadkonika.com
# http://www.gonokantho.com
# https://www.bangla.dhakatribune.com  error
# https://www.khulnanews.com  error
# https://www.dailyamadercomilla.com
# https://www.ukhiyanews.com  error
# https://www.chattagramnews.com  error
# https://www.dailykhowai.com  error
# https://www.satkhiranews.com
# https://www.dailycoxsbazar.com  error
# https://www.euttorpurbo.com
# https://www.amaderbarisal.com  error
# https://www.surmatimes.com
# https://www.dinajpurnews.com  error
# https://www.dinajpurnews.com
# https://www.teknafnews.com  error
# https://www.barisalnews.com  error
# https://www.sylhetexpress.com  error

# %%
from fake_useragent import UserAgent
import urllib
from bs4 import BeautifulSoup

url = "http://www.sylhetexpress.com"
ua = UserAgent()
request = urllib.request.Request(
    url,
    headers={
        'User-Agent': ua.random
    }
)
page = urllib.request.urlopen(request)
soup = BeautifulSoup(page, "html.parser")
soup
# Out:
# <html lang="bn">
# <head>
# <title>Sylhet Express | সিলেট এক্সপ্রেস</title>
# <meta charset="utf-8" content="text/html" http-equiv="Content-Type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, minimum-scale=1, initial-scale=1, maximum-scale=1, user-scalable=0" name="viewport"/>
# <style type="text/css">
# 		.topicTextColor{
# 			color: white
# 		}
# 		.topicShow{
# 		  background-color: #887474;
# 		}
# 	</style>
# <link href="http://www.sylhetexpress.com" rel="canonical"/>
# <meta content="bd" name="x-country"/>
# <meta content="Asia" name="x-audience"/>
# <meta content="Asia" name="CPS_AUDIENCE"/>
# <meta content="on" http-equiv="cleartype"/>
# <meta content="Global" name="distribution"/>
# <meta content="fc13e7a3d58fc9ca" name="yandex-verification">
# <meta content="bn" http-equiv="Content-Language"/>
# <!--meta http-equiv="refresh" content="120"-->
# <link href="http://www.sylhetexpress.com/wp-content/themes/sylhet-expresss/images/favicon.png" rel="shortcut icon"/>
# <link href="http://www.sylhetexpress.com/wp-content/themes/sylhet-expresss/css/font-awesome.min.css" rel="stylesheet"/>
# <link href="http://www.sylhetexpress.com/wp-content/themes/sylhet-expresss/css/bootstrap.min.css" rel="stylesheet"/>
# <link href="http://www.sylhetexpress.com/wp-content/themes/sylhet-expresss/css/bootstrap-datepicker.min.css" rel="stylesheet" type="text/css"/>
# <link href="http://www.sylhetexpress.com/wp-content/themes/sylhet-expresss/css/lightslider.css" rel="stylesheet"/>
# <link href="http://www.sylhetexpress.com/wp-content/themes/sylhet-expresss/css/breakingnews.css" rel="stylesheet"/>
# <link href="http://www.sylhetexpress.com/wp-content/themes/sylhet-expresss/css/app.css" rel="stylesheet"/>
# <link href="http://www.sylhetexpress.com/wp-content/themes/sylhet-expresss/css/stylesheet.css" rel="stylesheet"/>
# <link href="http://www.sylhetexpress.com/wp-content/themes/sylhet-expresss/css/fonts.css" rel="stylesheet"/>
# <link href="http://www.sylhetexpress.com/wp-content/themes/sylhet-expresss/css/responsive.css" rel="stylesheet"/>
# <link href="http://www.sylhetexpress.com/wp-content/themes/sylhet-expresss/fonts/kalpurush.css" rel="stylesheet"/>
# <link href="http://www.sylhetexpress.com/xmlrpc.php" rel="pingback"/>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <script type="text/javascript">function theChampLoadEvent(e){var t=window.onload;if(typeof window.onload!="function"){window.onload=e}else{window.onload=function(){t();e()}}}</script>
# <script type="text/javascript">var theChampDefaultLang = 'en_US', theChampCloseIconPath = 'http://www.sylhetexpress.com/wp-content/plugins/super-socializer/images/close.png';</script>
# <script>var theChampSiteUrl = 'http://www.sylhetexpress.com', theChampVerified = 0, theChampEmailPopup = 0, heateorSsMoreSharePopupSearchText = 'Search';</script>
# <script> var theChampSharingAjaxUrl = 'http://www.sylhetexpress.com/wp-admin/admin-ajax.php', heateorSsFbMessengerAPI = 'https://www.facebook.com/dialog/send?app_id=595489497242932&display=popup&link=%encoded_post_url%&redirect_uri=%encoded_post_url%',heateorSsWhatsappShareAPI = 'web', heateorSsUrlCountFetched = [], heateorSsSharesText = 'Shares', heateorSsShareText = 'Share', theChampPluginIconPath = 'http://www.sylhetexpress.com/wp-content/plugins/super-socializer/images/logo.png', theChampSaveSharesLocally = 0, theChampHorizontalSharingCountEnable = 1, theChampVerticalSharingCountEnable = 0, theChampSharingOffset = -10, theChampCounterOffset = -10, theChampMobileStickySharingEnabled = 0, heateorSsCopyLinkMessage = "Link copied.";
# 		var heateorSsHorSharingShortUrl = "http://www.sylhetexpress.com/%e0%a6%b8%e0%a6%bf%e0%a6%b2%e0%a7%87%e0%a6%9f%e0%a7%87-%e0%a6%8f%e0%a6%95%e0%a6%a6%e0%a6%bf%e0%a6%a8%e0%a7%87-%e0%a6%95%e0%a6%b0%e0%a7%8b%e0%a6%a8%e0%a6%be%e0%a7%9f-%e0%a6%ae%e0%a7%83%e0%a6%a4/";var heateorSsVerticalSharingShortUrl = "http://www.sylhetexpress.com/%e0%a6%b8%e0%a6%bf%e0%a6%b2%e0%a7%87%e0%a6%9f%e0%a7%87-%e0%a6%8f%e0%a6%95%e0%a6%a6%e0%a6%bf%e0%a6%a8%e0%a7%87-%e0%a6%95%e0%a6%b0%e0%a7%8b%e0%a6%a8%e0%a6%be%e0%a7%9f-%e0%a6%ae%e0%a7%83%e0%a6%a4/";		</script>
# <style type="text/css">.the_champ_horizontal_sharing .theChampSharing{
# 					color: #fff;
# 				border-width: 0px;
# 		border-style: solid;
# 		border-color: transparent;
# 	}
# 		.the_champ_horizontal_sharing .theChampTCBackground{
# 		color:#666;
# 	}
# 		.the_champ_horizontal_sharing .theChampSharing:hover{
# 				border-color: transparent;
# 	}
# 	.the_champ_vertical_sharing .theChampSharing{
# 					color: #fff;
# 				border-width: 0px;
# 		border-style: solid;
# 		border-color: transparent;
# 	}
# 		.the_champ_vertical_sharing .theChampTCBackground{
# 		color:#666;
# 	}
# 		.the_champ_vertical_sharing .theChampSharing:hover{
# 				border-color: transparent;
# 	}
# 				div.the_champ_horizontal_sharing .the_champ_square_count{float:right;margin:0 8px;line-height:35px;}
# 			@media screen and (max-width:783px){.the_champ_vertical_sharing{display:none!important}}</style>
# <meta content="index, follow, max-video-preview:-1, max-snippet:-1, max-image-preview:large" name="robots">
# <!-- This site is optimized with the Yoast SEO plugin v16.8 - https://yoast.com/wordpress/plugins/seo/ -->
# <meta content="সিলেটের প্রথম অনলাইন দৈনিক" name="description">
# <link href="http://www.sylhetexpress.com/" rel="canonical">
# <link href="http://www.sylhetexpress.com/page/2/" rel="next">
# <meta content="en_US" property="og:locale">
# <meta content="website" property="og:type">
# <meta content="Sylhet Express | সিলেট এক্সপ্রেস" property="og:title">
# <meta content="সিলেটের প্রথম অনলাইন দৈনিক" property="og:description">
# <meta content="http://www.sylhetexpress.com/" property="og:url">
# <meta content="Sylhet Express | সিলেট এক্সপ্রেস" property="og:site_name"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <script class="yoast-schema-graph" type="application/ld+json">{"@context":"https://schema.org","@graph":[{"@type":"WebSite","@id":"http://www.sylhetexpress.com/#website","url":"http://www.sylhetexpress.com/","name":"Sylhet Express | \u09b8\u09bf\u09b2\u09c7\u099f \u098f\u0995\u09cd\u09b8\u09aa\u09cd\u09b0\u09c7\u09b8","description":"\u09b8\u09bf\u09b2\u09c7\u099f\u09c7\u09b0 \u09aa\u09cd\u09b0\u09a5\u09ae \u0985\u09a8\u09b2\u09be\u0987\u09a8 \u09a6\u09c8\u09a8\u09bf\u0995","potentialAction":[{"@type":"SearchAction","target":{"@type":"EntryPoint","urlTemplate":"http://www.sylhetexpress.com/?s={search_term_string}"},"query-input":"required name=search_term_string"}],"inLanguage":"en-US"},{"@type":"CollectionPage","@id":"http://www.sylhetexpress.com/#webpage","url":"http://www.sylhetexpress.com/","name":"Sylhet Express | \u09b8\u09bf\u09b2\u09c7\u099f \u098f\u0995\u09cd\u09b8\u09aa\u09cd\u09b0\u09c7\u09b8","isPartOf":{"@id":"http://www.sylhetexpress.com/#website"},"description":"\u09b8\u09bf\u09b2\u09c7\u099f\u09c7\u09b0 \u09aa\u09cd\u09b0\u09a5\u09ae \u0985\u09a8\u09b2\u09be\u0987\u09a8 \u09a6\u09c8\u09a8\u09bf\u0995","breadcrumb":{"@id":"http://www.sylhetexpress.com/#breadcrumb"},"inLanguage":"en-US","potentialAction":[{"@type":"ReadAction","target":["http://www.sylhetexpress.com/"]}]},{"@type":"BreadcrumbList","@id":"http://www.sylhetexpress.com/#breadcrumb","itemListElement":[{"@type":"ListItem","position":1,"name":"Home"}]}]}</script>
# <!-- / Yoast SEO plugin. -->
# <link href="//s.w.org" rel="dns-prefetch">
# <link href="http://www.sylhetexpress.com/feed/" rel="alternate" title="Sylhet Express | সিলেট এক্সপ্রেস » Feed" type="application/rss+xml">
# <link href="http://www.sylhetexpress.com/comments/feed/" rel="alternate" title="Sylhet Express | সিলেট এক্সপ্রেস » Comments Feed" type="application/rss+xml">
# <script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/13.1.0\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/13.1.0\/svg\/","svgExt":".svg","source":{"concatemoji":"http:\/\/www.sylhetexpress.com\/wp-includes\/js\/wp-emoji-release.min.js?ver=5.8"}};
# 			!function(e,a,t){var n,r,o,i=a.createElement("canvas"),p=i.getContext&&i.getContext("2d");function s(e,t){var a=String.fromCharCode;p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,e),0,0);e=i.toDataURL();return p.clearRect(0,0,i.width,i.height),p.fillText(a.apply(this,t),0,0),e===i.toDataURL()}function c(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(o=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},r=0;r<o.length;r++)t.supports[o[r]]=function(e){if(!p||!p.fillText)return!1;switch(p.textBaseline="top",p.font="600 32px Arial",e){case"flag":return s([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])?!1:!s([55356,56826,55356,56819],[55356,56826,8203,55356,56819])&&!s([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]);case"emoji":return!s([10084,65039,8205,55357,56613],[10084,65039,8203,55357,56613])}return!1}(o[r]),t.supports.everything=t.supports.everything&&t.supports[o[r]],"flag"!==o[r]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[o[r]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(n=t.source||{}).concatemoji?c(n.concatemoji):n.wpemoji&&n.twemoji&&(c(n.twemoji),c(n.wpemoji)))}(window,document,window._wpemojiSettings);
# 		</script>
# <style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# <style type="text/css">
# 	.wp-pagenavi{margin-left:auto !important; margin-right:auto; !important}
# 	</style>
# <link href="http://www.sylhetexpress.com/wp-content/plugins/metronet-profile-picture/dist/blocks.style.build.css?ver=2.6.0" id="mpp_gutenberg-css" media="all" rel="stylesheet" type="text/css">
# <link href="http://www.sylhetexpress.com/wp-content/plugins/super-socializer/css/front.css?ver=7.13.25" id="the_champ_frontend_css-css" media="all" rel="stylesheet" type="text/css">
# <link href="http://www.sylhetexpress.com/wp-content/plugins/super-socializer/css/share-svg.css?ver=7.13.25" id="the_champ_sharing_default_svg-css" media="all" rel="stylesheet" type="text/css">
# <link href="http://www.sylhetexpress.com/wp-content/plugins/wp-pagenavi-style/css/css3_black_glossy.css?ver=1.0" id="wp-pagenavi-style-css" media="all" rel="stylesheet" type="text/css">
# <script id="jquery-core-js" src="http://www.sylhetexpress.com/wp-includes/js/jquery/jquery.min.js?ver=3.6.0" type="text/javascript"></script>
# <script id="jquery-migrate-js" src="http://www.sylhetexpress.com/wp-includes/js/jquery/jquery-migrate.min.js?ver=3.3.2" type="text/javascript"></script>
# <link href="http://www.sylhetexpress.com/wp-json/" rel="https://api.w.org/"><link href="http://www.sylhetexpress.com/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml">
# <link href="http://www.sylhetexpress.com/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml">
# <script type="text/javascript">
# 	    var ajaxurl = 'http://www.sylhetexpress.com/wp-admin/admin-ajax.php';
# 	</script>
# <style type="text/css">
# 		.ajax-calendar{
# 			position:relative;
# 		}
#
# 		#ajax_ac_widget th {
# 		background: none repeat scroll 0 0 #2cb2bc;
# 		color: #FFFFFF;
# 		font-weight: normal;
# 		padding: 5px 1px;
# 		text-align: center;
# 		 font-size: 16px;
# 		}
# 		#ajax_ac_widget {
# 			padding: 5px;
# 		}
#
# 		#ajax_ac_widget td {
# 			border: 1px solid #CCCCCC;
# 			text-align: center;
# 		}
#
# 		#my-calendar a {
# 			background: none repeat scroll 0 0 #008000;
# 			color: #FFFFFF;
# 			display: block;
# 			padding: 6px 0;
# 			width: 100% !important;
# 		}
# 		#my-calendar{
# 			width:100%;
# 		}
#
#
# 		#my_calender span {
# 			display: block;
# 			padding: 6px 0;
# 			width: 100% !important;
# 		}
#
# 		#today a,#today span {
# 			   background: none repeat scroll 0 0 #2cb2bc !important;
# 			color: #FFFFFF;
# 		}
# 		#ajax_ac_widget #my_year {
# 			float: right;
# 		}
# 		.select_ca #my_month {
# 			float: left;
# 		}
#
# 	</style>
# <script type="text/javascript">
# 	    var ajaxurl = 'http://www.sylhetexpress.com/wp-admin/admin-ajax.php';
# 	</script>
# <style type="text/css">
# 		.ajax-calendar{
# 			position:relative;
# 		}
#
# 		#bddp_ac_widget th {
# 		background: none repeat scroll 0 0 #2cb2bc;
# 		color: #FFFFFF;
# 		font-weight: normal;
# 		padding: 5px 1px;
# 		text-align: center;
# 		 font-size: 16px;
# 		}
# 		#bddp_ac_widget {
# 			padding: 5px;
# 		}
#
# 		#bddp_ac_widget td {
# 			border: 1px solid #CCCCCC;
# 			text-align: center;
# 		}
#
# 		#my-calendar a {
# 			background: none repeat scroll 0 0 #008000;
# 			color: #FFFFFF;
# 			display: block;
# 			padding: 6px 0;
# 			width: 100% !important;
# 		}
# 		#my-calendar{
# 			width:100%;
# 		}
#
#
# 		#my_calender span {
# 			display: block;
# 			padding: 6px 0;
# 			width: 100% !important;
# 		}
#
# 		#today a,#today span {
# 			   background: none repeat scroll 0 0 #2cb2bc !important;
# 			color: #FFFFFF;
# 		}
# 		#bddp_ac_widget #my_year {
# 			float: right;
# 		}
# 		.select_ca #my_month {
# 			float: left;
# 		}
#
# 	</style>
# <meta content="483842441646179" property="fb:pages"/>
# <meta content="http://www.sylhetexpress.com/%e0%a6%b8%e0%a6%bf%e0%a6%b2%e0%a7%87%e0%a6%9f%e0%a7%87-%e0%a6%8f%e0%a6%95%e0%a6%a6%e0%a6%bf%e0%a6%a8%e0%a7%87-%e0%a6%95%e0%a6%b0%e0%a7%8b%e0%a6%a8%e0%a6%be%e0%a7%9f-%e0%a6%ae%e0%a7%83%e0%a6%a4/?ia_markup=1" property="ia:markup_url"/>
# <style type="text/css">
# 	 .wp-pagenavi
# 	{
# 		font-size:12px !important;
# 	}
# 	</style>
# <link href="http://www.sylhetexpress.com/wp-content/uploads/2018/02/favicon.png" rel="icon" sizes="32x32">
# <link href="http://www.sylhetexpress.com/wp-content/uploads/2018/02/favicon.png" rel="icon" sizes="192x192"/>
# <link href="http://www.sylhetexpress.com/wp-content/uploads/2018/02/favicon.png" rel="apple-touch-icon"/>
# <meta content="http://www.sylhetexpress.com/wp-content/uploads/2018/02/favicon.png" name="msapplication-TileImage"/>
# <!-- BEGIN SHAREAHOLIC CODE -->
# <link as="script" href="https://cdn.shareaholic.net/assets/pub/shareaholic.js" rel="preload"/>
# <meta content="34963c751e308a41fca66637723ae44d" name="shareaholic:site_id"/>
# <script async="" data-cfasync="false" src="https://cdn.shareaholic.net/assets/pub/shareaholic.js"></script>
# <!-- END SHAREAHOLIC CODE -->
# <meta content="483842441646179" property="fb:pages"/>
# </link></link></link></link></link></link></link></link></link></link></link></meta></meta></meta></meta></meta></link></link></meta></meta></meta></head>
# <body class="home blog">
# <div id="fb-root"></div>
# <script>(function(d, s, id) {
#   var js, fjs = d.getElementsByTagName(s)[0];
#   if (d.getElementById(id)) return;
#   js = d.createElement(s); js.id = id;
#   js.src = 'https://connect.facebook.net/bn_IN/sdk.js#xfbml=1&version=v2.12&appId=1045091022220179&autoLogAppEvents=1';
#   fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));</script>
# <!-- sylhetexpress navbar-->
# <div class="topadv"> <aside class="widget widget_text" id="text-3"> <div class="textwidget"></div>
# </aside></div>
# <nav class="navbar navbar-default sylhetexpress-nav" style="border:none;">
# <div class="container">
# <div>
# <button aria-controls="navbar" aria-expanded="false" class="navbar-toggle collapsed" data-target="#navbar" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# <a href="https://www.sylhetexpress.com">
# <img class="img-responsive center-block" src="http://www.sylhetexpress.com/wp-content/uploads/sylhet_express_beta.jpg"/>
# </a>
# </div>
# <div class="navbar-collapse collapse" id="navbar" style="margin: 0 auto;padding: 0;">
# <ul class="nav navbar-nav sylhetexpress-nav-menu">
# <li><a href="http://www.sylhetexpress.com">হোম</a></li>
# <li><a href="http://www.sylhetexpress.com/category/national">জাতীয়</a></li>
# <li><a href="http://www.sylhetexpress.com/category/politics">রাজনীতি</a></li>
# <li><a href="http://www.sylhetexpress.com/category/sylhet">সিলেট</a></li>
# <li><a href="http://www.sylhetexpress.com/category/moulvibazar">মৌলভীবাজার</a></li>
# <li><a href="http://www.sylhetexpress.com/category/habiganj">হবিগঞ্জ</a></li>
# <li><a href="http://www.sylhetexpress.com/category/sunamganj">সুনামগঞ্জ</a></li>
# <li><a href="http://www.sylhetexpress.com/category/country">সারাদেশ</a></li>
# <li><a href="http://www.sylhetexpress.com/category/law-crime">আইন-অপরাধ</a></li>
# <li class="triky"><a href="http://www.sylhetexpress.com/category/media-watch">মিডিয়া ওয়াচ</a></li>
# <li class="triky"><a href="http://www.sylhetexpress.com/category/literature-culture">সাহিত্য ও সংস্কৃতি</a></li>
# <li class="triky"><a href="http://www.sylhetexpress.com/category/local-government">স্থানীয় সরকার</a></li>
# <li class="triky"><a href="http://www.sylhetexpress.com/category/education">শিক্ষা</a> </li>
# <li class="triky"><a href="http://www.sylhetexpress.com/category/services-club">সার্ভিস ক্লাব </a></li>
# <li class="triky"><a href="http://www.sylhetexpress.com/category/interview">সাক্ষাৎকার</a></li>
# <li class="triky"><a href="http://www.sylhetexpress.com/category/industry-trade">শিল্প-বাণিজ্য</a></li>
# <li class="triky"><a href="http://www.sylhetexpress.com/category/photo-gallery"><i aria-hidden="true" class="fa fa-camera" style="color: #662b8e;" title="ছবি"></i> ছবি</a></li>
# <li class="triky"><a href="http://www.sylhetexpress.com/category/video-gallery"><i aria-hidden="true" class="fa fa-video-camera" style="color: #9c3232;" title="ভিডিও"></i> ভিডিও</a></li>
# <li class="triky"><a href="http://www.sylhetexpress.com/category/sylhet-surma-tv"><i aria-hidden="true" class="fa fa-television" style="color: green;" title="সিলেট সুরমা টিভি"></i> সিলেট সুরমা টিভি</a></li>
# <li class="triky"><a href="archive"><i aria-hidden="true" class="fa fa-file-archive-o" style="color: #f44506;" title="আর্কাইভ"></i> পুরনো আর্কাইভ</a></li>
# <li class="triky" id="sylhetexpress-search-trigger-m"><a href="javascript:void(0)"><i aria-hidden="true" class="fa fa-search" style="color: #7da923;" title="খুঁজন..."></i> খুঁজন...</a></li>
# <li class="dropdown mega-dropdown sm-trick">
# <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="#" role="button">অন্যান্য  <i aria-hidden="true" class="fa fa-bars" style="font-size: 15px;"></i></a>
# <div class="dropdown-menu mega-dropdown-menu" style="margin-top: -1px">
# <div class="mega-dropdown-menu-inner">
# <div class="container">
# <div class="menu-inner">
# <ul class="list-unstyled must-menu" style="padding-left: 0px;">
# <li class="col-sm-3" style="padding-top: 20px; padding-bottom: 10px;"><a href="http://www.sylhetexpress.com/category/media-watch">মিডিয়া ওয়াচ</a></li>
# <li class="col-sm-3" style="padding-top: 20px; padding-bottom: 10px;"><a href="http://www.sylhetexpress.com/category/literature-culture">সাহিত্য ও সংস্কৃতি</a></li>
# <li class="col-sm-3" style="padding-top: 20px; padding-bottom: 10px;"><a href="http://www.sylhetexpress.com/category/local-government">স্থানীয় সরকার</a></li>
# <li class="col-sm-3" style="padding-top: 20px; padding-bottom: 10px;"><a href="http://www.sylhetexpress.com/category/international">বিশ্ব</a> </li>
# <li class="col-sm-3" style="padding-top: 20px; padding-bottom: 10px;"><a href="http://www.sylhetexpress.com/category/emigration">প্রবাস</a></li>
# <li class="col-sm-3" style="padding-top: 20px; padding-bottom: 10px;"><a href="http://www.sylhetexpress.com/category/sports">খেলাধুলা</a> </li>
# <li class="col-sm-3" style="padding-top: 20px; padding-bottom: 10px;"><a href="http://www.sylhetexpress.com/category/election">নির্বাচন</a></li>
# <li class="col-sm-3" style="padding-top: 20px; padding-bottom: 10px;"><a href="http://www.sylhetexpress.com/category/administration">প্রশাসন</a></li>
# <li class="col-sm-3" style="padding-top: 20px; padding-bottom: 10px;"><a href="http://www.sylhetexpress.com/category/industry-trade">শিল্প-বাণিজ্য</a></li>
# <li class="col-sm-3" style="padding-top: 20px; padding-bottom: 10px;"><a href="http://www.sylhetexpress.com/category/interview">সাক্ষাৎকার</a></li>
# <li class="col-sm-3" style="padding-top: 20px; padding-bottom: 10px;"><a href="http://www.sylhetexpress.com/category/Illuminated-face">আলোকিত মুখ</a></li>
# <li class="col-sm-3" style="padding-top: 20px; padding-bottom: 10px;"><a href="http://www.sylhetexpress.com/category/liberation-war">মুক্তিযুদ্ধ</a></li>
# <li class="col-sm-3" style="padding-top: 20px; padding-bottom: 10px;"><a href="http://www.sylhetexpress.com/category/day">দিবস</a></li>
# <li class="col-sm-3" style="padding-top: 20px; padding-bottom: 10px;"><a href="http://www.sylhetexpress.com/category/miscellaneous">বিবিধ</a></li>
# <li class="col-sm-3" style="padding-top: 20px; padding-bottom: 10px;"><a href="http://www.sylhetexpress.com/category/personality">ব্যক্তিত্ব</a></li>
# <li class="col-sm-3" style="padding-top: 20px; padding-bottom: 10px;"><a href="http://www.sylhetexpress.com/category/day">দিবস</a></li>
# <li class="col-sm-3" style="padding-top: 20px; padding-bottom: 10px;"><a href="http://www.sylhetexpress.com/category/accident">দুর্ঘটনা</a></li>
# <li class="col-sm-3" style="padding-top: 20px; padding-bottom: 10px;"><a href="http://www.sylhetexpress.com/category/islam-life">ইসলাম ও জীবন</a></li>
# <li class="col-sm-3" style="padding-top: 20px; padding-bottom: 10px;"><a href="http://www.sylhetexpress.com/category/health">লাইফস্টাইল</a></li>
# </ul>
# </div>
# <div class="hr" style="color: #fff;"></div>
# <div class="row">
# <div class="col-md-12">
# <ul class="list-unstyled list-inline mega-adition must-menu">
# <li><a href="http://www.sylhetexpress.com/category/education">শিক্ষা</a> </li>
# <li><a href="http://www.sylhetexpress.com/category/services-club">সার্ভিস ক্লাব </a></li>
# <li><a href="http://www.sylhetexpress.com/category/interview">সাক্ষাৎকার</a></li>
# <li><a href="http://www.sylhetexpress.com/category/industry-trade">শিল্প-বাণিজ্য</a></li>
# <li><a href="http://www.sylhetexpress.com/category/photo-gallery"><i aria-hidden="true" class="fa fa-camera" style="color: #662b8e;" title="ছবি"></i> ছবি</a></li>
# <li><a href="http://www.sylhetexpress.com/category/video-gallery"><i aria-hidden="true" class="fa fa-video-camera" style="color: #9c3232;" title="ভিডিও"></i> ভিডিও</a></li>
# <li><a href="http://www.sylhetexpress.com/category/sylhet-surma-tv"><i aria-hidden="true" class="fa fa-television" style="color: green;" title="সিলেট সুরমা টিভি"></i> সিলেট সুরমা টিভি</a></li>
# <li><a href="archive"><i aria-hidden="true" class="fa fa-file-archive-o" style="color: #f44506;" title="আর্কাইভ"></i> পুরনো আর্কাইভ</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="mega-rest-part"></div>
# </div>
# </li>
# <li class="sm-trick" id="sylhetexpress-search-trigger"><a href="javascript:void(0)" style="padding: 19px 15px;" title="serarch sylhetexpress news"><i class="fa fa-search"></i></a></li>
# </ul>
# </div>
# <!--/.nav-collapse -->
# </div>
# </nav></body></html>
# <div class="updatebar" style="background-color: #f8f8f8; color: #000; box-shadow: 0px 5px 5px -5px #000; height: 30px;">
# <div class="container">
# <div class="row">
# <div class="col-xs-12">
# <div class="updatebar-wraper clearfix">
# <!-- <p style="margin-bottom: 0px;"> -->
# <div class="pull-left" style="padding-top: 2px; padding-bottom: 0px;">
# <span class="theme-site-intro">
# <i class="fa fa-map-marker"></i> সিলেট</span>
# <span class="theme-site-intro">
# <i class="fa fa-calendar"></i>
# 								শুক্রবার, ২০শে আগস্ট, ২০২১ খ্রিস্টাব্দ | ৫ই ভাদ্র, ১৪২৮ বঙ্গাব্দ | ১১ই মহর্‌রম, ১৪৪৩ হিজরি							</span>
# </div>
# <div class="pull-right hidden-xs" style="padding-top: 1px;">
# <span><a href="http://www.sylhetexpress.com/sylhet_express_apps.apk" style="text-decoration: none;" target="_blank" title="Sylhet Express App"><i aria-hidden="true" class="fa fa-android fa-2x" style="color: green;font-size: 24px"></i></a></span>
# 						<span><a href="https://www.facebook.com/sylhetexpress.news" style="text-decoration: none;" target="_blank" title="Sylhet Express Facebook Page"><i aria-hidden="true" class="fa fa-facebook-official" style="color: #3B5998;font-size: 24px"></i></a></span>
# 						<span><a href="http://www.youtube.com/SylhetExpressOfficial" style="text-decoration: none;color: black" target="_blank" title=""><i class="fa fa-youtube-square" style="color: #CC181E;font-size: 24px"></i></a></span> <span style="margin-top: 4px;">|</span>
# <span><a href="http://www.sylhetexpress.com/wp-login.php" style="text-decoration: none;color: #961210;font-size: 16px;" target="_blank" title="">লগ-ইন করুন</a></span>
# </div>
# <!-- </p> -->
# </div>
# </div>
# </div>
# </div>
# </div>
#
# <!--/ sylhetexpress navbar-->
# <!--serach form-->
# <form action="http://www.sylhetexpress.com/" class="form-search form-inline" id="sylhetexpress-search" method="get" role="search" style="display: none;">
# <div class="container">
# <div class="form-group">
# <div class="input-group input-group-unstyled">
# <input class="form-control search-text-input" name="s" placeholder="কী খুঁজতে চান?" type="search" value=""/>
# <span class="input-group-addon form_submit" type="submit">
# <i class="fa fa-search" style="color:#7da923;"></i>
# </span>
# <span class="input-group-addon" id="sylhetexpress-search-close">
# <i class="fa fa-close" style="color: brown"></i>
# </span>
# </div>
# </div>
# </div>
# </form>
# <!--/search form-->
# <div class="main-div">
# <div class="bg-white" style="padding: 0;">
# <div class="container">
# <div style="text-shadow: 0px 2px 0px #000;font-size: 21px;background:url('http://www.sylhetexpress.com/wp-content/uploads/youtubebw.jpg');padding-top: 12px;padding-bottom: 8px;text-align: center;color: #fff;"><p>ইউটিউবে সিলেট এক্সপ্রেসর জনপ্রিয় সব ভিডিও দেখুন। সাবস্ক্রাইব করুন আমাদের চ্যানেলটি:</p>
# <span style="margin-top:12px;"></span>
# <script src="https://apis.google.com/js/platform.js"></script>
# <div class="g-ytsubscribe" data-channelid="UC7BIL00CgKeto6PUCG0hiaA" data-count="default" data-layout="full"></div>
# </div>
# </div>
# </div>
# </div>
# <!--election result-->
# <!--------------------- Headlines/Breaking News ---------------------------->
# <div class="container headline-content">
# <div class="breakingNews bn-bordernone bn-red" id="sBreakingNews">
# <div class="bn-title" style="width: auto;"><h2 style="display: inline-block;">শিরোনাম</h2><span></span></div>
# <ul style="left: 106px;">
# <li style="display: none; width: 100%;"><a href="http://www.sylhetexpress.com/%e0%a6%b8%e0%a6%bf%e0%a6%b2%e0%a7%87%e0%a6%9f%e0%a7%87-%e0%a6%8f%e0%a6%95%e0%a6%a6%e0%a6%bf%e0%a6%a8%e0%a7%87-%e0%a6%95%e0%a6%b0%e0%a7%8b%e0%a6%a8%e0%a6%be%e0%a7%9f-%e0%a6%ae%e0%a7%83%e0%a6%a4/">সিলেটে একদিনে করোনায় মৃত্যু ও শনাক্ত কিছুটা কমেছে</a></li>
# <li style="display: none; width: 100%;"><a href="http://www.sylhetexpress.com/%e0%a6%b8%e0%a6%bf%e0%a6%b2%e0%a7%87%e0%a6%9f-%e0%a6%9c%e0%a7%87%e0%a6%b2%e0%a6%be-%e0%a6%86%e0%a6%93%e0%a6%af%e0%a6%bc%e0%a6%be%e0%a6%ae%e0%a7%80-%e0%a6%b2%e0%a7%80%e0%a6%97%e0%a7%87%e0%a6%b0/">সিলেট জেলা আওয়ামী লীগের ২১ আগস্টের কর্মসূচি</a></li>
# <li style="display: none; width: 100%;"><a href="http://www.sylhetexpress.com/%e0%a6%9c%e0%a6%a8%e0%a7%8d%e0%a6%ae%e0%a6%a6%e0%a6%bf%e0%a6%a8%e0%a7%87-%e0%a6%ad%e0%a6%be%e0%a6%b2%e0%a6%ac%e0%a6%be%e0%a6%b8%e0%a6%be%e0%a7%9f-%e0%a6%b8%e0%a6%bf%e0%a6%95%e0%a7%8d%e0%a6%a4/">জন্মদিনে ভালবাসায় সিক্ত সাংবাদিক তানভীর</a></li>
# <li style="display: none; width: 100%;"><a href="http://www.sylhetexpress.com/%e0%a6%b8%e0%a6%bf%e0%a6%b2%e0%a7%87%e0%a6%9f%e0%a7%87-%e0%a6%86%e0%a6%9c-%e0%a6%b8%e0%a6%bf%e0%a6%8f%e0%a6%b8%e0%a6%86%e0%a6%b0-%e0%a6%b8%e0%a6%82%e0%a6%b2%e0%a6%be%e0%a6%aa/">সিলেটে আজ ‘সিএসআর সংলাপ’</a></li>
# <li style="display: none; width: 100%;"><a href="http://www.sylhetexpress.com/%e0%a6%b8%e0%a6%bf%e0%a6%b2%e0%a7%87%e0%a6%9f%e0%a7%87-%e0%a6%8f%e0%a6%95%e0%a6%a6%e0%a6%bf%e0%a6%a8%e0%a7%87-%e0%a6%86%e0%a6%b0%e0%a6%93-%e0%a7%a8%e0%a7%a8-%e0%a6%9c%e0%a6%a8%e0%a7%87%e0%a6%b0/">সিলেটে একদিনে আরও ২২ জনের মৃত্যু করোনা</a></li>
# <li style="display: none; width: 100%;"><a href="http://www.sylhetexpress.com/%e0%a6%b8%e0%a7%8d%e0%a6%ac%e0%a6%be%e0%a6%b8%e0%a7%8d%e0%a6%a5%e0%a7%8d%e0%a6%af%e0%a6%ac%e0%a6%bf%e0%a6%a7%e0%a6%bf-%e0%a6%ae%e0%a7%87%e0%a6%a8%e0%a7%87-%e0%a6%86%e0%a6%9c-%e0%a6%a5%e0%a7%87/">স্বাস্থ্যবিধি মেনে আজ থেকে খুলছে পর্যটনকেন্দ্র</a></li>
# </ul>
# <div class="bn-navi">
# <span></span>
# <span></span>
# </div>
# </div>
# </div>
# <div class="bg-white" style="padding-top: 0px; padding-bottom: 15px;">
# <div class="container">
# <img class="img-responsive" src="http://www.sylhetexpress.com/wp-content/uploads/77251017_429546657720201_4454960673226489856_n.jpg" style="margin: 0 auto;width: 100%;margin-bottom: 10px;">
# <div class="row" style="">
# <div class="col-md-6 col-sm-12 col-xs-12">
# <div class="lead-news has_img">
# <img alt="" class="img-responsive post-img wp-post-image" height="358" loading="lazy" src="http://www.sylhetexpress.com/wp-content/uploads/news_image_16-640x358.jpg" width="640"/> <div class="news-intro">
# <p style="font-size: 20px;color: #d5e119;margin: 0px"></p>
# <h3 class="heading lead-hl" style="padding-top: 0px !important">
# 					  সিলেটে একদিনে করোনায় মৃত্যু ও শনাক্ত কিছুটা কমেছে					</h3>
# </div>
# <a class="link-overlay" href="http://www.sylhetexpress.com/%e0%a6%b8%e0%a6%bf%e0%a6%b2%e0%a7%87%e0%a6%9f%e0%a7%87-%e0%a6%8f%e0%a6%95%e0%a6%a6%e0%a6%bf%e0%a6%a8%e0%a7%87-%e0%a6%95%e0%a6%b0%e0%a7%8b%e0%a6%a8%e0%a6%be%e0%a7%9f-%e0%a6%ae%e0%a7%83%e0%a6%a4/"></a>
# <p class="time lead-time" style="color: #e6e6e6; margin-bottom:5px; font-size: 15px;"><i class="fa fa-clock-o"></i> <span>আপডেট ২ ঘন্টা আগে</span> </p>
# </div>
# </div>
# <!-- topnews -->
# <div class="col-md-3 col-sm-6 col-xs-12 col-md-3-custom">
# <div class="row">
# <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12" style="padding-bottom: 9px;">
# <div class="top-news has_img">
# <!--Loop 1-->
# <img alt="" class="img-responsive xs-100 wp-post-image" height="358" loading="lazy" src="http://www.sylhetexpress.com/wp-content/uploads/01-320-640x358.jpg" width="640"/> <div class="news-intro">
# <h3 class="heading front-hl" style="padding-bottom: 0px; margin-bottom: 0px;">পবিত্র আশুরা আজ </h3>
# </div>
# <a class="link-overlay" href="http://www.sylhetexpress.com/%e0%a6%aa%e0%a6%ac%e0%a6%bf%e0%a6%a4%e0%a7%8d%e0%a6%b0-%e0%a6%86%e0%a6%b6%e0%a7%81%e0%a6%b0%e0%a6%be-%e0%a6%86%e0%a6%9c/"></a>
# <!--Loop 1-->
# </div>
# </div>
# <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12" style="padding-top: 9px;">
# <div class="top-news has_img">
# <!--Loop 3-->
# <img alt="" class="img-responsive xs-100 wp-post-image" height="340" loading="lazy" sizes="(max-width: 600px) 100vw, 600px" src="http://www.sylhetexpress.com/wp-content/uploads/1ca8009189519988038260596aa839df.jpg" srcset="http://www.sylhetexpress.com/wp-content/uploads/1ca8009189519988038260596aa839df.jpg 600w, http://www.sylhetexpress.com/wp-content/uploads/1ca8009189519988038260596aa839df-300x170.jpg 300w, http://www.sylhetexpress.com/wp-content/uploads/1ca8009189519988038260596aa839df-150x85.jpg 150w" width="600"/> <div class="news-intro">
# <h3 class="heading front-hl" style="padding-bottom: 0px; margin-bottom: 0px;">ঝুনঝুনি চত্বর নিয়ে ফেসবুকে যা লিখলেন কাউন্সিলর কয়েস লোদী </h3>
# </div>
# <a class="link-overlay" href="http://www.sylhetexpress.com/%e0%a6%9d%e0%a7%81%e0%a6%a8%e0%a6%9d%e0%a7%81%e0%a6%a8%e0%a6%bf-%e0%a6%9a%e0%a6%a4%e0%a7%8d%e0%a6%ac%e0%a6%b0-%e0%a6%a8%e0%a6%bf%e0%a7%9f%e0%a7%87-%e0%a6%ab%e0%a7%87%e0%a6%b8%e0%a6%ac%e0%a7%81/"></a>
# <!--Loop 3-->
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-3 col-sm-6 col-xs-12 col-md-3-custom" style="padding-right: 12px;">
# <div class="row">
# <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12" style="padding-bottom: 9px;">
# <div class="top-news has_img">
# <!--Loop 2-->
# <img alt="" class="img-responsive xs-100 wp-post-image" height="358" loading="lazy" src="http://www.sylhetexpress.com/wp-content/uploads/Awa-1-640x358.jpg" width="640"/> <div class="news-intro">
# <h3 class="heading front-hl" style="padding-bottom: 0px; margin-bottom: 0px;">সিলেট জেলা আওয়ামী লীগের ২১ আগস্টের কর্মসূচি </h3>
# </div>
# <a class="link-overlay" href="http://www.sylhetexpress.com/%e0%a6%b8%e0%a6%bf%e0%a6%b2%e0%a7%87%e0%a6%9f-%e0%a6%9c%e0%a7%87%e0%a6%b2%e0%a6%be-%e0%a6%86%e0%a6%93%e0%a6%af%e0%a6%bc%e0%a6%be%e0%a6%ae%e0%a7%80-%e0%a6%b2%e0%a7%80%e0%a6%97%e0%a7%87%e0%a6%b0/"></a>
# <!--Loop 2-->
# </div>
# </div>
# <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12" style="padding-top: 9px;">
# <div class="top-news has_img">
# <!--Loop 4-->
# <img alt="" class="img-responsive xs-100 wp-post-image" height="358" loading="lazy" src="http://www.sylhetexpress.com/wp-content/uploads/005-35-640x358.jpg" width="640"/> <div class="news-intro">
# <h3 class="heading front-hl" style="padding-bottom: 0px; margin-bottom: 0px;">পররাষ্ট্রমন্ত্রীর উদ্যোগে ওসমানীতে অক্সিজেন প্লান্ট স্থাপনে ২ কোটি টাকা বরাদ্দ </h3>
# </div>
# <a class="link-overlay" href="http://www.sylhetexpress.com/%e0%a6%aa%e0%a6%b0%e0%a6%b0%e0%a6%be%e0%a6%b7%e0%a7%8d%e0%a6%9f%e0%a7%8d%e0%a6%b0%e0%a6%ae%e0%a6%a8%e0%a7%8d%e0%a6%a4%e0%a7%8d%e0%a6%b0%e0%a7%80%e0%a6%b0-%e0%a6%89%e0%a6%a6%e0%a7%8d%e0%a6%af%e0%a7%8b/"></a>
# <!--Loop 4-->
# </div>
# </div>
# </div>
# </div>
# </div>
# <!--/row-->
# </img></div>
# <!--/container-->
# </div>
# <!--/bg-white-->
# <!--------------------- Front News ---------------------------->
# <div class="bg-white" style="padding-bottom: 0px; padding-top: 15px;">
# <div class="container">
# <!--Notable Category News-->
# <div class="row" style="margin-top: 4px;">
# <div class="col-lg-12 col-md-12 col-sm-12">
# <div class="category-lbl-card" style="border-bottom: 2px solid #3c3c3c;"><a class="pull-left category-lbl" href="http://www.sylhetexpress.com/category/notable" style="background-color: #3c3c3c;"><strong>উল্লেখযোগ্য</strong></a>
# <a class="pull-right category-all-news" href="http://www.sylhetexpress.com/category/notable" style="color: #3c3c3c"><strong>আরও <i aria-hidden="true" class="fa fa-angle-double-right"></i></strong></a>
# </div>
# <div class="row res-sm first3-md-gap-parent">
# <div class="col-lg-3 col-md-3 col-sm-6 col-xs-6 res-xs-btm res-sm-btm first3-md-gap">
# <div class="news-content" style="background-color: #F2F2F2; min-height: 250px;">
# <img alt="" class="img-responsive img-btm wp-post-image" height="358" loading="lazy" src="http://www.sylhetexpress.com/wp-content/uploads/news_image_16-640x358.jpg" width="640"/> <div class="info">
# <h3 class="heading" style="">সিলেটে একদিনে করোনায় মৃত্যু ও শনাক্ত কিছুটা কমেছে</h3>
# </div>
# <a class="link-overlay" href="http://www.sylhetexpress.com/%e0%a6%b8%e0%a6%bf%e0%a6%b2%e0%a7%87%e0%a6%9f%e0%a7%87-%e0%a6%8f%e0%a6%95%e0%a6%a6%e0%a6%bf%e0%a6%a8%e0%a7%87-%e0%a6%95%e0%a6%b0%e0%a7%8b%e0%a6%a8%e0%a6%be%e0%a7%9f-%e0%a6%ae%e0%a7%83%e0%a6%a4/"></a>
# <p class="time"><i class="fa fa-clock-o"></i> <span>আপডেট ২ ঘন্টা আগে</span> </p>
# </div>
# </div>
# <div class="col-lg-3 col-md-3 col-sm-6 col-xs-6 res-xs-btm res-sm-btm first3-md-gap">
# <div class="news-content" style="background-color: #F2F2F2; min-height: 250px;">
# <img alt="" class="img-responsive img-btm wp-post-image" height="358" loading="lazy" src="http://www.sylhetexpress.com/wp-content/uploads/01-320-640x358.jpg" width="640"/> <div class="info">
# <h3 class="heading" style="">পবিত্র আশুরা আজ</h3>
# </div>
# <a class="link-overlay" href="http://www.sylhetexpress.com/%e0%a6%aa%e0%a6%ac%e0%a6%bf%e0%a6%a4%e0%a7%8d%e0%a6%b0-%e0%a6%86%e0%a6%b6%e0%a7%81%e0%a6%b0%e0%a6%be-%e0%a6%86%e0%a6%9c/"></a>
# <p class="time"><i class="fa fa-clock-o"></i> <span>আপডেট ৩ ঘন্টা আগে</span> </p>
# </div>
# </div>
# <div class="col-lg-3 col-md-3 col-sm-6 col-xs-6 res-xs-btm res-sm-btm first3-md-gap">
# <div class="news-content" style="background-color: #F2F2F2; min-height: 250px;">
# <img alt="" class="img-responsive img-btm wp-post-image" height="358" loading="lazy" src="http://www.sylhetexpress.com/wp-content/uploads/Awa-1-640x358.jpg" width="640"/> <div class="info">
# <h3 class="heading" style="">সিলেট জেলা আওয়ামী লীগের ২১ আগস্টের কর্মসূচি</h3>
# </div>
# <a class="link-overlay" href="http://www.sylhetexpress.com/%e0%a6%b8%e0%a6%bf%e0%a6%b2%e0%a7%87%e0%a6%9f-%e0%a6%9c%e0%a7%87%e0%a6%b2%e0%a6%be-%e0%a6%86%e0%a6%93%e0%a6%af%e0%a6%bc%e0%a6%be%e0%a6%ae%e0%a7%80-%e0%a6%b2%e0%a7%80%e0%a6%97%e0%a7%87%e0%a6%b0/"></a>
# <p class="time"><i class="fa fa-clock-o"></i> <span>আপডেট ৩ ঘন্টা আগে</span> </p>
# </div>
# </div>
# <div class="col-lg-3 col-md-3 col-sm-6 col-xs-6 res-xs-btm res-sm-btm first3-md-gap">
# <div class="news-content" style="background-color: #F2F2F2; min-height: 250px;">
# <img alt="" class="img-responsive img-btm wp-post-image" height="340" loading="lazy" sizes="(max-width: 600px) 100vw, 600px" src="http://www.sylhetexpress.com/wp-content/uploads/1ca8009189519988038260596aa839df.jpg" srcset="http://www.sylhetexpress.com/wp-content/uploads/1ca8009189519988038260596aa839df.jpg 600w, http://www.sylhetexpress.com/wp-content/uploads/1ca8009189519988038260596aa839df-300x170.jpg 300w, http://www.sylhetexpress.com/wp-content/uploads/1ca8009189519988038260596aa839df-150x85.jpg 150w" width="600"/> <div class="info">
# <h3 class="heading" style="">ঝুনঝুনি চত্বর নিয়ে ফেসবুকে যা লিখলেন কাউন্সিলর কয়েস লোদী</h3>
# </div>
# <a class="link-overlay" href="http://www.sylhetexpress.com/%e0%a6%9d%e0%a7%81%e0%a6%a8%e0%a6%9d%e0%a7%81%e0%a6%a8%e0%a6%bf-%e0%a6%9a%e0%a6%a4%e0%a7%8d%e0%a6%ac%e0%a6%b0-%e0%a6%a8%e0%a6%bf%e0%a7%9f%e0%a7%87-%e0%a6%ab%e0%a7%87%e0%a6%b8%e0%a6%ac%e0%a7%81/"></a>
# <p class="time"><i class="fa fa-clock-o"></i> <span>আপডেট ৯ ঘন্টা আগে</span> </p>
# </div>
# </div>
# </div>
# <div class="row res-sm first3-md-gap-parent">
# <div class="col-lg-3 col-md-3 col-sm-6 col-xs-6 res-xs-btm res-sm-btm first3-md-gap">
# <div class="news-content" style="background-color: #F2F2F2; min-height: 250px;">
# <img alt="" class="img-responsive img-btm wp-post-image" height="340" loading="lazy" sizes="(max-width: 600px) 100vw, 600px" src="http://www.sylhetexpress.com/wp-content/uploads/8cda81fc7ad906927144235dda5fdf15.jpg" srcset="http://www.sylhetexpress.com/wp-content/uploads/8cda81fc7ad906927144235dda5fdf15.jpg 600w, http://www.sylhetexpress.com/wp-content/uploads/8cda81fc7ad906927144235dda5fdf15-300x170.jpg 300w, http://www.sylhetexpress.com/wp-content/uploads/8cda81fc7ad906927144235dda5fdf15-150x85.jpg 150w" width="600"/> <div class="info">
# <h3 class="heading" style="">সিলেটবাসীর কাছে দোয়া চেয়েছেন  আবহাওয়াবিদ সাঈদ চৌধুরী</h3>
# </div>
# <a class="link-overlay" href="http://www.sylhetexpress.com/%e0%a6%b8%e0%a6%bf%e0%a6%b2%e0%a7%87%e0%a6%9f%e0%a6%ac%e0%a6%be%e0%a6%b8%e0%a7%80%e0%a6%b0-%e0%a6%a6%e0%a7%8b%e0%a7%9f%e0%a6%be-%e0%a6%9a%e0%a7%87%e0%a7%9f%e0%a7%87%e0%a6%9b%e0%a7%87%e0%a6%a8/"></a>
# <p class="time"><i class="fa fa-clock-o"></i> <span>আপডেট ২৪ ঘন্টা আগে</span> </p>
# </div>
# </div>
# <div class="col-lg-3 col-md-3 col-sm-6 col-xs-6 res-xs-btm res-sm-btm first3-md-gap">
# <div class="news-content" style="background-color: #F2F2F2; min-height: 250px;">
# <img alt="" class="img-responsive img-btm wp-post-image" height="358" loading="lazy" src="http://www.sylhetexpress.com/wp-content/uploads/005-35-640x358.jpg" width="640"/> <div class="info">
# <h3 class="heading" style="">পররাষ্ট্রমন্ত্রীর উদ্যোগে ওসমানীতে অক্সিজেন প্লান্ট স্থাপনে ২ কোটি টাকা বরাদ্দ</h3>
# </div>
# <a class="link-overlay" href="http://www.sylhetexpress.com/%e0%a6%aa%e0%a6%b0%e0%a6%b0%e0%a6%be%e0%a6%b7%e0%a7%8d%e0%a6%9f%e0%a7%8d%e0%a6%b0%e0%a6%ae%e0%a6%a8%e0%a7%8d%e0%a6%a4%e0%a7%8d%e0%a6%b0%e0%a7%80%e0%a6%b0-%e0%a6%89%e0%a6%a6%e0%a7%8d%e0%a6%af%e0%a7%8b/"></a>
# <p class="time"><i class="fa fa-clock-o"></i> <span>আপডেট ১ দিন আগে</span> </p>
# </div>
# </div>
# <div class="col-lg-3 col-md-3 col-sm-6 col-xs-6 res-xs-btm res-sm-btm first3-md-gap">
# <div class="news-content" style="background-color: #F2F2F2; min-height: 250px;">
# <img alt="" class="img-responsive img-btm wp-post-image" height="358" loading="lazy" src="http://www.sylhetexpress.com/wp-content/uploads/1-832-640x358.jpg" width="640"/> <div class="info">
# <h3 class="heading" style="">শনিবার থেকে মঙ্গলবার পর্যন্ত নগরীর যেসব এলাকায় বিদ্যুৎ থাকবে না</h3>
# </div>
# <a class="link-overlay" href="http://www.sylhetexpress.com/%e0%a6%b6%e0%a6%a8%e0%a6%bf%e0%a6%ac%e0%a6%be%e0%a6%b0-%e0%a6%a5%e0%a7%87%e0%a6%95%e0%a7%87-%e0%a6%ae%e0%a6%99%e0%a7%8d%e0%a6%97%e0%a6%b2%e0%a6%ac%e0%a6%be%e0%a6%b0-%e0%a6%aa%e0%a6%b0%e0%a7%8d/"></a>
# <p class="time"><i class="fa fa-clock-o"></i> <span>আপডেট ১ দিন আগে</span> </p>
# </div>
# </div>
# <div class="col-lg-3 col-md-3 col-sm-6 col-xs-6 res-xs-btm res-sm-btm first3-md-gap">
# <div class="news-content" style="background-color: #F2F2F2; min-height: 250px;">
# <img alt="" class="img-responsive img-btm wp-post-image" height="302" loading="lazy" sizes="(max-width: 500px) 100vw, 500px" src="http://www.sylhetexpress.com/wp-content/uploads/19-116.jpg" srcset="http://www.sylhetexpress.com/wp-content/uploads/19-116.jpg 500w, http://www.sylhetexpress.com/wp-content/uploads/19-116-300x181.jpg 300w, http://www.sylhetexpress.com/wp-content/uploads/19-116-150x91.jpg 150w" width="500"/> <div class="info">
# <h3 class="heading" style="">হেফাজতে ইসলামের আমির আল্লামা জুনায়েদ বাবুনগরী আর নেই</h3>
# </div>
# <a class="link-overlay" href="http://www.sylhetexpress.com/%e0%a6%b9%e0%a7%87%e0%a6%ab%e0%a6%be%e0%a6%9c%e0%a6%a4%e0%a7%87-%e0%a6%87%e0%a6%b8%e0%a6%b2%e0%a6%be%e0%a6%ae%e0%a7%87%e0%a6%b0-%e0%a6%86%e0%a6%ae%e0%a6%bf%e0%a6%b0-%e0%a6%86%e0%a6%b2%e0%a7%8d/"></a>
# <p class="time"><i class="fa fa-clock-o"></i> <span>আপডেট ১ দিন আগে</span> </p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!--Notable Category News-->
# <div class="row">
# <div class="col-lg-9 col-md-9 col-sm-12 col-xs-12">
# <!--advertisement-->
# <div class="row">
# <div class="col-sm-12">
# <div class="adv text-center" style="margin-bottom: 23px;">
# <aside class="widget widget_text" id="text-4"> <div class="textwidget"></div>
# </aside> </div>
# </div>
# </div>
# <!--advertisement-->
# <!--sylhet category news-->
# <div class="row flex-row" style="">
# <div class="col-md-4 col-sm-6 col-xs-12 front-news flex-col" style="">
# <div class="news-content xs-100" style="background-color: #f6f6f6;">
# <img alt="" class="img-responsive xs-100 wp-post-image" height="233" loading="lazy" sizes="(max-width: 400px) 100vw, 400px" src="http://www.sylhetexpress.com/wp-content/uploads/99-18.jpg" srcset="http://www.sylhetexpress.com/wp-content/uploads/99-18.jpg 400w, http://www.sylhetexpress.com/wp-content/uploads/99-18-300x175.jpg 300w, http://www.sylhetexpress.com/wp-content/uploads/99-18-150x87.jpg 150w" width="400"/> <div class="info">
# <h3 class="heading front-hl" style="margin-bottom:0px;"><span>জন্মদিনে ভালবাসায় সিক্ত সাংবাদিক তানভীর</span></h3>
# <p class="summary">  ছাতক প্রতিনিধি: সুনামগঞ্জের ছাতক অনলাইন প্রেসক্লাবের সদস্য সচিব, দৈনিক...</p>
# </div>
# <a class="link-overlay" href="http://www.sylhetexpress.com/%e0%a6%9c%e0%a6%a8%e0%a7%8d%e0%a6%ae%e0%a6%a6%e0%a6%bf%e0%a6%a8%e0%a7%87-%e0%a6%ad%e0%a6%be%e0%a6%b2%e0%a6%ac%e0%a6%be%e0%a6%b8%e0%a6%be%e0%a7%9f-%e0%a6%b8%e0%a6%bf%e0%a6%95%e0%a7%8d%e0%a6%a4/"></a>
# <p class="time"><i class="fa fa-clock-o"></i> <span>আপডেট ২৩ ঘন্টা আগে</span> </p>
# </div>
# </div>
# <div class="col-md-4 col-sm-6 col-xs-12 front-news flex-col" style="">
# <div class="news-content xs-100" style="background-color: #f6f6f6;">
# <img alt="" class="img-responsive xs-100 wp-post-image" height="358" loading="lazy" src="http://www.sylhetexpress.com/wp-content/uploads/Sylhet-CSR-Cp-640x358.jpg" width="640"/> <div class="info">
# <h3 class="heading front-hl" style="margin-bottom:0px;"><span>সিলেটে আজ ‘সিএসআর সংলাপ’</span></h3>
# <p class="summary">এক্সপ্রেস ডেস্ক ঃ- বেসরকারি খাতের প্রতিষ্ঠানগুলোর সামাজিক দায়বদ্ধতা কর্মসূচিসমূহ যেগুলো...</p>
# </div>
# <a class="link-overlay" href="http://www.sylhetexpress.com/%e0%a6%b8%e0%a6%bf%e0%a6%b2%e0%a7%87%e0%a6%9f%e0%a7%87-%e0%a6%86%e0%a6%9c-%e0%a6%b8%e0%a6%bf%e0%a6%8f%e0%a6%b8%e0%a6%86%e0%a6%b0-%e0%a6%b8%e0%a6%82%e0%a6%b2%e0%a6%be%e0%a6%aa/"></a>
# <p class="time"><i class="fa fa-clock-o"></i> <span>আপডেট ১ দিন আগে</span> </p>
# </div>
# </div>
# <div class="col-md-4 col-sm-6 col-xs-12 front-news flex-col" style="">
# <div class="news-content xs-100" style="background-color: #f6f6f6;">
# <img alt="" class="img-responsive xs-100 wp-post-image" height="337" loading="lazy" sizes="(max-width: 600px) 100vw, 600px" src="http://www.sylhetexpress.com/wp-content/uploads/allama-babunogoir.jpg" srcset="http://www.sylhetexpress.com/wp-content/uploads/allama-babunogoir.jpg 600w, http://www.sylhetexpress.com/wp-content/uploads/allama-babunogoir-300x169.jpg 300w, http://www.sylhetexpress.com/wp-content/uploads/allama-babunogoir-150x84.jpg 150w" width="600"/> <div class="info">
# <h3 class="heading front-hl" style="margin-bottom:0px;"><span>হেফাজত আমীরের মৃত্যুতে জমিয়তের শোক</span></h3>
# <p class="summary">হেফাজতে ইসলাম বাংলাদেশের আমীর, দারুল উলূম ময়নুল ইসলাম হাটহাজারীর মহাপরিচালক,...</p>
# </div>
# <a class="link-overlay" href="http://www.sylhetexpress.com/%e0%a6%b9%e0%a7%87%e0%a6%ab%e0%a6%be%e0%a6%9c%e0%a6%a4-%e0%a6%86%e0%a6%ae%e0%a7%80%e0%a6%b0%e0%a7%87%e0%a6%b0-%e0%a6%ae%e0%a7%83%e0%a6%a4%e0%a7%8d%e0%a6%af%e0%a7%81%e0%a6%a4%e0%a7%87-%e0%a6%9c/"></a>
# <p class="time"><i class="fa fa-clock-o"></i> <span>আপডেট ১ দিন আগে</span> </p>
# </div>
# </div>
# <div class="col-md-4 col-sm-6 col-xs-12 front-news flex-col" style="">
# <div class="news-content xs-100" style="background-color: #f6f6f6;">
# <img alt="" class="img-responsive xs-100 wp-post-image" height="297" loading="lazy" sizes="(max-width: 500px) 100vw, 500px" src="http://www.sylhetexpress.com/wp-content/uploads/21-141.jpg" srcset="http://www.sylhetexpress.com/wp-content/uploads/21-141.jpg 500w, http://www.sylhetexpress.com/wp-content/uploads/21-141-300x178.jpg 300w, http://www.sylhetexpress.com/wp-content/uploads/21-141-150x89.jpg 150w" width="500"/> <div class="info">
# <h3 class="heading front-hl" style="margin-bottom:0px;"><span>সিলেট বিভাগ পরিদর্শনে আনসার-ভিডিপির মহাপরিচালক মেজর জেনারেল শামীম</span></h3>
# <p class="summary">বাংলাদেশ আনসার গ্রাম প্রতিরক্ষা বাহিনীর মহাপরিচালক মেজর জেনারেল মিজানুর রহমান...</p>
# </div>
# <a class="link-overlay" href="http://www.sylhetexpress.com/%e0%a6%b8%e0%a6%bf%e0%a6%b2%e0%a7%87%e0%a6%9f-%e0%a6%ac%e0%a6%bf%e0%a6%ad%e0%a6%be%e0%a6%97-%e0%a6%aa%e0%a6%b0%e0%a6%bf%e0%a6%a6%e0%a6%b0%e0%a7%8d%e0%a6%b6%e0%a6%a8%e0%a7%87-%e0%a6%86%e0%a6%a8/"></a>
# <p class="time"><i class="fa fa-clock-o"></i> <span>আপডেট ১ দিন আগে</span> </p>
# </div>
# </div>
# <div class="col-md-4 col-sm-6 col-xs-12 front-news flex-col" style="">
# <div class="news-content xs-100" style="background-color: #f6f6f6;">
# <img alt="" class="img-responsive xs-100 wp-post-image" height="272" loading="lazy" sizes="(max-width: 500px) 100vw, 500px" src="http://www.sylhetexpress.com/wp-content/uploads/17-173.jpg" srcset="http://www.sylhetexpress.com/wp-content/uploads/17-173.jpg 500w, http://www.sylhetexpress.com/wp-content/uploads/17-173-300x163.jpg 300w, http://www.sylhetexpress.com/wp-content/uploads/17-173-150x82.jpg 150w" width="500"/> <div class="info">
# <h3 class="heading front-hl" style="margin-bottom:0px;"><span>সিলেটে হাজী আব্দুন নূর সহুরুজ্জামান ফাউন্ডেশনের ফ্রি অক্সিজেন সার্ভিস চালু</span></h3>
# <p class="summary">সিলেটে হাজী আব্দুন নূর (সহুরুজ্জামান) ফাউন্ডেশন এর উদ্যাগে ১৭নং ওয়ার্ডে...</p>
# </div>
# <a class="link-overlay" href="http://www.sylhetexpress.com/%e0%a6%b8%e0%a6%bf%e0%a6%b2%e0%a7%87%e0%a6%9f%e0%a7%87-%e0%a6%b9%e0%a6%be%e0%a6%9c%e0%a7%80-%e0%a6%86%e0%a6%ac%e0%a7%8d%e0%a6%a6%e0%a7%81%e0%a6%a8-%e0%a6%a8%e0%a7%82%e0%a6%b0-%e0%a6%b8%e0%a6%b9/"></a>
# <p class="time"><i class="fa fa-clock-o"></i> <span>আপডেট ১ দিন আগে</span> </p>
# </div>
# </div>
# <div class="col-md-4 col-sm-6 col-xs-12 front-news flex-col" style="">
# <div class="news-content xs-100" style="background-color: #f6f6f6;">
# <img class="img-responsive xs-100" src="http://www.sylhetexpress.com/wp-content/themes/sylhet-expresss/images/post.jpg"/> <div class="info">
# ...
# <div class="v-icon1 xs-v-icon"><i aria-hidden="true" class="fa fa-video-camera fa-1x"></i></div>
# </div>
# <div class="v-info hidden-xs">
# <a class="v-caption" href="http://www.sylhetexpress.com/%e0%a6%ac%e0%a6%87-%e0%a6%86%e0%a6%b2%e0%a7%8b%e0%a6%9a%e0%a6%a8%e0%a6%be-%e0%a6%97%e0%a6%ac%e0%a7%87%e0%a6%b7%e0%a6%95-%e0%a6%ab%e0%a6%be%e0%a6%b0%e0%a7%81%e0%a6%95-%e0%a6%86%e0%a6%b9%e0%a6%ae/">বই আলোচনা : গবেষক ফারুক আহমদের গোলাপগঞ্জের ইতিহাস</a>
# </div>
# <p class="v-category"><span style="color: #6c4813; border-bottom: 1px solid #6c4813; ">বাংলাদেশ</span></p>
# </li>
# <li class="lslide" style="width: 223.25px; margin-right: 10px;">
# <div class="v-img" style="padding-bottom: 5px;">
# <a href="http://www.sylhetexpress.com/%e0%a6%b6%e0%a6%be%e0%a6%a8%e0%a7%8d%e0%a6%a4%e0%a6%bf%e0%a6%a4%e0%a7%87-%e0%a6%ac%e0%a6%bf%e0%a6%9c%e0%a6%af%e0%a6%bc-%e0%a6%b6%e0%a6%be%e0%a6%a8%e0%a7%8d%e0%a6%a4%e0%a6%bf-%e0%a6%9c/"><img alt="" class="img-responsive wp-post-image" height="358" loading="lazy" src="http://www.sylhetexpress.com/wp-content/uploads/74-3-640x358.jpg" width="640"/></a>
# <div class="v-icon1 xs-v-icon"><i aria-hidden="true" class="fa fa-video-camera fa-1x"></i></div>
# </div>
# <div class="v-info hidden-xs">
# <a class="v-caption" href="http://www.sylhetexpress.com/%e0%a6%b6%e0%a6%be%e0%a6%a8%e0%a7%8d%e0%a6%a4%e0%a6%bf%e0%a6%a4%e0%a7%87-%e0%a6%ac%e0%a6%bf%e0%a6%9c%e0%a6%af%e0%a6%bc-%e0%a6%b6%e0%a6%be%e0%a6%a8%e0%a7%8d%e0%a6%a4%e0%a6%bf-%e0%a6%9c/">‘শান্তিতে বিজয়, শান্তি জিতলে জিতবে দেশ’ শীর্ষক রাজনৈতিক সংলাপ Sylhet Surma TV | সিলেট সুরমা টিভি</a>
# </div>
# <p class="v-category"><span style="color: #6c4813; border-bottom: 1px solid #6c4813; ">বাংলাদেশ</span></p>
# </li>
# <li class="lslide" style="width: 223.25px; margin-right: 10px;">
# <div class="v-img" style="padding-bottom: 5px;">
# <a href="http://www.sylhetexpress.com/%e0%a6%a1%e0%a6%bf%e0%a6%86%e0%a6%87-%e0%a6%86%e0%a6%af%e0%a6%bc%e0%a7%8b%e0%a6%9c%e0%a6%bf%e0%a6%a4-%e0%a6%b6%e0%a6%be%e0%a6%a8%e0%a7%8d%e0%a6%a4%e0%a6%bf%e0%a6%a4%e0%a7%87-%e0%a6%ac%e0%a6%bf/"><img alt="" class="img-responsive wp-post-image" height="358" loading="lazy" src="http://www.sylhetexpress.com/wp-content/uploads/14-9-600x358.jpg" width="600"/></a>
# <div class="v-icon1 xs-v-icon"><i aria-hidden="true" class="fa fa-video-camera fa-1x"></i></div>
# </div>
# <div class="v-info hidden-xs">
# <a class="v-caption" href="http://www.sylhetexpress.com/%e0%a6%a1%e0%a6%bf%e0%a6%86%e0%a6%87-%e0%a6%86%e0%a6%af%e0%a6%bc%e0%a7%8b%e0%a6%9c%e0%a6%bf%e0%a6%a4-%e0%a6%b6%e0%a6%be%e0%a6%a8%e0%a7%8d%e0%a6%a4%e0%a6%bf%e0%a6%a4%e0%a7%87-%e0%a6%ac%e0%a6%bf/">ডি,আই আয়োজিত শান্তিতে বিজয় আলোচনায়-এড.মিসবাহ উদ্দিন সিরাজ</a>
# </div>
# <p class="v-category"><span style="color: #6c4813; border-bottom: 1px solid #6c4813; ">বাংলাদেশ</span></p>
# </li>
# <li class="lslide" style="width: 223.25px; margin-right: 10px;">
# <div class="v-img" style="padding-bottom: 5px;">
# <a href="http://www.sylhetexpress.com/14396/"><img alt="" class="img-responsive wp-post-image" height="90" loading="lazy" src="http://www.sylhetexpress.com/wp-content/uploads/3-1-1.jpg" width="120"/></a>
# <div class="v-icon1 xs-v-icon"><i aria-hidden="true" class="fa fa-video-camera fa-1x"></i></div>
# </div>
# <div class="v-info hidden-xs">
# <a class="v-caption" href="http://www.sylhetexpress.com/14396/">গ্রেনেড হামলা মামলার রায়কে স্বাগত জানিয়ে আওয়ামীলীগের মিছিল</a>
# </div>
# <p class="v-category"><span style="color: #6c4813; border-bottom: 1px solid #6c4813; ">বাংলাদেশ</span></p>
# </li>
# </ul>
# <div class="lSAction"><a class="lSPrev"></a><a class="lSNext"></a></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="bg-white">
# <div class="container">
# <div class="row">
# <div class="col-md-9 col-md-9-custom">
# <!-- magazines news -->
# <div class="row">
# <div class="col-md-12 col-xs-12 col-sm-12">
# <div class="category-lbl-card" style="border-bottom: 2px solid #1d441c;"><a class="pull-left category-lbl" href="http://www.sylhetexpress.com/category/writings" style="background-color: #1d441c;"><strong>লেখালেখি</strong></a>
# <a class="pull-right category-all-news" href="http://www.sylhetexpress.com/category/writings" style="color: #1d441c"><strong>আরও  <i aria-hidden="true" class="fa fa-angle-double-right"></i></strong></a>
# </div>
# <div class="row flex-row">
# <div class="col-lg-6 col-md-6 flex-col">
# <div class="news-content" style="background-color: #F2F2F2;">
# <img alt="" class="img-responsive wp-post-image" height="358" loading="lazy" src="http://www.sylhetexpress.com/wp-content/uploads/238275333_10208490498496226_9045320353164246266_n-640x358.jpg" style="width: 100%" width="640"/>
# <div class="info">
# <h3 class="heading" style="margin-bottom: 0px;">হেলাল উদ্দীন রানার প্রতিবেদনে ফুটে উঠে শিল্পময় ব্যঞ্জনা</h3>
# <p class="summary">সাঈদ চৌধুরী : সাংবাদিক ও সাহিত্যিক হেলাল উদ্দীন রানা একজন নিরলস সত্যসন্ধানী লেখক। কর্মসূত্রে আপাদমস্তক...</p>
# </div>
# <a class="link-overlay" href="http://www.sylhetexpress.com/%e0%a6%b9%e0%a7%87%e0%a6%b2%e0%a6%be%e0%a6%b2-%e0%a6%89%e0%a6%a6%e0%a7%8d%e0%a6%a6%e0%a7%80%e0%a6%a8-%e0%a6%b0%e0%a6%be%e0%a6%a8%e0%a6%be%e0%a6%b0-%e0%a6%aa%e0%a7%8d%e0%a6%b0%e0%a6%a4%e0%a6%bf/"></a>
# <p class="time"><i class="fa fa-clock-o"></i> <span>আপডেট ১ দিন আগে</span> </p>
# </div>
# </div>
# <div class="col-lg-6 col-md-6 flex-col">
# <div style="background-color: #F2F2F2;">
# <ul class="category_news_list first-li first-media">
# <li class="" style="padding: 10px 0px;">
# <div class="media" style="padding: 0px 0px;">
# <a class="link-overlay" href="http://www.sylhetexpress.com/%e0%a6%86%e0%a6%ab%e0%a6%97%e0%a6%be%e0%a6%a8%e0%a6%bf%e0%a6%b8%e0%a7%8d%e0%a6%a4%e0%a6%be%e0%a6%a8-%e0%a6%86%e0%a6%ae%e0%a6%be%e0%a6%a6%e0%a7%87%e0%a6%b0-%e0%a6%b6%e0%a6%bf%e0%a6%95%e0%a7%8d/"></a>
# <div class="media-left vicon-parent">
# <img alt="" class="media-object wp-post-image" height="358" loading="lazy" src="http://www.sylhetexpress.com/wp-content/uploads/02-198-640x358.jpg" style="width: 115px; height: auto;" width="640"/>
# </div>
# <div class="media-body">
# <h4 class="media-heading">আফগানিস্তান: আমাদের শিক্ষা ও প্রত্যাশা</h4>
# </div>
# </div>
# <p class="time" style="margin-left: 124px;left: 0;bottom: 0;right: 0;position: absolute;"><i class="fa fa-clock-o"></i> <span>আপডেট ৩ দিন আগে</span> </p>
# </li>
# <li class="" style="padding: 10px 0px;">
# <div class="media" style="padding: 0px 0px;">
# <a class="link-overlay" href="http://www.sylhetexpress.com/%e0%a6%b8%e0%a7%8b%e0%a6%a8%e0%a6%be%e0%a6%b2%e0%a7%80-%e0%a6%b8%e0%a6%ae%e0%a7%9f/"></a>
# <div class="media-left vicon-parent">
# <img alt="" class="media-object wp-post-image" height="336" loading="lazy" sizes="(max-width: 400px) 100vw, 400px" src="http://www.sylhetexpress.com/wp-content/uploads/88-18.jpg" srcset="http://www.sylhetexpress.com/wp-content/uploads/88-18.jpg 400w, http://www.sylhetexpress.com/wp-content/uploads/88-18-300x252.jpg 300w, http://www.sylhetexpress.com/wp-content/uploads/88-18-150x126.jpg 150w" style="width: 115px; height: auto;" width="400"/>
# </div>
# <div class="media-body">
# <h4 class="media-heading">সোনালী সময়</h4>
# </div>
# </div>
# <p class="time" style="margin-left: 124px;left: 0;bottom: 0;right: 0;position: absolute;"><i class="fa fa-clock-o"></i> <span>আপডেট ১ সপ্তাহ আগে</span> </p>
# </li>
# <li class="" style="padding: 10px 0px;">
# <div class="media" style="padding: 0px 0px;">
# <a class="link-overlay" href="http://www.sylhetexpress.com/%e0%a6%85%e0%a6%a8%e0%a6%be%e0%a6%95%e0%a6%be%e0%a6%99%e0%a7%8d%e0%a6%95%e0%a7%8d%e0%a6%b7%e0%a6%bf%e0%a6%a4-%e0%a6%ab%e0%a6%b2/"></a>
# <div class="media-left vicon-parent">
# <img class="media-object" src="http://www.sylhetexpress.com/wp-content/themes/sylhet-expresss/images/post.jpg" style="width:115px; height: auto"/>
# </div>
# <div class="media-body">
# <h4 class="media-heading">অনাকাঙ্ক্ষিত ফল</h4>
# </div>
# </div>
# <p class="time" style="margin-left: 124px;left: 0;bottom: 0;right: 0;position: absolute;"><i class="fa fa-clock-o"></i> <span>আপডেট ১ সপ্তাহ আগে</span> </p>
# </li>
# <li class="" style="padding: 10px 0px;">
# <div class="media" style="padding: 0px 0px;">
# <a class="link-overlay" href="http://www.sylhetexpress.com/%e0%a6%b8%e0%a6%be%e0%a6%a6%e0%a6%be-%e0%a6%aa%e0%a6%be%e0%a6%a5%e0%a6%b0%e0%a7%87%e0%a6%b0-%e0%a6%b6%e0%a7%8b%e0%a6%ad%e0%a6%be/"></a>
# <div class="media-left vicon-parent">
# <img alt="" class="media-object wp-post-image" height="358" loading="lazy" sizes="(max-width: 640px) 100vw, 640px" src="http://www.sylhetexpress.com/wp-content/uploads/228427692_4548527661880829_3813162610841700580_n-640x358.jpg" srcset="http://www.sylhetexpress.com/wp-content/uploads/228427692_4548527661880829_3813162610841700580_n-640x358.jpg 640w, http://www.sylhetexpress.com/wp-content/uploads/228427692_4548527661880829_3813162610841700580_n-300x169.jpg 300w, http://www.sylhetexpress.com/wp-content/uploads/228427692_4548527661880829_3813162610841700580_n-150x84.jpg 150w" style="width: 115px; height: auto;" width="640"/>
# </div>
# <div class="media-body">
# <h4 class="media-heading">সাদা পাথরের শোভা</h4>
# </div>
# </div>
# <p class="time" style="margin-left: 124px;left: 0;bottom: 0;right: 0;position: absolute;"><i class="fa fa-clock-o"></i> <span>আপডেট ১ সপ্তাহ আগে</span> </p>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- end lifestyle news -->
# </div>
# <div class="col-md-3 col-md-3-custom1">
# <div class="advertisement">
# <!-- advertisement -->
# <div class="adv text-center hidden-xs hidden-sm" style="margin:10px; overflow:hidden;">
# </div>
# <!-- advertisement  end -->
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="container">
# <div class="adv text-center" style="margin-top: 12px;">
# </div>
# </div>
#
# <footer>
# <div class="footer-1" style="">
# <div class="container">
# <div class="row">
# <div class="col-md-6 col-sm-6 hidden-xs footer-logo">
# <img alt="The Daily Sylhet Express" class="img-responsive" src="http://www.sylhetexpress.com/wp-content/themes/sylhet-expresss/images/logo-footer.png" style="width: 200px;" title="The Daily Sylhet Express"/>
# </div>
# <div class="col-md-3 col-sm-6 col-xs-12 download-text">
# <a class="dmca-badge" href="//www.dmca.com/Protection/Status.aspx?ID=b14d3292-6192-4e85-a0c7-598be2fe9eb3" title="DMCA.com Protection Status"> <img alt="DMCA.com Protection Status" src="//images.dmca.com/Badges/dmca-badge-w250-5x1-11.png?ID=b14d3292-6192-4e85-a0c7-598be2fe9eb3"/></a> <script src="//images.dmca.com/Badges/DMCABadgeHelper.min.js"> </script>
# </div>
# <div class="col-md-3 col-sm-6 col-xs-12">
# <div class="social-media">
# <ul class="list-unstyled list-inline">
# <li><a href="http://www.sylhetexpress.com/sylhet_express_apps.apk" style="text-decoration: none;" target="_blank" title="Sylhet Express App"><i aria-hidden="true" class="fa fa-android fa-2x"></i></a></li>
# <li><a href="https://www.facebook.com/sylhetexpress.news" target="_blank" title="Sylhet Express Face Book Page"><i aria-hidden="true" class="fa fa-facebook fa-2x"></i></a></li>
# <li><a href="https://www.youtube.com/channel/UCTEc3ZluT8OE21bWVFFmCuA" target="_blank" title="Sylhet Express Youtube"><i aria-hidden="true" class="fa fa-youtube fa-2x"></i></a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="line-white"></div>
# <div class="footer-2">
# <div class="container">
# <div class="footer-menu-div">
# <div class="row">
# <div class="col-xs-12">
# <ul class="list-unstyled list-inline footer-menu-list">
# <li><a href="http://www.sylhetexpress.com/category/bangladesh">সিলেট</a></li>
# <li><a href="http://www.sylhetexpress.com/category/politics">মৌলভীবাজার</a></li>
# <li><a href="http://www.sylhetexpress.com/category/economics">হবিগঞ্জ</a></li>
# <li><a href="http://www.sylhetexpress.com/category/international">সুনামগঞ্জ</a></li>
# <li><a href="http://www.sylhetexpress.com/category/politics">রাজনীতি</a></li>
# <li><a href="http://www.sylhetexpress.com/category/law-crime">আইন-অপরাধ</a></li>
# <li><a href="http://www.sylhetexpress.com/category/media-watch">মিডিয়া ওয়াচ</a></li>
# <li><a href="http://www.sylhetexpress.com/category/sahitto-o-sangskriti">সাহিত্য ও সংস্কৃতি</a></li>
# <li><a href="http://www.sylhetexpress.com/category/interview">সাক্ষাৎকার</a></li>
# <li><a href="http://www.sylhetexpress.com/category/education">শিক্ষা</a></li>
# <li><a href="http://www.sylhetexpress.com/category/local-government">স্থানীয় সরকার</a></li>
# <li><a href="http://www.sylhetexpress.com/category/administration">প্রশাসন</a></li>
# <li><a href="http://www.sylhetexpress.com/category/emigration">প্রবাস</a></li>
# <li><a href="http://www.sylhetexpress.com/category/election">নির্বাচন</a></li>
# <li><a href="http://www.sylhetexpress.com/category/day">দিবস</a></li>
# <li><a href="http://www.sylhetexpress.com/category/magazines">পত্রিকার সংবাদ</a></li>
# <li><a href="http://www.sylhetexpress.com/category/sports">খেলাধুলা</a></li>
# <li><a href="http://www.sylhetexpress.com/category/industry-trade">শিল্প-বাণিজ্য</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="row">
# <div class="col-xs-12">
# <div class="line-white"></div>
# <div class="sylhetexpress-info-div">
# <p>কপিরাইট <i class="fa fa-copyright"></i> ২০০৬-২০২১ <a href="http://www.sylhetexpress.com" style="color: #fff;">সিলেট এক্সপ্রেস</a> - সিলেটের প্রথম অনলাইন দৈনিক, সর্বস্বত্ব স্বত্বাধিকার সংরক্ষিত</p>
# <p>সম্পাদক : আব্দুল বাতিন ফয়সল, মোবা : +৮৮ ০১৭১১ ৩৩৪৬৪১ | ব্যবস্থাপনা সম্পাদক : রোটারিয়ান আব্দুল মুহিত দিদার, মোবা : +৮৮ ০১৭৩০ ১২২০৫১</p>
# <p>যোগাযোগ : রুম নং- ৯০৬, সিলেট সিটি সেন্টার, জিন্দাবাজার, সিলেট-৩১০০ |  ইমেইল: <span style="font-family: arial;"><a href="mailto:sylhetexpress2011@gmail.com" style="color:#fff">sylhetexpress2011@gmail.com</a></span></p>
# <p>ওয়েব অ্যাডমিন : এ.এস.এইচ ইমরানুল ইসলাম রুবেল, শেখ মুক্তাদির ইকবাল, আইটি কর্মকর্তা, ওয়াইলড ব্রেইন, (ইইউ, মিডল ইস্ট, ইউএসএ, এশিয়া, ইউকে), সোলেমান আহমদ তাওহিদ</p>
# <p>
# <strong>⚠ এই ওয়েবসাইটের কোনো লেখা, ছবি, ভিডিও অনুমতি ছাড়া ব্যবহার বেআইনি</strong>
# </p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </footer>
# <a class="btn btn-1x btn-go-top go-to-top" href="javascript:void(0)" onclick="gotop()" style="display: none;"><i aria-hidden="true" class="fa fa-angle-up fa-2x"></i></a>
# <script src="http://www.sylhetexpress.com/wp-content/themes/sylhet-expresss/js/jquery.min.js"></script>
# <script src="http://www.sylhetexpress.com/wp-content/themes/sylhet-expresss/js/bootstrap.min.js"></script>
# <script src="http://www.sylhetexpress.com/wp-content/themes/sylhet-expresss/js/bootstrap-datepicker.min.js"></script>
# <script src="http://www.sylhetexpress.com/wp-content/themes/sylhet-expresss/js/lightslider.js"></script>
# <script src="http://www.sylhetexpress.com/wp-content/themes/sylhet-expresss/js/app.js"></script>
# <script src="http://www.sylhetexpress.com/wp-content/themes/sylhet-expresss/js/breakingnews.min.js"></script>
# <script type="text/javascript">
#   $('.form_submit').click( function(){
# 	$('#sylhetexpress-search').submit();
#   });
# </script>
# <script type="text/javascript">
# 	$('#tp-search input').datepicker({
# 	format: 'yyyy/mm/dd'
# 	});
# </script>
# <script type="text/javascript">
#   $(window).load(function(e) {
# 	$("#sBreakingNews").breakingNews({
# 	  effect    :"slide-h",
# 	  autoplay  :true,
# 	  timer   :3000,
# 	  color   :"red"
# 	});
#   })
#
# </script>
# <script type="text/javascript">
#   $(document).ready(function(){
# 	$('.rel-soci').hover(function () {
# 	  $(this).find('.rel-soci-con').show();
# 	}, function () {
# 	 $(this).find('.rel-soci-con').hide();
#    });
#
#   });
# </script>
#
#
# <script id="mpp_gutenberg_tabs-js" src="http://www.sylhetexpress.com/wp-content/plugins/metronet-profile-picture/js/mpp-frontend.js?ver=2.6.0" type="text/javascript"></script>
# <script id="the_champ_ss_general_scripts-js" src="http://www.sylhetexpress.com/wp-content/plugins/super-socializer/js/front/social_login/general.js?ver=7.13.25" type="text/javascript"></script>
# <script id="the_champ_share_counts-js" src="http://www.sylhetexpress.com/wp-content/plugins/super-socializer/js/front/sharing/sharing.js?ver=7.13.25" type="text/javascript"></script>
# <script id="wp-embed-js" src="http://www.sylhetexpress.com/wp-includes/js/wp-embed.min.js?ver=5.8" type="text/javascript"></script>

# %%
if 

page.status != 200
# Out:
# 200

# %%
from fake_useragent import UserAgent
import urllib

def requestWithUA(url):
    ua = UserAgent()
    request = urllib.request.Request(
        url,
        headers={
            'User-Agent': ua.random
        }
    )
    page = urllib.request.urlopen(request)
    return page

# %%
for url in paper_site.values():
    try:
        resp = requestWithUA(url)
    except:
        print(url, " error")
    if resp.status != 200:
        print(url)
# Out:
# https://ukhiyanews.com  error
# https://chattagramnews.com  error
# https://dailykhowai.com  error
# https://dailycoxsbazar.com  error
# https://amaderbarisal.com  error
# https://surmatimes.com  error
# https://teknafnews.com  error
# https://barisalnews.com  error
# https://sylhetexpress.com  error

# %%
old_paper_site
# Out:
# {'prothom_alo': 'https://www.prothomalo.com',
#  'the_daily_janakantha': 'https://www.dailyjanakantha.com',
#  'kaler_kantho': 'https://www.kalerkantho.com',
#  'the_daily_jugantor': 'https://www.jugantor.com',
#  'the_daily_ittefaq': 'https://www.ittefaq.com.bd',
#  'samakal': 'https://samakal.com',
#  'amader_shomoy': 'http://www.dainikamadershomoy.com',
#  'bhorer_kagoj': 'https://www.bhorerkagoj.com',
#  'daily_manab_zamin': 'https://mzamin.com',
#  'alokito_bangladesh': 'https://www.alokitobangladesh.com',
#  'the_sangbad': 'http://sangbad.net.bd',
#  'the_daily_inqilab': 'https://www.dailyinqilab.com',
#  'jaijaidin': 'https://www.jaijaidinbd.com',
#  'daily_naya_diganta': 'https://www.dailynayadiganta.com',
#  'the_azadi': 'https://dainikazadi.net',
#  'daily_sangram': 'https://dailysangram.com',
#  'sangbad_pratidin': 'https://www.sangbadpratidin.in',
#  'the_daily_star': 'https://www.thedailystar.net/bangla',
#  'bd_news': 'bangla.bdnews24.com'}

# %%
paper_site
# Out:
# {'prothom_alo': 'https://www.prothomalo.com',
#  'bangladesh_pratidin': 'https://www.bd-pratidin.com',
#  'the_daily_ittefaq': 'https://www.ittefaq.com.bd',
#  'kaler_kantho': 'https://www.kalerkantho.com',
#  'daily_naya_diganta': 'https://www.dailynayadiganta.com',
#  'daily_amar_sangbad': 'https://www.amarsangbad.com',
#  'protidiner_sangbad': 'https://www.protidinersangbad.com',
#  'the_daily_jugantor': 'https://www.jugantor.com',
#  'daily_sangram': 'https://dailysangram.com',
#  'daily_manab_zamin': 'https://mzamin.com',
#  'amader_shomoy': 'http://www.dainikamadershomoy.com',
#  'samakal': 'https://samakal.com',
#  'the_daily_janakantha': 'https://www.dailyjanakantha.com',
#  'jaijaidin': 'https://www.jaijaidinbd.com',
#  'bhorer_kagoj': 'https://www.bhorerkagoj.com',
#  'arthoniteer_kagoj': 'http://www.arthoniteerkagoj.com',
#  'the_daily_inqilab': 'https://www.dailyinqilab.com',
#  'sangbad': 'http://sangbad.net.bd',
#  'manob_kantha': 'https://www.manobkantha.com.bd',
#  'daily_suprobhat': 'https://suprobhat.com',
#  'bangladesh_journal': 'https://www.bd-journal.com',
#  'bonik_barta': 'https://bonikbarta.net',
#  'alokito_bangladesh': 'https://www.alokitobangladesh.com',
#  'ajker_bazar': 'https://www.ajkerbazzar.com',
#  'amadar_orthoneeti': 'https://amaderorthoneeti.com/new/',
#  'bangladesh_post': 'https://bn.bangladeshpost.net',
#  'sorejomin_barta': 'http://sorejominbarta.com',
#  'ajker_patrika': 'https://www.ajkerpatrika.com',
#  'khabar_patra': 'https://khoborpatrabd.com',
#  'vorer_pata': 'https://dailyvorerpata.com',
#  'shomoyer_alo': 'https://www.shomoyeralo.com',
#  'dhakar_dak': 'https://dhakardak-bd.com',
#  'natun_barta': 'http://www.natun-barta.com',
#  'share_biz': 'https://sharebiz.net',
#  'daily_bartoman': 'http://dailybartoman.com',
#  'ajkaler_khobor': 'https://www.ajkalerkhobor.net',
#  'sangbad_konika': 'https://www.sangbadkonika.com',
#  'somoyer_kantha': 'http://www.gonokantho.com',
#  'daily_star': 'https://www.thedailystar.net/bangla/',
#  'khola_kagoj': 'http://kholakagojbd.com',
#  'desh_rupantor': 'https://www.deshrupantor.com',
#  'bangladesher_khabor': 'https://www.bangladesherkhabor.net',
#  'amar_desh': 'http://bd-bulletin.com',
#  'daily_jagran': 'https://dailyjagaran.com',
#  'business_standard': 'https://www.tbsnews.net/bangla',
#  'dhaka_tribune': 'https://bangla.dhakatribune.com',
#  'khulna_news': 'https://khulnanews.com',
#  'daily_azadi': 'https://dainikazadi.org',
#  'daily_purbokone': 'https://dainikpurbokone.net',
#  'amader_comilla': 'https://dailyamadercomilla.com',
#  'daily_purbanchal': 'https://purbanchal.com',
#  'ukhiya_news': 'https://ukhiyanews.com',
#  'matha_bhanga': 'https://mathabhanga.com',
#  'rajshahi_news_24': 'https://rajshahinews24.com',
#  'chattagram_news': 'https://chattagramnews.com',
#  'daily_khowai': 'https://dailykhowai.com',
#  'daily_karatoa': 'https://karatoa.com.bd',
#  'satkhira_news': 'https://satkhiranews.com',
#  'dainik_sylhet': 'https://dainiksylhet.com',
#  'daily_coxsbazar': 'https://dailycoxsbazar.com',
#  'uttorpurbo': 'https://euttorpurbo.com',
#  'ajker_jamalpur': 'https://ajkerjamalpur.com',
#  'amader_barisal': 'https://amaderbarisal.com',
#  'surma_times': 'https://surmatimes.com',
#  'dinajpur_news': 'https://dinajpurnews.com',
#  'kuakata_news': 'https://kuakatanews.com',
#  'chadpur_times': 'https://chandpurtimes.com',
#  'mukto_khobor_24': 'https://muktokhobor24.com',
#  'teknaf_news': 'https://teknafnews.com',
#  'bogra_sangbad': 'https://bograsangbad.com',
#  'rajshahir_somoy': 'https://rajshahirsomoy.com',
#  'chandpurweb': 'https://chandpurweb.com',
#  'barisal_news': 'https://barisalnews.com',
#  'sylhet_express': 'https://sylhetexpress.com',
#  'laksmipur_24': 'https://lakshmipur24.com',
#  'prothom_feni': 'https://prothom-feni.com',
#  'amar_noakhali': 'https://amarnoakhali.com',
#  'chakaria_news': 'https://chakarianews.com',
#  'gramer_kagoj': 'https://gramerkagoj.com',
#  'andoloner_bazar': 'https://dailyandolonerbazar.com',
#  'khulnanchal': 'https://khulnanchal.com',
#  'mymensingh_pratidin': 'https://mymensinghpratidin.com',
#  'the_sangbad': 'http://sangbad.net.bd',
#  'the_azadi': 'https://dainikazadi.net',
#  'sangbad_pratidin': 'https://www.sangbadpratidin.in',
#  'the_daily_star': 'https://www.thedailystar.net/bangla',
#  'bd_news': 'bangla.bdnews24.com'}

# %%
https://ukhiyanews.com  error
https://chattagramnews.com  error
https://dailykhowai.com  error
https://dailycoxsbazar.com  error
https://amaderbarisal.com  error
https://surmatimes.com  error
https://teknafnews.com  error
https://barisalnews.com  error
https://sylhetexpress.com  error

# %%
del paper_site['ukhiya_news']
del paper_site['chattagram_news']
del paper_site['daily_khowai']
del paper_site['daily_coxsbazar']
del paper_site['amader_barisal']
del paper_site['surma_times']
del paper_site['teknaf_news']
del paper_site['barisal_news']
del paper_site['sylhet_express']

# %%
paper_site
# Out:
# {'prothom_alo': 'https://www.prothomalo.com',
#  'bangladesh_pratidin': 'https://www.bd-pratidin.com',
#  'the_daily_ittefaq': 'https://www.ittefaq.com.bd',
#  'kaler_kantho': 'https://www.kalerkantho.com',
#  'daily_naya_diganta': 'https://www.dailynayadiganta.com',
#  'daily_amar_sangbad': 'https://www.amarsangbad.com',
#  'protidiner_sangbad': 'https://www.protidinersangbad.com',
#  'the_daily_jugantor': 'https://www.jugantor.com',
#  'daily_sangram': 'https://dailysangram.com',
#  'daily_manab_zamin': 'https://mzamin.com',
#  'amader_shomoy': 'http://www.dainikamadershomoy.com',
#  'samakal': 'https://samakal.com',
#  'the_daily_janakantha': 'https://www.dailyjanakantha.com',
#  'jaijaidin': 'https://www.jaijaidinbd.com',
#  'bhorer_kagoj': 'https://www.bhorerkagoj.com',
#  'arthoniteer_kagoj': 'http://www.arthoniteerkagoj.com',
#  'the_daily_inqilab': 'https://www.dailyinqilab.com',
#  'sangbad': 'http://sangbad.net.bd',
#  'manob_kantha': 'https://www.manobkantha.com.bd',
#  'daily_suprobhat': 'https://suprobhat.com',
#  'bangladesh_journal': 'https://www.bd-journal.com',
#  'bonik_barta': 'https://bonikbarta.net',
#  'alokito_bangladesh': 'https://www.alokitobangladesh.com',
#  'ajker_bazar': 'https://www.ajkerbazzar.com',
#  'amadar_orthoneeti': 'https://amaderorthoneeti.com/new/',
#  'bangladesh_post': 'https://bn.bangladeshpost.net',
#  'sorejomin_barta': 'http://sorejominbarta.com',
#  'ajker_patrika': 'https://www.ajkerpatrika.com',
#  'khabar_patra': 'https://khoborpatrabd.com',
#  'vorer_pata': 'https://dailyvorerpata.com',
#  'shomoyer_alo': 'https://www.shomoyeralo.com',
#  'dhakar_dak': 'https://dhakardak-bd.com',
#  'natun_barta': 'http://www.natun-barta.com',
#  'share_biz': 'https://sharebiz.net',
#  'daily_bartoman': 'http://dailybartoman.com',
#  'ajkaler_khobor': 'https://www.ajkalerkhobor.net',
#  'sangbad_konika': 'https://www.sangbadkonika.com',
#  'somoyer_kantha': 'http://www.gonokantho.com',
#  'daily_star': 'https://www.thedailystar.net/bangla/',
#  'khola_kagoj': 'http://kholakagojbd.com',
#  'desh_rupantor': 'https://www.deshrupantor.com',
#  'bangladesher_khabor': 'https://www.bangladesherkhabor.net',
#  'amar_desh': 'http://bd-bulletin.com',
#  'daily_jagran': 'https://dailyjagaran.com',
#  'business_standard': 'https://www.tbsnews.net/bangla',
#  'dhaka_tribune': 'https://bangla.dhakatribune.com',
#  'khulna_news': 'https://khulnanews.com',
#  'daily_azadi': 'https://dainikazadi.org',
#  'daily_purbokone': 'https://dainikpurbokone.net',
#  'amader_comilla': 'https://dailyamadercomilla.com',
#  'daily_purbanchal': 'https://purbanchal.com',
#  'matha_bhanga': 'https://mathabhanga.com',
#  'rajshahi_news_24': 'https://rajshahinews24.com',
#  'daily_karatoa': 'https://karatoa.com.bd',
#  'satkhira_news': 'https://satkhiranews.com',
#  'dainik_sylhet': 'https://dainiksylhet.com',
#  'uttorpurbo': 'https://euttorpurbo.com',
#  'ajker_jamalpur': 'https://ajkerjamalpur.com',
#  'dinajpur_news': 'https://dinajpurnews.com',
#  'kuakata_news': 'https://kuakatanews.com',
#  'chadpur_times': 'https://chandpurtimes.com',
#  'mukto_khobor_24': 'https://muktokhobor24.com',
#  'bogra_sangbad': 'https://bograsangbad.com',
#  'rajshahir_somoy': 'https://rajshahirsomoy.com',
#  'chandpurweb': 'https://chandpurweb.com',
#  'laksmipur_24': 'https://lakshmipur24.com',
#  'prothom_feni': 'https://prothom-feni.com',
#  'amar_noakhali': 'https://amarnoakhali.com',
#  'chakaria_news': 'https://chakarianews.com',
#  'gramer_kagoj': 'https://gramerkagoj.com',
#  'andoloner_bazar': 'https://dailyandolonerbazar.com',
#  'khulnanchal': 'https://khulnanchal.com',
#  'mymensingh_pratidin': 'https://mymensinghpratidin.com',
#  'the_sangbad': 'http://sangbad.net.bd',
#  'the_azadi': 'https://dainikazadi.net',
#  'sangbad_pratidin': 'https://www.sangbadpratidin.in',
#  'the_daily_star': 'https://www.thedailystar.net/bangla',
#  'bd_news': 'bangla.bdnews24.com'}

# %%
for v in paper_site.keys() - old_paper_site.keys():
    print(f"      - '{v}'")
# Out:
#       - 'daily_azadi'
#       - 'dhaka_tribune'
#       - 'daily_karatoa'
#       - 'somoyer_kantha'
#       - 'protidiner_sangbad'
#       - 'ajker_patrika'
#       - 'amar_noakhali'
#       - 'laksmipur_24'
#       - 'daily_amar_sangbad'
#       - 'ajkaler_khobor'
#       - 'satkhira_news'
#       - 'dainik_sylhet'
#       - 'amadar_orthoneeti'
#       - 'vorer_pata'
#       - 'sorejomin_barta'
#       - 'business_standard'
#       - 'chadpur_times'
#       - 'prothom_feni'
#       - 'share_biz'
#       - 'daily_purbanchal'
#       - 'bangladesh_journal'
#       - 'sangbad'
#       - 'bangladesh_pratidin'
#       - 'dinajpur_news'
#       - 'daily_jagran'
#       - 'chandpurweb'
#       - 'ajker_jamalpur'
#       - 'gramer_kagoj'
#       - 'sangbad_konika'
#       - 'natun_barta'
#       - 'ajker_bazar'
#       - 'daily_purbokone'
#       - 'mymensingh_pratidin'
#       - 'shomoyer_alo'
#       - 'kuakata_news'
#       - 'arthoniteer_kagoj'
#       - 'khulnanchal'
#       - 'desh_rupantor'
#       - 'chakaria_news'
#       - 'daily_star'
#       - 'khulna_news'
#       - 'bogra_sangbad'
#       - 'mukto_khobor_24'
#       - 'amader_comilla'
#       - 'uttorpurbo'
#       - 'bangladesher_khabor'
#       - 'daily_suprobhat'
#       - 'rajshahi_news_24'
#       - 'daily_bartoman'
#       - 'manob_kantha'
#       - 'bonik_barta'
#       - 'rajshahir_somoy'
#       - 'bangladesh_post'
#       - 'andoloner_bazar'
#       - 'khabar_patra'
#       - 'dhakar_dak'
#       - 'khola_kagoj'
#       - 'matha_bhanga'
#       - 'amar_desh'

# %%
keywords = {"জলমগ্ন": "submerged",
    "জোয়ারের":"tidal", 
    "প্লাবিত": "flooded", 
    "বন্যা": "flood", 
    "জলাবদ্ধ": "waterlogged", 
    "উজান": "upstream", 
    "ঘূর্ণিঝড়": "cyclone",
    "নদী": "river", 
    "ভাঙ্গন": "erosion",
    "বাঁধ": "embankment",
    "বেড়িবাঁধ": "embankment",
    "পোল্ডার": "polder"
}

# %%
for v in keywords.keys():
    print(f"      - \"\\\"{v}\\\"\"")
# Out:
#       - "\"জলমগ্ন\""
#       - "\"জোয়ারের\""
#       - "\"প্লাবিত\""
#       - "\"বন্যা\""
#       - "\"জলাবদ্ধ\""
#       - "\"উজান\""
#       - "\"ঘূর্ণিঝড়\""
#       - "\"নদী\""
#       - "\"ভাঙ্গন\""
#       - "\"বাঁধ\""
#       - "\"বেড়িবাঁধ\""
#       - "\"পোল্ডার\""

# %%
with open("paper_to_site.json", "w") as f:
    json.dump(paper_site, f)
