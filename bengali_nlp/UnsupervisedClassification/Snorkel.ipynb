# %%
import sys
sys.path.insert(0, "..")

from bengali_article_classification.load_classification_data import (
    load_fulldataset, 
    load_fivefold_standard_training_dataset,
    load_exact_fulldataset
)

from bengali_timeseries.timeseries_from_classification import flood_timeseries_with_model
from bengali_classification_models.sklearnModel import LinearSVC
from bengali_timeseries.timeseries import TimeSeries

# %%
df, _id, Xtr, Xte, ytr, yte = load_fivefold_standard_training_dataset(root="../bengali_article_classification/training_datasets")
# Out:
# Loaded rawFivefoldWithTranslation dataset
# 5 folds
# 804 training examples
# 202 test examples

# %%
df
# Out:
#                                                 content  is_flood split_0  \
# 0     চরাঞ্চলে সাধারণত আষাঢ়–ভাদ্র মাসের মাঝামাঝি পর্...     False    test
# 1     সুনামগঞ্জ প্রতিনিধি\nশেষের পাতা  ১৩ জুলাই ২০২০...      True    test
# 2     >\nজনপ্রতিনিধিরা ব্যক্তিগত উদ্যোগে কিছু ত্রাণ ...      True   train
# 3     ১৮ ফেব্রুয়ারি ২০১৮, ডেইলি স্টার ওকেয়ার বাংলাদে...     False    test
# 4     কখনো ঠা ঠা রোদ আবার কখনো মধ্য শ্রাবণের অঝোরধার...     False    test
# ...                                                 ...       ...     ...
# 1001  নোয়াখালীর ভাসানচর দ্বীপটি পুরোপুরি বাসযোগ্য বল...     False   train
# 1002  কক্সবাজারের চকরিয়ায় ঘূর্ণিঝড় ‘মোরা’য় বসতবাড়ি হ...     False    test
# 1003  শেফালি বেগম গৃহিণী। প্রায় ১০ বছর আগে বিয়ে হয় ত...     False    test
# 1004  প্রাকৃতিক দুর্যোগে নষ্ট হওয়া ফসলের আর্থিক ক্ষ...      True    test
# 1005  সম্প্রতি মিয়ানমারে রয়টার্সের দুজন সাংবাদিককে স...     False   train
#
#      split_1 split_2 split_3 split_4  \
# 0       test    test    test   train
# ...
